# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_colwidth', 100)

from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# # Import data

# %%
fslr = pd.read_csv('./data_first_solar_FSLR.csv')
gctay = pd.read_csv('./data_siemens_gamesa_GCTAY.csv')
spwr = pd.read_csv('./data_sunpower_SPWR.csv')
run = pd.read_csv('./data_sunrun_RUN.csv')
plug = pd.read_csv('./data_plug_power_PLUG.csv')

# %% [markdown]
# ## Set datatime index

# %%
def set_datetime_index(df):
    df['date'] = pd.to_datetime(df['Date'], errors='coerce')
    df.set_index('date', inplace=True)
    df.drop('Date', axis=1, inplace=True)
    return df

# %%
fslr = set_datetime_index(fslr)
gctay = set_datetime_index(gctay)
spwr = set_datetime_index(spwr)
run = set_datetime_index(run)
plug = set_datetime_index(plug)

# %% [markdown]
# # Import data normalized

# %%
fslr_normalized = pd.read_csv('./data_first_solar_FSLR_normalized.csv')
gctay_normalized = pd.read_csv('./data_siemens_gamesa_GCTAY_normalized.csv')
spwr_normalized = pd.read_csv('./data_sunpower_SPWR_normalized.csv')
run_normalized = pd.read_csv('./data_sunrun_RUN_normalized.csv')
plug_normalized = pd.read_csv('./data_plug_power_PLUG_normalized.csv')

# %%
fslr_normalized = set_datetime_index(fslr_normalized)
gctay_normalized = set_datetime_index(gctay_normalized)
spwr_normalized = set_datetime_index(spwr_normalized)
run_normalized = set_datetime_index(run_normalized)
plug_normalized = set_datetime_index(plug_normalized)

# %% [markdown]
# # Granger Tests - FSLR

# %%
maxlag = 100
ticker = 'FSLR'
series = 'daily_tweets'

# %%
input_data = np.asarray(fslr[['closing_price', series]])
test = grangercausalitytests(input_data, maxlag, addconst = True, verbose=True);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7173  , p=0.3971  , df_denom=2536, df_num=1
# ssr based chi2 test:   chi2=0.7182  , p=0.3968  , df=1
# likelihood ratio test: chi2=0.7180  , p=0.3968  , df=1
# parameter F test:         F=0.7173  , p=0.3971  , df_denom=2536, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3613  , p=0.6968  , df_denom=2533, df_num=2
# ssr based chi2 test:   chi2=0.7240  , p=0.6963  , df=2
# likelihood ratio test: chi2=0.7239  , p=0.6963  , df=2
# parameter F test:         F=0.3613  , p=0.6968  , df_denom=2533, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4826  , p=0.6944  , df_denom=2530, df_num=3
# ssr based chi2 test:   chi2=1.4519  , p=0.6934  , df=3
# likelihood ratio test: chi2=1.4515  , p=0.6935  , df=3
# parameter F test:         F=0.4826  , p=0.6944  , df_denom=2530, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5873  , p=0.6718  , df_denom=2527, df_num=4
# ssr based chi2 test:   chi2=2.3577  , p=0.6703  , df=4
# likelihood ratio test: chi2=2.3566  , p=0.6705  , df=4
# parameter F test:         F=0.5873  , p=0.6718  , df_denom=2527, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6558  , p=0.6571  , df_denom=2524, df_num=5
# ssr based chi2 test:   chi2=3.2933  , p=0.6549  , df=5
# likelihood ratio test: chi2=3.2912  , p=0.6552  , df=5
# parameter F test:         F=0.6558  , p=0.6571  , df_denom=2524, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4858  , p=0.8194  , df_denom=2521, df_num=6
# ssr based chi2 test:   chi2=2.9296  , p=0.8176  , df=6
# likelihood ratio test: chi2=2.9279  , p=0.8178  , df=6
# parameter F test:         F=0.4858  , p=0.8194  , df_denom=2521, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3892  , p=0.9092  , df_denom=2518, df_num=7
# ssr based chi2 test:   chi2=2.7403  , p=0.9079  , df=7
# likelihood ratio test: chi2=2.7389  , p=0.9081  , df=7
# parameter F test:         F=0.3892  , p=0.9092  , df_denom=2518, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3580  , p=0.9425  , df_denom=2515, df_num=8
# ssr based chi2 test:   chi2=2.8833  , p=0.9415  , df=8
# likelihood ratio test: chi2=2.8817  , p=0.9416  , df=8
# parameter F test:         F=0.3580  , p=0.9425  , df_denom=2515, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4551  , p=0.9048  , df_denom=2512, df_num=9
# ssr based chi2 test:   chi2=4.1267  , p=0.9029  , df=9
# likelihood ratio test: chi2=4.1234  , p=0.9031  , df=9
# parameter F test:         F=0.4551  , p=0.9048  , df_denom=2512, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5338  , p=0.8673  , df_denom=2509, df_num=10
# ssr based chi2 test:   chi2=5.3830  , p=0.8642  , df=10
# likelihood ratio test: chi2=5.3772  , p=0.8646  , df=10
# parameter F test:         F=0.5338  , p=0.8673  , df_denom=2509, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.5049  , p=0.9012  , df_denom=2506, df_num=11
# ssr based chi2 test:   chi2=5.6052  , p=0.8984  , df=11
# likelihood ratio test: chi2=5.5990  , p=0.8987  , df=11
# parameter F test:         F=0.5049  , p=0.9012  , df_denom=2506, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.4737  , p=0.9309  , df_denom=2503, df_num=12
# ssr based chi2 test:   chi2=5.7409  , p=0.9286  , df=12
# likelihood ratio test: chi2=5.7344  , p=0.9289  , df=12
# parameter F test:         F=0.4737  , p=0.9309  , df_denom=2503, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.4072  , p=0.9680  , df_denom=2500, df_num=13
# ssr based chi2 test:   chi2=5.3511  , p=0.9666  , df=13
# likelihood ratio test: chi2=5.3454  , p=0.9668  , df=13
# parameter F test:         F=0.4072  , p=0.9680  , df_denom=2500, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.6662  , p=0.8093  , df_denom=2497, df_num=14
# ssr based chi2 test:   chi2=9.4345  , p=0.8022  , df=14
# likelihood ratio test: chi2=9.4170  , p=0.8034  , df=14
# parameter F test:         F=0.6662  , p=0.8093  , df_denom=2497, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.5990  , p=0.8779  , df_denom=2494, df_num=15
# ssr based chi2 test:   chi2=9.0967  , p=0.8724  , df=15
# likelihood ratio test: chi2=9.0803  , p=0.8733  , df=15
# parameter F test:         F=0.5990  , p=0.8779  , df_denom=2494, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.5636  , p=0.9123  , df_denom=2491, df_num=16
# ssr based chi2 test:   chi2=9.1373  , p=0.9077  , df=16
# likelihood ratio test: chi2=9.1208  , p=0.9084  , df=16
# parameter F test:         F=0.5636  , p=0.9123  , df_denom=2491, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.5457  , p=0.9308  , df_denom=2488, df_num=17
# ssr based chi2 test:   chi2=9.4076  , p=0.9266  , df=17
# likelihood ratio test: chi2=9.3901  , p=0.9272  , df=17
# parameter F test:         F=0.5457  , p=0.9308  , df_denom=2488, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=0.5184  , p=0.9512  , df_denom=2485, df_num=18
# ssr based chi2 test:   chi2=9.4709  , p=0.9478  , df=18
# likelihood ratio test: chi2=9.4532  , p=0.9483  , df=18
# parameter F test:         F=0.5184  , p=0.9512  , df_denom=2485, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=0.4733  , p=0.9734  , df_denom=2482, df_num=19
# ssr based chi2 test:   chi2=9.1337  , p=0.9712  , df=19
# likelihood ratio test: chi2=9.1172  , p=0.9715  , df=19
# parameter F test:         F=0.4733  , p=0.9734  , df_denom=2482, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=0.5178  , p=0.9609  , df_denom=2479, df_num=20
# ssr based chi2 test:   chi2=10.5283 , p=0.9576  , df=20
# likelihood ratio test: chi2=10.5064 , p=0.9580  , df=20
# parameter F test:         F=0.5178  , p=0.9609  , df_denom=2479, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=0.6789  , p=0.8577  , df_denom=2476, df_num=21
# ssr based chi2 test:   chi2=14.5047 , p=0.8470  , df=21
# likelihood ratio test: chi2=14.4631 , p=0.8489  , df=21
# parameter F test:         F=0.6789  , p=0.8577  , df_denom=2476, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.6412  , p=0.8970  , df_denom=2473, df_num=22
# ssr based chi2 test:   chi2=14.3637 , p=0.8881  , df=22
# likelihood ratio test: chi2=14.3229 , p=0.8896  , df=22
# parameter F test:         F=0.6412  , p=0.8970  , df_denom=2473, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=0.6349  , p=0.9077  , df_denom=2470, df_num=23
# ssr based chi2 test:   chi2=14.8815 , p=0.8988  , df=23
# likelihood ratio test: chi2=14.8377 , p=0.9004  , df=23
# parameter F test:         F=0.6349  , p=0.9077  , df_denom=2470, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=0.6061  , p=0.9328  , df_denom=2467, df_num=24
# ssr based chi2 test:   chi2=14.8341 , p=0.9255  , df=24
# likelihood ratio test: chi2=14.7906 , p=0.9267  , df=24
# parameter F test:         F=0.6061  , p=0.9328  , df_denom=2467, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=0.6270  , p=0.9235  , df_denom=2464, df_num=25
# ssr based chi2 test:   chi2=16.0005 , p=0.9148  , df=25
# likelihood ratio test: chi2=15.9498 , p=0.9163  , df=25
# parameter F test:         F=0.6270  , p=0.9235  , df_denom=2464, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=0.6315  , p=0.9249  , df_denom=2461, df_num=26
# ssr based chi2 test:   chi2=16.7721 , p=0.9158  , df=26
# likelihood ratio test: chi2=16.7164 , p=0.9174  , df=26
# parameter F test:         F=0.6315  , p=0.9249  , df_denom=2461, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=0.5937  , p=0.9518  , df_denom=2458, df_num=27
# ssr based chi2 test:   chi2=16.3887 , p=0.9451  , df=27
# likelihood ratio test: chi2=16.3355 , p=0.9462  , df=27
# parameter F test:         F=0.5937  , p=0.9518  , df_denom=2458, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=0.6059  , p=0.9487  , df_denom=2455, df_num=28
# ssr based chi2 test:   chi2=17.3597 , p=0.9411  , df=28
# likelihood ratio test: chi2=17.3000 , p=0.9424  , df=28
# parameter F test:         F=0.6059  , p=0.9487  , df_denom=2455, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=0.5959  , p=0.9571  , df_denom=2452, df_num=29
# ssr based chi2 test:   chi2=17.6962 , p=0.9502  , df=29
# likelihood ratio test: chi2=17.6341 , p=0.9514  , df=29
# parameter F test:         F=0.5959  , p=0.9571  , df_denom=2452, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=0.5701  , p=0.9708  , df_denom=2449, df_num=30
# ssr based chi2 test:   chi2=17.5301 , p=0.9657  , df=30
# likelihood ratio test: chi2=17.4691 , p=0.9665  , df=30
# parameter F test:         F=0.5701  , p=0.9708  , df_denom=2449, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=0.6578  , p=0.9262  , df_denom=2446, df_num=31
# ssr based chi2 test:   chi2=20.9162 , p=0.9141  , df=31
# likelihood ratio test: chi2=20.8295 , p=0.9163  , df=31
# parameter F test:         F=0.6578  , p=0.9262  , df_denom=2446, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=0.6739  , p=0.9176  , df_denom=2443, df_num=32
# ssr based chi2 test:   chi2=22.1380 , p=0.9037  , df=32
# likelihood ratio test: chi2=22.0409 , p=0.9063  , df=32
# parameter F test:         F=0.6739  , p=0.9176  , df_denom=2443, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=0.6627  , p=0.9296  , df_denom=2440, df_num=33
# ssr based chi2 test:   chi2=22.4712 , p=0.9166  , df=33
# likelihood ratio test: chi2=22.3711 , p=0.9190  , df=33
# parameter F test:         F=0.6627  , p=0.9296  , df_denom=2440, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=0.6698  , p=0.9277  , df_denom=2437, df_num=34
# ssr based chi2 test:   chi2=23.4197 , p=0.9137  , df=34
# likelihood ratio test: chi2=23.3109 , p=0.9163  , df=34
# parameter F test:         F=0.6698  , p=0.9277  , df_denom=2437, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=0.6618  , p=0.9365  , df_denom=2434, df_num=35
# ssr based chi2 test:   chi2=23.8401 , p=0.9233  , df=35
# likelihood ratio test: chi2=23.7273 , p=0.9258  , df=35
# parameter F test:         F=0.6618  , p=0.9365  , df_denom=2434, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=0.6680  , p=0.9351  , df_denom=2431, df_num=36
# ssr based chi2 test:   chi2=24.7709 , p=0.9211  , df=36
# likelihood ratio test: chi2=24.6492 , p=0.9237  , df=36
# parameter F test:         F=0.6680  , p=0.9351  , df_denom=2431, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=0.6450  , p=0.9525  , df_denom=2428, df_num=37
# ssr based chi2 test:   chi2=24.6007 , p=0.9411  , df=37
# likelihood ratio test: chi2=24.4805 , p=0.9432  , df=37
# parameter F test:         F=0.6450  , p=0.9525  , df_denom=2428, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=0.6936  , p=0.9217  , df_denom=2425, df_num=38
# ssr based chi2 test:   chi2=27.1940 , p=0.9037  , df=38
# likelihood ratio test: chi2=27.0473 , p=0.9073  , df=38
# parameter F test:         F=0.6936  , p=0.9217  , df_denom=2425, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=0.6747  , p=0.9388  , df_denom=2422, df_num=39
# ssr based chi2 test:   chi2=27.1697 , p=0.9233  , df=39
# likelihood ratio test: chi2=27.0232 , p=0.9263  , df=39
# parameter F test:         F=0.6747  , p=0.9388  , df_denom=2422, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=0.6797  , p=0.9378  , df_denom=2419, df_num=40
# ssr based chi2 test:   chi2=28.0979 , p=0.9215  , df=40
# likelihood ratio test: chi2=27.9412 , p=0.9247  , df=40
# parameter F test:         F=0.6797  , p=0.9378  , df_denom=2419, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=0.6575  , p=0.9544  , df_denom=2416, df_num=41
# ssr based chi2 test:   chi2=27.8844 , p=0.9411  , df=41
# likelihood ratio test: chi2=27.7299 , p=0.9437  , df=41
# parameter F test:         F=0.6575  , p=0.9544  , df_denom=2416, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=0.6670  , p=0.9509  , df_denom=2413, df_num=42
# ssr based chi2 test:   chi2=28.9999 , p=0.9362  , df=42
# likelihood ratio test: chi2=28.8329 , p=0.9391  , df=42
# parameter F test:         F=0.6670  , p=0.9509  , df_denom=2413, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=0.6525  , p=0.9611  , df_denom=2410, df_num=43
# ssr based chi2 test:   chi2=29.0693 , p=0.9485  , df=43
# likelihood ratio test: chi2=28.9014 , p=0.9509  , df=43
# parameter F test:         F=0.6525  , p=0.9611  , df_denom=2410, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=0.6357  , p=0.9706  , df_denom=2407, df_num=44
# ssr based chi2 test:   chi2=29.0071 , p=0.9603  , df=44
# likelihood ratio test: chi2=28.8399 , p=0.9623  , df=44
# parameter F test:         F=0.6357  , p=0.9706  , df_denom=2407, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=0.6897  , p=0.9426  , df_denom=2404, df_num=45
# ssr based chi2 test:   chi2=32.2113 , p=0.9237  , df=45
# likelihood ratio test: chi2=32.0051 , p=0.9275  , df=45
# parameter F test:         F=0.6897  , p=0.9426  , df_denom=2404, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=0.6770  , p=0.9529  , df_denom=2401, df_num=46
# ssr based chi2 test:   chi2=32.3480 , p=0.9362  , df=46
# likelihood ratio test: chi2=32.1401 , p=0.9396  , df=46
# parameter F test:         F=0.6770  , p=0.9529  , df_denom=2401, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=0.6825  , p=0.9514  , df_denom=2398, df_num=47
# ssr based chi2 test:   chi2=33.3505 , p=0.9335  , df=47
# likelihood ratio test: chi2=33.1294 , p=0.9372  , df=47
# parameter F test:         F=0.6825  , p=0.9514  , df_denom=2398, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=0.6681  , p=0.9616  , df_denom=2395, df_num=48
# ssr based chi2 test:   chi2=33.3664 , p=0.9463  , df=48
# likelihood ratio test: chi2=33.1449 , p=0.9494  , df=48
# parameter F test:         F=0.6681  , p=0.9616  , df_denom=2395, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=0.6766  , p=0.9585  , df_denom=2392, df_num=49
# ssr based chi2 test:   chi2=34.5237 , p=0.9416  , df=49
# likelihood ratio test: chi2=34.2867 , p=0.9451  , df=49
# parameter F test:         F=0.6766  , p=0.9585  , df_denom=2392, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=0.8000  , p=0.8414  , df_denom=2389, df_num=50
# ssr based chi2 test:   chi2=41.6899 , p=0.7923  , df=50
# likelihood ratio test: chi2=41.3447 , p=0.8033  , df=50
# parameter F test:         F=0.8000  , p=0.8414  , df_denom=2389, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=0.8124  , p=0.8263  , df_denom=2386, df_num=51
# ssr based chi2 test:   chi2=43.2213 , p=0.7723  , df=51
# likelihood ratio test: chi2=42.8503 , p=0.7845  , df=51
# parameter F test:         F=0.8124  , p=0.8263  , df_denom=2386, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=0.7991  , p=0.8479  , df_denom=2383, df_num=52
# ssr based chi2 test:   chi2=43.3852 , p=0.7968  , df=52
# likelihood ratio test: chi2=43.0112 , p=0.8083  , df=52
# parameter F test:         F=0.7991  , p=0.8479  , df_denom=2383, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=0.8121  , p=0.8319  , df_denom=2380, df_num=53
# ssr based chi2 test:   chi2=44.9769 , p=0.7754  , df=53
# likelihood ratio test: chi2=44.5751 , p=0.7883  , df=53
# parameter F test:         F=0.8121  , p=0.8319  , df_denom=2380, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=0.8437  , p=0.7843  , df_denom=2377, df_num=54
# ssr based chi2 test:   chi2=47.6511 , p=0.7163  , df=54
# likelihood ratio test: chi2=47.2002 , p=0.7321  , df=54
# parameter F test:         F=0.8437  , p=0.7843  , df_denom=2377, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=0.8732  , p=0.7343  , df_denom=2374, df_num=55
# ssr based chi2 test:   chi2=50.2716 , p=0.6556  , df=55
# likelihood ratio test: chi2=49.7699 , p=0.6741  , df=55
# parameter F test:         F=0.8732  , p=0.7343  , df_denom=2374, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=0.8624  , p=0.7564  , df_denom=2371, df_num=56
# ssr based chi2 test:   chi2=50.5951 , p=0.6789  , df=56
# likelihood ratio test: chi2=50.0868 , p=0.6971  , df=56
# parameter F test:         F=0.8624  , p=0.7564  , df_denom=2371, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=0.8508  , p=0.7793  , df_denom=2368, df_num=57
# ssr based chi2 test:   chi2=50.8513 , p=0.7037  , df=57
# likelihood ratio test: chi2=50.3375 , p=0.7214  , df=57
# parameter F test:         F=0.8508  , p=0.7793  , df_denom=2368, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=0.8402  , p=0.7997  , df_denom=2365, df_num=58
# ssr based chi2 test:   chi2=51.1428 , p=0.7261  , df=58
# likelihood ratio test: chi2=50.6230 , p=0.7434  , df=58
# parameter F test:         F=0.8402  , p=0.7997  , df_denom=2365, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=0.8273  , p=0.8231  , df_denom=2362, df_num=59
# ssr based chi2 test:   chi2=51.2690 , p=0.7528  , df=59
# likelihood ratio test: chi2=50.7465 , p=0.7692  , df=59
# parameter F test:         F=0.8273  , p=0.8231  , df_denom=2362, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=0.8297  , p=0.8214  , df_denom=2359, df_num=60
# ssr based chi2 test:   chi2=52.3376 , p=0.7486  , df=60
# likelihood ratio test: chi2=51.7930 , p=0.7657  , df=60
# parameter F test:         F=0.8297  , p=0.8214  , df_denom=2359, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=0.8289  , p=0.8249  , df_denom=2356, df_num=61
# ssr based chi2 test:   chi2=53.2048 , p=0.7509  , df=61
# likelihood ratio test: chi2=52.6419 , p=0.7683  , df=61
# parameter F test:         F=0.8289  , p=0.8249  , df_denom=2356, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=0.8255  , p=0.8325  , df_denom=2353, df_num=62
# ssr based chi2 test:   chi2=53.9030 , p=0.7583  , df=62
# likelihood ratio test: chi2=53.3251 , p=0.7758  , df=62
# parameter F test:         F=0.8255  , p=0.8325  , df_denom=2353, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=0.8193  , p=0.8443  , df_denom=2350, df_num=63
# ssr based chi2 test:   chi2=54.4029 , p=0.7715  , df=63
# likelihood ratio test: chi2=53.8141 , p=0.7886  , df=63
# parameter F test:         F=0.8193  , p=0.8443  , df_denom=2350, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=0.8052  , p=0.8667  , df_denom=2347, df_num=64
# ssr based chi2 test:   chi2=54.3682 , p=0.7991  , df=64
# likelihood ratio test: chi2=53.7799 , p=0.8151  , df=64
# parameter F test:         F=0.8052  , p=0.8667  , df_denom=2347, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=0.7938  , p=0.8841  , df_denom=2344, df_num=65
# ssr based chi2 test:   chi2=54.4790 , p=0.8208  , df=65
# likelihood ratio test: chi2=53.8881 , p=0.8357  , df=65
# parameter F test:         F=0.7938  , p=0.8841  , df_denom=2344, df_num=65
#
# Granger Causality
# number of lags (no zero) 66
# ssr based F test:         F=0.7834  , p=0.8988  , df_denom=2341, df_num=66
# ssr based chi2 test:   chi2=54.6427 , p=0.8396  , df=66
# likelihood ratio test: chi2=54.0480 , p=0.8535  , df=66
# parameter F test:         F=0.7834  , p=0.8988  , df_denom=2341, df_num=66
#
# Granger Causality
# number of lags (no zero) 67
# ssr based F test:         F=0.7709  , p=0.9146  , df_denom=2338, df_num=67
# ssr based chi2 test:   chi2=54.6347 , p=0.8607  , df=67
# likelihood ratio test: chi2=54.0399 , p=0.8734  , df=67
# parameter F test:         F=0.7709  , p=0.9146  , df_denom=2338, df_num=67
#
# Granger Causality
# number of lags (no zero) 68
# ssr based F test:         F=0.7862  , p=0.8991  , df_denom=2335, df_num=68
# ssr based chi2 test:   chi2=56.5972 , p=0.8366  , df=68
# likelihood ratio test: chi2=55.9590 , p=0.8514  , df=68
# parameter F test:         F=0.7862  , p=0.8991  , df_denom=2335, df_num=68
#
# Granger Causality
# number of lags (no zero) 69
# ssr based F test:         F=0.8277  , p=0.8433  , df_denom=2332, df_num=69
# ssr based chi2 test:   chi2=60.5118 , p=0.7571  , df=69
# likelihood ratio test: chi2=59.7828 , p=0.7779  , df=69
# parameter F test:         F=0.8277  , p=0.8433  , df_denom=2332, df_num=69
#
# Granger Causality
# number of lags (no zero) 70
# ssr based F test:         F=0.8292  , p=0.8427  , df_denom=2329, df_num=70
# ssr based chi2 test:   chi2=61.5603 , p=0.7540  , df=70
# likelihood ratio test: chi2=60.8056 , p=0.7755  , df=70
# parameter F test:         F=0.8292  , p=0.8427  , df_denom=2329, df_num=70
#
# Granger Causality
# number of lags (no zero) 71
# ssr based F test:         F=0.8405  , p=0.8259  , df_denom=2326, df_num=71
# ssr based chi2 test:   chi2=63.3467 , p=0.7292  , df=71
# likelihood ratio test: chi2=62.5477 , p=0.7527  , df=71
# parameter F test:         F=0.8405  , p=0.8259  , df_denom=2326, df_num=71
#
# Granger Causality
# number of lags (no zero) 72
# ssr based F test:         F=0.8128  , p=0.8711  , df_denom=2323, df_num=72
# ssr based chi2 test:   chi2=62.1779 , p=0.7889  , df=72
# likelihood ratio test: chi2=61.4076 , p=0.8089  , df=72
# parameter F test:         F=0.8128  , p=0.8711  , df_denom=2323, df_num=72
#
# Granger Causality
# number of lags (no zero) 73
# ssr based F test:         F=0.8205  , p=0.8616  , df_denom=2320, df_num=73
# ssr based chi2 test:   chi2=63.6944 , p=0.7733  , df=73
# likelihood ratio test: chi2=62.8860 , p=0.7948  , df=73
# parameter F test:         F=0.8205  , p=0.8616  , df_denom=2320, df_num=73
#
# Granger Causality
# number of lags (no zero) 74
# ssr based F test:         F=0.8136  , p=0.8735  , df_denom=2317, df_num=74
# ssr based chi2 test:   chi2=64.0781 , p=0.7881  , df=74
# likelihood ratio test: chi2=63.2597 , p=0.8090  , df=74
# parameter F test:         F=0.8136  , p=0.8735  , df_denom=2317, df_num=74
#
# Granger Causality
# number of lags (no zero) 75
# ssr based F test:         F=0.8220  , p=0.8628  , df_denom=2314, df_num=75
# ssr based chi2 test:   chi2=65.6740 , p=0.7705  , df=75
# likelihood ratio test: chi2=64.8143 , p=0.7932  , df=75
# parameter F test:         F=0.8220  , p=0.8628  , df_denom=2314, df_num=75
#
# Granger Causality
# number of lags (no zero) 76
# ssr based F test:         F=0.8322  , p=0.8486  , df_denom=2311, df_num=76
# ssr based chi2 test:   chi2=67.4370 , p=0.7479  , df=76
# likelihood ratio test: chi2=66.5307 , p=0.7727  , df=76
# parameter F test:         F=0.8322  , p=0.8486  , df_denom=2311, df_num=76
#
# Granger Causality
# number of lags (no zero) 77
# ssr based F test:         F=0.8179  , p=0.8723  , df_denom=2308, df_num=77
# ssr based chi2 test:   chi2=67.2103 , p=0.7796  , df=77
# likelihood ratio test: chi2=66.3096 , p=0.8025  , df=77
# parameter F test:         F=0.8179  , p=0.8723  , df_denom=2308, df_num=77
#
# Granger Causality
# number of lags (no zero) 78
# ssr based F test:         F=0.8014  , p=0.8966  , df_denom=2305, df_num=78
# ssr based chi2 test:   chi2=66.7643 , p=0.8140  , df=78
# likelihood ratio test: chi2=65.8751 , p=0.8345  , df=78
# parameter F test:         F=0.8014  , p=0.8966  , df_denom=2305, df_num=78
#
# Granger Causality
# number of lags (no zero) 79
# ssr based F test:         F=0.7978  , p=0.9027  , df_denom=2302, df_num=79
# ssr based chi2 test:   chi2=67.3781 , p=0.8213  , df=79
# likelihood ratio test: chi2=66.4722 , p=0.8416  , df=79
# parameter F test:         F=0.7978  , p=0.9027  , df_denom=2302, df_num=79
#
# Granger Causality
# number of lags (no zero) 80
# ssr based F test:         F=0.8135  , p=0.8834  , df_denom=2299, df_num=80
# ssr based chi2 test:   chi2=69.6380 , p=0.7894  , df=80
# likelihood ratio test: chi2=68.6705 , p=0.8129  , df=80
# parameter F test:         F=0.8135  , p=0.8834  , df_denom=2299, df_num=80
#
# Granger Causality
# number of lags (no zero) 81
# ssr based F test:         F=0.8302  , p=0.8601  , df_denom=2296, df_num=81
# ssr based chi2 test:   chi2=72.0163 , p=0.7520  , df=81
# likelihood ratio test: chi2=70.9819 , p=0.7791  , df=81
# parameter F test:         F=0.8302  , p=0.8601  , df_denom=2296, df_num=81
#
# Granger Causality
# number of lags (no zero) 82
# ssr based F test:         F=0.8269  , p=0.8668  , df_denom=2293, df_num=82
# ssr based chi2 test:   chi2=72.6819 , p=0.7595  , df=82
# likelihood ratio test: chi2=71.6280 , p=0.7865  , df=82
# parameter F test:         F=0.8269  , p=0.8668  , df_denom=2293, df_num=82
#
# Granger Causality
# number of lags (no zero) 83
# ssr based F test:         F=0.8312  , p=0.8616  , df_denom=2290, df_num=83
# ssr based chi2 test:   chi2=74.0182 , p=0.7491  , df=83
# likelihood ratio test: chi2=72.9252 , p=0.7775  , df=83
# parameter F test:         F=0.8312  , p=0.8616  , df_denom=2290, df_num=83
#
# Granger Causality
# number of lags (no zero) 84
# ssr based F test:         F=0.8369  , p=0.8538  , df_denom=2287, df_num=84
# ssr based chi2 test:   chi2=75.4979 , p=0.7349  , df=84
# likelihood ratio test: chi2=74.3608 , p=0.7649  , df=84
# parameter F test:         F=0.8369  , p=0.8538  , df_denom=2287, df_num=84
#
# Granger Causality
# number of lags (no zero) 85
# ssr based F test:         F=0.8265  , p=0.8719  , df_denom=2284, df_num=85
# ssr based chi2 test:   chi2=75.5139 , p=0.7596  , df=85
# likelihood ratio test: chi2=74.3758 , p=0.7881  , df=85
# parameter F test:         F=0.8265  , p=0.8719  , df_denom=2284, df_num=85
#
# Granger Causality
# number of lags (no zero) 86
# ssr based F test:         F=0.8584  , p=0.8189  , df_denom=2281, df_num=86
# ssr based chi2 test:   chi2=79.4226 , p=0.6786  , df=86
# likelihood ratio test: chi2=78.1645 , p=0.7141  , df=86
# parameter F test:         F=0.8584  , p=0.8189  , df_denom=2281, df_num=86
#
# Granger Causality
# number of lags (no zero) 87
# ssr based F test:         F=0.8679  , p=0.8021  , df_denom=2278, df_num=87
# ssr based chi2 test:   chi2=81.3060 , p=0.6520  , df=87
# likelihood ratio test: chi2=79.9876 , p=0.6899  , df=87
# parameter F test:         F=0.8679  , p=0.8021  , df_denom=2278, df_num=87
#
# Granger Causality
# number of lags (no zero) 88
# ssr based F test:         F=0.8718  , p=0.7956  , df_denom=2275, df_num=88
# ssr based chi2 test:   chi2=82.6898 , p=0.6399  , df=88
# likelihood ratio test: chi2=81.3261 , p=0.6793  , df=88
# parameter F test:         F=0.8718  , p=0.7956  , df_denom=2275, df_num=88
#
# Granger Causality
# number of lags (no zero) 89
# ssr based F test:         F=0.8635  , p=0.8137  , df_denom=2272, df_num=89
# ssr based chi2 test:   chi2=82.9035 , p=0.6619  , df=89
# likelihood ratio test: chi2=81.5322 , p=0.7005  , df=89
# parameter F test:         F=0.8635  , p=0.8137  , df_denom=2272, df_num=89
#
# Granger Causality
# number of lags (no zero) 90
# ssr based F test:         F=0.8787  , p=0.7842  , df_denom=2269, df_num=90
# ssr based chi2 test:   chi2=85.3932 , p=0.6177  , df=90
# likelihood ratio test: chi2=83.9388 , p=0.6600  , df=90
# parameter F test:         F=0.8787  , p=0.7842  , df_denom=2269, df_num=90
#
# Granger Causality
# number of lags (no zero) 91
# ssr based F test:         F=0.8905  , p=0.7601  , df_denom=2266, df_num=91
# ssr based chi2 test:   chi2=87.5786 , p=0.5821  , df=91
# likelihood ratio test: chi2=86.0490 , p=0.6271  , df=91
# parameter F test:         F=0.8905  , p=0.7601  , df_denom=2266, df_num=91
#
# Granger Causality
# number of lags (no zero) 92
# ssr based F test:         F=0.8809  , p=0.7824  , df_denom=2263, df_num=92
# ssr based chi2 test:   chi2=87.6672 , p=0.6084  , df=92
# likelihood ratio test: chi2=86.1339 , p=0.6527  , df=92
# parameter F test:         F=0.8809  , p=0.7824  , df_denom=2263, df_num=92
#
# Granger Causality
# number of lags (no zero) 93
# ssr based F test:         F=0.8860  , p=0.7726  , df_denom=2260, df_num=93
# ssr based chi2 test:   chi2=89.2173 , p=0.5918  , df=93
# likelihood ratio test: chi2=87.6293 , p=0.6378  , df=93
# parameter F test:         F=0.8860  , p=0.7726  , df_denom=2260, df_num=93
#
# Granger Causality
# number of lags (no zero) 94
# ssr based F test:         F=0.8638  , p=0.8200  , df_denom=2257, df_num=94
# ssr based chi2 test:   chi2=87.9980 , p=0.6549  , df=94
# likelihood ratio test: chi2=86.4521 , p=0.6974  , df=94
# parameter F test:         F=0.8638  , p=0.8200  , df_denom=2257, df_num=94
#
# Granger Causality
# number of lags (no zero) 95
# ssr based F test:         F=0.8551  , p=0.8380  , df_denom=2254, df_num=95
# ssr based chi2 test:   chi2=88.1131 , p=0.6785  , df=95
# likelihood ratio test: chi2=86.5626 , p=0.7199  , df=95
# parameter F test:         F=0.8551  , p=0.8380  , df_denom=2254, df_num=95
#
# Granger Causality
# number of lags (no zero) 96
# ssr based F test:         F=0.8473  , p=0.8532  , df_denom=2251, df_num=96
# ssr based chi2 test:   chi2=88.3168 , p=0.6990  , df=96
# likelihood ratio test: chi2=86.7586 , p=0.7393  , df=96
# parameter F test:         F=0.8473  , p=0.8532  , df_denom=2251, df_num=96
#
# Granger Causality
# number of lags (no zero) 97
# ssr based F test:         F=0.8383  , p=0.8698  , df_denom=2248, df_num=97
# ssr based chi2 test:   chi2=88.3691 , p=0.7227  , df=97
# likelihood ratio test: chi2=86.8084 , p=0.7614  , df=97
# parameter F test:         F=0.8383  , p=0.8698  , df_denom=2248, df_num=97
#
# Granger Causality
# number of lags (no zero) 98
# ssr based F test:         F=0.8501  , p=0.8509  , df_denom=2245, df_num=98
# ssr based chi2 test:   chi2=90.6206 , p=0.6890  , df=98
# likelihood ratio test: chi2=88.9797 , p=0.7314  , df=98
# parameter F test:         F=0.8501  , p=0.8509  , df_denom=2245, df_num=98
#
# Granger Causality
# number of lags (no zero) 99
# ssr based F test:         F=0.8370  , p=0.8744  , df_denom=2242, df_num=99
# ssr based chi2 test:   chi2=90.2148 , p=0.7244  , df=99
# likelihood ratio test: chi2=88.5877 , p=0.7642  , df=99
# parameter F test:         F=0.8370  , p=0.8744  , df_denom=2242, df_num=99
#
# Granger Causality
# number of lags (no zero) 100
# ssr based F test:         F=0.8304  , p=0.8860  , df_denom=2239, df_num=100
# ssr based chi2 test:   chi2=90.4899 , p=0.7413  , df=100
# likelihood ratio test: chi2=88.8523 , p=0.7799  , df=100
# parameter F test:         F=0.8304  , p=0.8860  , df_denom=2239, df_num=100

# %%
def find_lags(test):
    lag_found = False
    lags = []
    
    for i in range(1, maxlag):
        p = test[i][0]['ssr_ftest'][1]
        if (p < 0.05):
            lags.append(test[i][0]['ssr_ftest'])
            lag_found = True

    if (lag_found == True):
        return lags
    else:
        print("lag not found")

# %%
lags_info = find_lags(test)
# Out:
# lag not found

# %%
lags_info

# %% [markdown]
# # Granger Tests - GCTAY

# %%
maxlag = 100
ticker = 'GCTAY'
series = 'daily_tweets'

# %%
input_data = np.asarray(gctay[['closing_price', series]])
test = grangercausalitytests(input_data, maxlag, addconst = True, verbose=True);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2861  , p=0.2569  , df_denom=2547, df_num=1
# ssr based chi2 test:   chi2=1.2876  , p=0.2565  , df=1
# likelihood ratio test: chi2=1.2872  , p=0.2566  , df=1
# parameter F test:         F=1.2861  , p=0.2569  , df_denom=2547, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7837  , p=0.4568  , df_denom=2544, df_num=2
# ssr based chi2 test:   chi2=1.5706  , p=0.4560  , df=2
# likelihood ratio test: chi2=1.5701  , p=0.4561  , df=2
# parameter F test:         F=0.7837  , p=0.4568  , df_denom=2544, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7455  , p=0.5249  , df_denom=2541, df_num=3
# ssr based chi2 test:   chi2=2.2427  , p=0.5236  , df=3
# likelihood ratio test: chi2=2.2417  , p=0.5238  , df=3
# parameter F test:         F=0.7455  , p=0.5249  , df_denom=2541, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7322  , p=0.5699  , df_denom=2538, df_num=4
# ssr based chi2 test:   chi2=2.9392  , p=0.5680  , df=4
# likelihood ratio test: chi2=2.9375  , p=0.5683  , df=4
# parameter F test:         F=0.7322  , p=0.5699  , df_denom=2538, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2179  , p=0.0067  , df_denom=2535, df_num=5
# ssr based chi2 test:   chi2=16.1594 , p=0.0064  , df=5
# likelihood ratio test: chi2=16.1084 , p=0.0065  , df=5
# parameter F test:         F=3.2179  , p=0.0067  , df_denom=2535, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.8065  , p=0.0101  , df_denom=2532, df_num=6
# ssr based chi2 test:   chi2=16.9252 , p=0.0096  , df=6
# likelihood ratio test: chi2=16.8692 , p=0.0098  , df=6
# parameter F test:         F=2.8065  , p=0.0101  , df_denom=2532, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.0244  , p=0.0036  , df_denom=2529, df_num=7
# ssr based chi2 test:   chi2=21.2964 , p=0.0034  , df=7
# likelihood ratio test: chi2=21.2077 , p=0.0035  , df=7
# parameter F test:         F=3.0244  , p=0.0036  , df_denom=2529, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.7490  , p=0.0051  , df_denom=2526, df_num=8
# ssr based chi2 test:   chi2=22.1399 , p=0.0047  , df=8
# likelihood ratio test: chi2=22.0440 , p=0.0048  , df=8
# parameter F test:         F=2.7490  , p=0.0051  , df_denom=2526, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7711  , p=0.0031  , df_denom=2523, df_num=9
# ssr based chi2 test:   chi2=25.1274 , p=0.0028  , df=9
# likelihood ratio test: chi2=25.0040 , p=0.0030  , df=9
# parameter F test:         F=2.7711  , p=0.0031  , df_denom=2523, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.5495  , p=0.0046  , df_denom=2520, df_num=10
# ssr based chi2 test:   chi2=25.7078 , p=0.0042  , df=10
# likelihood ratio test: chi2=25.5786 , p=0.0044  , df=10
# parameter F test:         F=2.5495  , p=0.0046  , df_denom=2520, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.2448  , p=0.0104  , df_denom=2517, df_num=11
# ssr based chi2 test:   chi2=24.9183 , p=0.0094  , df=11
# likelihood ratio test: chi2=24.7969 , p=0.0098  , df=11
# parameter F test:         F=2.2448  , p=0.0104  , df_denom=2517, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.0828  , p=0.0152  , df_denom=2514, df_num=12
# ssr based chi2 test:   chi2=25.2415 , p=0.0137  , df=12
# likelihood ratio test: chi2=25.1169 , p=0.0143  , df=12
# parameter F test:         F=2.0828  , p=0.0152  , df_denom=2514, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.9525  , p=0.0210  , df_denom=2511, df_num=13
# ssr based chi2 test:   chi2=25.6559 , p=0.0189  , df=13
# likelihood ratio test: chi2=25.5271 , p=0.0197  , df=13
# parameter F test:         F=1.9525  , p=0.0210  , df_denom=2511, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.8537  , p=0.0268  , df_denom=2508, df_num=14
# ssr based chi2 test:   chi2=26.2524 , p=0.0240  , df=14
# likelihood ratio test: chi2=26.1175 , p=0.0250  , df=14
# parameter F test:         F=1.8537  , p=0.0268  , df_denom=2508, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.8201  , p=0.0270  , df_denom=2505, df_num=15
# ssr based chi2 test:   chi2=27.6387 , p=0.0239  , df=15
# likelihood ratio test: chi2=27.4892 , p=0.0250  , df=15
# parameter F test:         F=1.8201  , p=0.0270  , df_denom=2505, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.8640  , p=0.0194  , df_denom=2502, df_num=16
# ssr based chi2 test:   chi2=30.2177 , p=0.0169  , df=16
# likelihood ratio test: chi2=30.0391 , p=0.0178  , df=16
# parameter F test:         F=1.8640  , p=0.0194  , df_denom=2502, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.7400  , p=0.0302  , df_denom=2499, df_num=17
# ssr based chi2 test:   chi2=29.9936 , p=0.0264  , df=17
# likelihood ratio test: chi2=29.8174 , p=0.0277  , df=17
# parameter F test:         F=1.7400  , p=0.0302  , df_denom=2499, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.8182  , p=0.0186  , df_denom=2496, df_num=18
# ssr based chi2 test:   chi2=33.2120 , p=0.0157  , df=18
# likelihood ratio test: chi2=32.9962 , p=0.0167  , df=18
# parameter F test:         F=1.8182  , p=0.0186  , df_denom=2496, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.7782  , p=0.0201  , df_denom=2493, df_num=19
# ssr based chi2 test:   chi2=34.3135 , p=0.0169  , df=19
# likelihood ratio test: chi2=34.0831 , p=0.0180  , df=19
# parameter F test:         F=1.7782  , p=0.0201  , df_denom=2493, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.7902  , p=0.0168  , df_denom=2490, df_num=20
# ssr based chi2 test:   chi2=36.3936 , p=0.0138  , df=20
# likelihood ratio test: chi2=36.1344 , p=0.0148  , df=20
# parameter F test:         F=1.7902  , p=0.0168  , df_denom=2490, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.7717  , p=0.0165  , df_denom=2487, df_num=21
# ssr based chi2 test:   chi2=37.8496 , p=0.0134  , df=21
# likelihood ratio test: chi2=37.5693 , p=0.0145  , df=21
# parameter F test:         F=1.7717  , p=0.0165  , df_denom=2487, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.6621  , p=0.0272  , df_denom=2484, df_num=22
# ssr based chi2 test:   chi2=37.2278 , p=0.0223  , df=22
# likelihood ratio test: chi2=36.9565 , p=0.0239  , df=22
# parameter F test:         F=1.6621  , p=0.0272  , df_denom=2484, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.6669  , p=0.0242  , df_denom=2481, df_num=23
# ssr based chi2 test:   chi2=39.0648 , p=0.0195  , df=23
# likelihood ratio test: chi2=38.7660 , p=0.0210  , df=23
# parameter F test:         F=1.6669  , p=0.0242  , df_denom=2481, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.5332  , p=0.0470  , df_denom=2478, df_num=24
# ssr based chi2 test:   chi2=37.5233 , p=0.0388  , df=24
# likelihood ratio test: chi2=37.2474 , p=0.0413  , df=24
# parameter F test:         F=1.5332  , p=0.0470  , df_denom=2478, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.6032  , p=0.0296  , df_denom=2475, df_num=25
# ssr based chi2 test:   chi2=40.9070 , p=0.0235  , df=25
# likelihood ratio test: chi2=40.5793 , p=0.0254  , df=25
# parameter F test:         F=1.6032  , p=0.0296  , df_denom=2475, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.5508  , p=0.0374  , df_denom=2472, df_num=26
# ssr based chi2 test:   chi2=41.1854 , p=0.0297  , df=26
# likelihood ratio test: chi2=40.8531 , p=0.0321  , df=26
# parameter F test:         F=1.5508  , p=0.0374  , df_denom=2472, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.5495  , p=0.0353  , df_denom=2469, df_num=27
# ssr based chi2 test:   chi2=42.7677 , p=0.0276  , df=27
# likelihood ratio test: chi2=42.4094 , p=0.0300  , df=27
# parameter F test:         F=1.5495  , p=0.0353  , df_denom=2469, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.4918  , p=0.0469  , df_denom=2466, df_num=28
# ssr based chi2 test:   chi2=42.7358 , p=0.0369  , df=28
# likelihood ratio test: chi2=42.3778 , p=0.0399  , df=28
# parameter F test:         F=1.4918  , p=0.0469  , df_denom=2466, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.4397  , p=0.0606  , df_denom=2463, df_num=29
# ssr based chi2 test:   chi2=42.7512 , p=0.0480  , df=29
# likelihood ratio test: chi2=42.3929 , p=0.0518  , df=29
# parameter F test:         F=1.4397  , p=0.0606  , df_denom=2463, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.5151  , p=0.0362  , df_denom=2460, df_num=30
# ssr based chi2 test:   chi2=46.5800 , p=0.0273  , df=30
# likelihood ratio test: chi2=46.1549 , p=0.0300  , df=30
# parameter F test:         F=1.5151  , p=0.0362  , df_denom=2460, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.4799  , p=0.0429  , df_denom=2457, df_num=31
# ssr based chi2 test:   chi2=47.0547 , p=0.0323  , df=31
# likelihood ratio test: chi2=46.6208 , p=0.0355  , df=31
# parameter F test:         F=1.4799  , p=0.0429  , df_denom=2457, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.5779  , p=0.0209  , df_denom=2454, df_num=32
# ssr based chi2 test:   chi2=51.8291 , p=0.0147  , df=32
# likelihood ratio test: chi2=51.3031 , p=0.0166  , df=32
# parameter F test:         F=1.5779  , p=0.0209  , df_denom=2454, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.5247  , p=0.0285  , df_denom=2451, df_num=33
# ssr based chi2 test:   chi2=51.6906 , p=0.0202  , df=33
# likelihood ratio test: chi2=51.1672 , p=0.0227  , df=33
# parameter F test:         F=1.5247  , p=0.0285  , df_denom=2451, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.6168  , p=0.0136  , df_denom=2448, df_num=34
# ssr based chi2 test:   chi2=56.5220 , p=0.0090  , df=34
# likelihood ratio test: chi2=55.8968 , p=0.0104  , df=34
# parameter F test:         F=1.6168  , p=0.0136  , df_denom=2448, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.6959  , p=0.0067  , df_denom=2445, df_num=35
# ssr based chi2 test:   chi2=61.0787 , p=0.0041  , df=35
# likelihood ratio test: chi2=60.3491 , p=0.0049  , df=35
# parameter F test:         F=1.6959  , p=0.0067  , df_denom=2445, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.6629  , p=0.0081  , df_denom=2442, df_num=36
# ssr based chi2 test:   chi2=61.6526 , p=0.0049  , df=36
# likelihood ratio test: chi2=60.9090 , p=0.0059  , df=36
# parameter F test:         F=1.6629  , p=0.0081  , df_denom=2442, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.6594  , p=0.0076  , df_denom=2439, df_num=37
# ssr based chi2 test:   chi2=63.2843 , p=0.0045  , df=37
# likelihood ratio test: chi2=62.5009 , p=0.0055  , df=37
# parameter F test:         F=1.6594  , p=0.0076  , df_denom=2439, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.6513  , p=0.0075  , df_denom=2436, df_num=38
# ssr based chi2 test:   chi2=64.7340 , p=0.0044  , df=38
# likelihood ratio test: chi2=63.9143 , p=0.0053  , df=38
# parameter F test:         F=1.6513  , p=0.0075  , df_denom=2436, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.6578  , p=0.0066  , df_denom=2433, df_num=39
# ssr based chi2 test:   chi2=66.7552 , p=0.0037  , df=39
# likelihood ratio test: chi2=65.8837 , p=0.0045  , df=39
# parameter F test:         F=1.6578  , p=0.0066  , df_denom=2433, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.6217  , p=0.0083  , df_denom=2430, df_num=40
# ssr based chi2 test:   chi2=67.0313 , p=0.0047  , df=40
# likelihood ratio test: chi2=66.1522 , p=0.0058  , df=40
# parameter F test:         F=1.6217  , p=0.0083  , df_denom=2430, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.5831  , p=0.0109  , df_denom=2427, df_num=41
# ssr based chi2 test:   chi2=67.1275 , p=0.0062  , df=41
# likelihood ratio test: chi2=66.2456 , p=0.0075  , df=41
# parameter F test:         F=1.5831  , p=0.0109  , df_denom=2427, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.5607  , p=0.0124  , df_denom=2424, df_num=42
# ssr based chi2 test:   chi2=67.8460 , p=0.0070  , df=42
# likelihood ratio test: chi2=66.9449 , p=0.0085  , df=42
# parameter F test:         F=1.5607  , p=0.0124  , df_denom=2424, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.5584  , p=0.0119  , df_denom=2421, df_num=43
# ssr based chi2 test:   chi2=69.4176 , p=0.0065  , df=43
# likelihood ratio test: chi2=68.4742 , p=0.0080  , df=43
# parameter F test:         F=1.5584  , p=0.0119  , df_denom=2421, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.5659  , p=0.0104  , df_denom=2418, df_num=44
# ssr based chi2 test:   chi2=71.4352 , p=0.0055  , df=44
# likelihood ratio test: chi2=70.4364 , p=0.0069  , df=44
# parameter F test:         F=1.5659  , p=0.0104  , df_denom=2418, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.5338  , p=0.0131  , df_denom=2415, df_num=45
# ssr based chi2 test:   chi2=71.6239 , p=0.0070  , df=45
# likelihood ratio test: chi2=70.6194 , p=0.0087  , df=45
# parameter F test:         F=1.5338  , p=0.0131  , df_denom=2415, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.5285  , p=0.0130  , df_denom=2412, df_num=46
# ssr based chi2 test:   chi2=73.0231 , p=0.0068  , df=46
# likelihood ratio test: chi2=71.9790 , p=0.0085  , df=46
# parameter F test:         F=1.5285  , p=0.0130  , df_denom=2412, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.6722  , p=0.0030  , df_denom=2409, df_num=47
# ssr based chi2 test:   chi2=81.6936 , p=0.0013  , df=47
# likelihood ratio test: chi2=80.3892 , p=0.0017  , df=47
# parameter F test:         F=1.6722  , p=0.0030  , df_denom=2409, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.7955  , p=0.0007  , df_denom=2406, df_num=48
# ssr based chi2 test:   chi2=89.6571 , p=0.0003  , df=48
# likelihood ratio test: chi2=88.0886 , p=0.0004  , df=48
# parameter F test:         F=1.7955  , p=0.0007  , df_denom=2406, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.8911  , p=0.0002  , df_denom=2403, df_num=49
# ssr based chi2 test:   chi2=96.4812 , p=0.0001  , df=49
# likelihood ratio test: chi2=94.6675 , p=0.0001  , df=49
# parameter F test:         F=1.8911  , p=0.0002  , df_denom=2403, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.8707  , p=0.0002  , df_denom=2400, df_num=50
# ssr based chi2 test:   chi2=97.4697 , p=0.0001  , df=50
# likelihood ratio test: chi2=95.6184 , p=0.0001  , df=50
# parameter F test:         F=1.8707  , p=0.0002  , df_denom=2400, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=1.8409  , p=0.0003  , df_denom=2397, df_num=51
# ssr based chi2 test:   chi2=97.9190 , p=0.0001  , df=51
# likelihood ratio test: chi2=96.0501 , p=0.0001  , df=51
# parameter F test:         F=1.8409  , p=0.0003  , df_denom=2397, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=1.8200  , p=0.0003  , df_denom=2394, df_num=52
# ssr based chi2 test:   chi2=98.7920 , p=0.0001  , df=52
# likelihood ratio test: chi2=96.8892 , p=0.0002  , df=52
# parameter F test:         F=1.8200  , p=0.0003  , df_denom=2394, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=1.8218  , p=0.0003  , df_denom=2391, df_num=53
# ssr based chi2 test:   chi2=100.8749, p=0.0001  , df=53
# likelihood ratio test: chi2=98.8913 , p=0.0001  , df=53
# parameter F test:         F=1.8218  , p=0.0003  , df_denom=2391, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=1.8069  , p=0.0003  , df_denom=2388, df_num=54
# ssr based chi2 test:   chi2=102.0255, p=0.0001  , df=54
# likelihood ratio test: chi2=99.9963 , p=0.0001  , df=54
# parameter F test:         F=1.8069  , p=0.0003  , df_denom=2388, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=1.7764  , p=0.0004  , df_denom=2385, df_num=55
# ssr based chi2 test:   chi2=102.2490, p=0.0001  , df=55
# likelihood ratio test: chi2=100.2102, p=0.0002  , df=55
# parameter F test:         F=1.7764  , p=0.0004  , df_denom=2385, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=1.7685  , p=0.0004  , df_denom=2382, df_num=56
# ssr based chi2 test:   chi2=103.7314, p=0.0001  , df=56
# likelihood ratio test: chi2=101.6330, p=0.0002  , df=56
# parameter F test:         F=1.7685  , p=0.0004  , df_denom=2382, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=1.7228  , p=0.0007  , df_denom=2379, df_num=57
# ssr based chi2 test:   chi2=102.9459, p=0.0002  , df=57
# likelihood ratio test: chi2=100.8779, p=0.0003  , df=57
# parameter F test:         F=1.7228  , p=0.0007  , df_denom=2379, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=1.6928  , p=0.0009  , df_denom=2376, df_num=58
# ssr based chi2 test:   chi2=103.0186, p=0.0003  , df=58
# likelihood ratio test: chi2=100.9470, p=0.0004  , df=58
# parameter F test:         F=1.6928  , p=0.0009  , df_denom=2376, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=1.6714  , p=0.0011  , df_denom=2373, df_num=59
# ssr based chi2 test:   chi2=103.5547, p=0.0003  , df=59
# likelihood ratio test: chi2=101.4609, p=0.0005  , df=59
# parameter F test:         F=1.6714  , p=0.0011  , df_denom=2373, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=1.6714  , p=0.0010  , df_denom=2370, df_num=60
# ssr based chi2 test:   chi2=105.4011, p=0.0003  , df=60
# likelihood ratio test: chi2=103.2322, p=0.0004  , df=60
# parameter F test:         F=1.6714  , p=0.0010  , df_denom=2370, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=1.6589  , p=0.0011  , df_denom=2367, df_num=61
# ssr based chi2 test:   chi2=106.4543, p=0.0003  , df=61
# likelihood ratio test: chi2=104.2415, p=0.0005  , df=61
# parameter F test:         F=1.6589  , p=0.0011  , df_denom=2367, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=1.6365  , p=0.0014  , df_denom=2364, df_num=62
# ssr based chi2 test:   chi2=106.8270, p=0.0004  , df=62
# likelihood ratio test: chi2=104.5981, p=0.0006  , df=62
# parameter F test:         F=1.6365  , p=0.0014  , df_denom=2364, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=1.5925  , p=0.0023  , df_denom=2361, df_num=63
# ssr based chi2 test:   chi2=105.7255, p=0.0006  , df=63
# likelihood ratio test: chi2=103.5408, p=0.0010  , df=63
# parameter F test:         F=1.5925  , p=0.0023  , df_denom=2361, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=1.5557  , p=0.0034  , df_denom=2358, df_num=64
# ssr based chi2 test:   chi2=105.0137, p=0.0009  , df=64
# likelihood ratio test: chi2=102.8571, p=0.0015  , df=64
# parameter F test:         F=1.5557  , p=0.0034  , df_denom=2358, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=1.5336  , p=0.0043  , df_denom=2355, df_num=65
# ssr based chi2 test:   chi2=105.2281, p=0.0012  , df=65
# likelihood ratio test: chi2=103.0619, p=0.0019  , df=65
# parameter F test:         F=1.5336  , p=0.0043  , df_denom=2355, df_num=65
#
# Granger Causality
# number of lags (no zero) 66
# ssr based F test:         F=1.5851  , p=0.0021  , df_denom=2352, df_num=66
# ssr based chi2 test:   chi2=110.5323, p=0.0005  , df=66
# likelihood ratio test: chi2=108.1446, p=0.0008  , df=66
# parameter F test:         F=1.5851  , p=0.0021  , df_denom=2352, df_num=66
#
# Granger Causality
# number of lags (no zero) 67
# ssr based F test:         F=1.5715  , p=0.0023  , df_denom=2349, df_num=67
# ssr based chi2 test:   chi2=111.3427, p=0.0005  , df=67
# likelihood ratio test: chi2=108.9194, p=0.0009  , df=67
# parameter F test:         F=1.5715  , p=0.0023  , df_denom=2349, df_num=67
#
# Granger Causality
# number of lags (no zero) 68
# ssr based F test:         F=1.5733  , p=0.0022  , df_denom=2346, df_num=68
# ssr based chi2 test:   chi2=113.2341, p=0.0005  , df=68
# likelihood ratio test: chi2=110.7281, p=0.0008  , df=68
# parameter F test:         F=1.5733  , p=0.0022  , df_denom=2346, df_num=68
#
# Granger Causality
# number of lags (no zero) 69
# ssr based F test:         F=1.5550  , p=0.0026  , df_denom=2343, df_num=69
# ssr based chi2 test:   chi2=113.6633, p=0.0006  , df=69
# likelihood ratio test: chi2=111.1376, p=0.0010  , df=69
# parameter F test:         F=1.5550  , p=0.0026  , df_denom=2343, df_num=69
#
# Granger Causality
# number of lags (no zero) 70
# ssr based F test:         F=1.5886  , p=0.0015  , df_denom=2340, df_num=70
# ssr based chi2 test:   chi2=117.9040, p=0.0003  , df=70
# likelihood ratio test: chi2=115.1882, p=0.0005  , df=70
# parameter F test:         F=1.5886  , p=0.0015  , df_denom=2340, df_num=70
#
# Granger Causality
# number of lags (no zero) 71
# ssr based F test:         F=1.5827  , p=0.0016  , df_denom=2337, df_num=71
# ssr based chi2 test:   chi2=119.2442, p=0.0003  , df=71
# likelihood ratio test: chi2=116.4662, p=0.0005  , df=71
# parameter F test:         F=1.5827  , p=0.0016  , df_denom=2337, df_num=71
#
# Granger Causality
# number of lags (no zero) 72
# ssr based F test:         F=1.5444  , p=0.0025  , df_denom=2334, df_num=72
# ssr based chi2 test:   chi2=118.1038, p=0.0005  , df=72
# likelihood ratio test: chi2=115.3767, p=0.0009  , df=72
# parameter F test:         F=1.5444  , p=0.0025  , df_denom=2334, df_num=72
#
# Granger Causality
# number of lags (no zero) 73
# ssr based F test:         F=1.5508  , p=0.0022  , df_denom=2331, df_num=73
# ssr based chi2 test:   chi2=120.3464, p=0.0004  , df=73
# likelihood ratio test: chi2=117.5154, p=0.0007  , df=73
# parameter F test:         F=1.5508  , p=0.0022  , df_denom=2331, df_num=73
#
# Granger Causality
# number of lags (no zero) 74
# ssr based F test:         F=1.5247  , p=0.0030  , df_denom=2328, df_num=74
# ssr based chi2 test:   chi2=120.0516, p=0.0006  , df=74
# likelihood ratio test: chi2=117.2331, p=0.0010  , df=74
# parameter F test:         F=1.5247  , p=0.0030  , df_denom=2328, df_num=74
#
# Granger Causality
# number of lags (no zero) 75
# ssr based F test:         F=1.5254  , p=0.0028  , df_denom=2325, df_num=75
# ssr based chi2 test:   chi2=121.8382, p=0.0005  , df=75
# likelihood ratio test: chi2=118.9354, p=0.0009  , df=75
# parameter F test:         F=1.5254  , p=0.0028  , df_denom=2325, df_num=75
#
# Granger Causality
# number of lags (no zero) 76
# ssr based F test:         F=1.5468  , p=0.0019  , df_denom=2322, df_num=76
# ssr based chi2 test:   chi2=125.3045, p=0.0003  , df=76
# likelihood ratio test: chi2=122.2356, p=0.0006  , df=76
# parameter F test:         F=1.5468  , p=0.0019  , df_denom=2322, df_num=76
#
# Granger Causality
# number of lags (no zero) 77
# ssr based F test:         F=1.5399  , p=0.0020  , df_denom=2319, df_num=77
# ssr based chi2 test:   chi2=126.4945, p=0.0003  , df=77
# likelihood ratio test: chi2=123.3669, p=0.0006  , df=77
# parameter F test:         F=1.5399  , p=0.0020  , df_denom=2319, df_num=77
#
# Granger Causality
# number of lags (no zero) 78
# ssr based F test:         F=1.5877  , p=0.0009  , df_denom=2316, df_num=78
# ssr based chi2 test:   chi2=132.2328, p=0.0001  , df=78
# likelihood ratio test: chi2=128.8187, p=0.0003  , df=78
# parameter F test:         F=1.5877  , p=0.0009  , df_denom=2316, df_num=78
#
# Granger Causality
# number of lags (no zero) 79
# ssr based F test:         F=1.5727  , p=0.0011  , df_denom=2313, df_num=79
# ssr based chi2 test:   chi2=132.7864, p=0.0001  , df=79
# likelihood ratio test: chi2=129.3428, p=0.0003  , df=79
# parameter F test:         F=1.5727  , p=0.0011  , df_denom=2313, df_num=79
#
# Granger Causality
# number of lags (no zero) 80
# ssr based F test:         F=1.7547  , p=0.0001  , df_denom=2310, df_num=80
# ssr based chi2 test:   chi2=150.1637, p=0.0000  , df=80
# likelihood ratio test: chi2=145.7778, p=0.0000  , df=80
# parameter F test:         F=1.7547  , p=0.0001  , df_denom=2310, df_num=80
#
# Granger Causality
# number of lags (no zero) 81
# ssr based F test:         F=1.7391  , p=0.0001  , df_denom=2307, df_num=81
# ssr based chi2 test:   chi2=150.8168, p=0.0000  , df=81
# likelihood ratio test: chi2=146.3917, p=0.0000  , df=81
# parameter F test:         F=1.7391  , p=0.0001  , df_denom=2307, df_num=81
#
# Granger Causality
# number of lags (no zero) 82
# ssr based F test:         F=1.7674  , p=0.0000  , df_denom=2304, df_num=82
# ssr based chi2 test:   chi2=155.3030, p=0.0000  , df=82
# likelihood ratio test: chi2=150.6143, p=0.0000  , df=82
# parameter F test:         F=1.7674  , p=0.0000  , df_denom=2304, df_num=82
#
# Granger Causality
# number of lags (no zero) 83
# ssr based F test:         F=1.7464  , p=0.0000  , df_denom=2301, df_num=83
# ssr based chi2 test:   chi2=155.4748, p=0.0000  , df=83
# likelihood ratio test: chi2=150.7741, p=0.0000  , df=83
# parameter F test:         F=1.7464  , p=0.0000  , df_denom=2301, df_num=83
#
# Granger Causality
# number of lags (no zero) 84
# ssr based F test:         F=1.7507  , p=0.0000  , df_denom=2298, df_num=84
# ssr based chi2 test:   chi2=157.8759, p=0.0000  , df=84
# likelihood ratio test: chi2=153.0300, p=0.0000  , df=84
# parameter F test:         F=1.7507  , p=0.0000  , df_denom=2298, df_num=84
#
# Granger Causality
# number of lags (no zero) 85
# ssr based F test:         F=1.7279  , p=0.0001  , df_denom=2295, df_num=85
# ssr based chi2 test:   chi2=157.8124, p=0.0000  , df=85
# likelihood ratio test: chi2=152.9684, p=0.0000  , df=85
# parameter F test:         F=1.7279  , p=0.0001  , df_denom=2295, df_num=85
#
# Granger Causality
# number of lags (no zero) 86
# ssr based F test:         F=1.7239  , p=0.0001  , df_denom=2292, df_num=86
# ssr based chi2 test:   chi2=159.4465, p=0.0000  , df=86
# likelihood ratio test: chi2=154.5018, p=0.0000  , df=86
# parameter F test:         F=1.7239  , p=0.0001  , df_denom=2292, df_num=86
#
# Granger Causality
# number of lags (no zero) 87
# ssr based F test:         F=1.7260  , p=0.0000  , df_denom=2289, df_num=87
# ssr based chi2 test:   chi2=161.6433, p=0.0000  , df=87
# likelihood ratio test: chi2=156.5623, p=0.0000  , df=87
# parameter F test:         F=1.7260  , p=0.0000  , df_denom=2289, df_num=87
#
# Granger Causality
# number of lags (no zero) 88
# ssr based F test:         F=1.8413  , p=0.0000  , df_denom=2286, df_num=88
# ssr based chi2 test:   chi2=174.5850, p=0.0000  , df=88
# likelihood ratio test: chi2=168.6751, p=0.0000  , df=88
# parameter F test:         F=1.8413  , p=0.0000  , df_denom=2286, df_num=88
#
# Granger Causality
# number of lags (no zero) 89
# ssr based F test:         F=1.8395  , p=0.0000  , df_denom=2283, df_num=89
# ssr based chi2 test:   chi2=176.5520, p=0.0000  , df=89
# likelihood ratio test: chi2=170.5089, p=0.0000  , df=89
# parameter F test:         F=1.8395  , p=0.0000  , df_denom=2283, df_num=89
#
# Granger Causality
# number of lags (no zero) 90
# ssr based F test:         F=1.8204  , p=0.0000  , df_denom=2280, df_num=90
# ssr based chi2 test:   chi2=176.8419, p=0.0000  , df=90
# likelihood ratio test: chi2=170.7770, p=0.0000  , df=90
# parameter F test:         F=1.8204  , p=0.0000  , df_denom=2280, df_num=90
#
# Granger Causality
# number of lags (no zero) 91
# ssr based F test:         F=1.8323  , p=0.0000  , df_denom=2277, df_num=91
# ssr based chi2 test:   chi2=180.1364, p=0.0000  , df=91
# likelihood ratio test: chi2=173.8463, p=0.0000  , df=91
# parameter F test:         F=1.8323  , p=0.0000  , df_denom=2277, df_num=91
#
# Granger Causality
# number of lags (no zero) 92
# ssr based F test:         F=1.8164  , p=0.0000  , df_denom=2274, df_num=92
# ssr based chi2 test:   chi2=180.7067, p=0.0000  , df=92
# likelihood ratio test: chi2=174.3751, p=0.0000  , df=92
# parameter F test:         F=1.8164  , p=0.0000  , df_denom=2274, df_num=92
#
# Granger Causality
# number of lags (no zero) 93
# ssr based F test:         F=1.8007  , p=0.0000  , df_denom=2271, df_num=93
# ssr based chi2 test:   chi2=181.2531, p=0.0000  , df=93
# likelihood ratio test: chi2=174.8817, p=0.0000  , df=93
# parameter F test:         F=1.8007  , p=0.0000  , df_denom=2271, df_num=93
#
# Granger Causality
# number of lags (no zero) 94
# ssr based F test:         F=1.7826  , p=0.0000  , df_denom=2268, df_num=94
# ssr based chi2 test:   chi2=181.5245, p=0.0000  , df=94
# likelihood ratio test: chi2=175.1319, p=0.0000  , df=94
# parameter F test:         F=1.7826  , p=0.0000  , df_denom=2268, df_num=94
#
# Granger Causality
# number of lags (no zero) 95
# ssr based F test:         F=1.7715  , p=0.0000  , df_denom=2265, df_num=95
# ssr based chi2 test:   chi2=182.4809, p=0.0000  , df=95
# likelihood ratio test: chi2=176.0198, p=0.0000  , df=95
# parameter F test:         F=1.7715  , p=0.0000  , df_denom=2265, df_num=95
#
# Granger Causality
# number of lags (no zero) 96
# ssr based F test:         F=1.7553  , p=0.0000  , df_denom=2262, df_num=96
# ssr based chi2 test:   chi2=182.8850, p=0.0000  , df=96
# likelihood ratio test: chi2=176.3935, p=0.0000  , df=96
# parameter F test:         F=1.7553  , p=0.0000  , df_denom=2262, df_num=96
#
# Granger Causality
# number of lags (no zero) 97
# ssr based F test:         F=1.7480  , p=0.0000  , df_denom=2259, df_num=97
# ssr based chi2 test:   chi2=184.1972, p=0.0000  , df=97
# likelihood ratio test: chi2=177.6118, p=0.0000  , df=97
# parameter F test:         F=1.7480  , p=0.0000  , df_denom=2259, df_num=97
#
# Granger Causality
# number of lags (no zero) 98
# ssr based F test:         F=1.7334  , p=0.0000  , df_denom=2256, df_num=98
# ssr based chi2 test:   chi2=184.7109, p=0.0000  , df=98
# likelihood ratio test: chi2=178.0871, p=0.0000  , df=98
# parameter F test:         F=1.7334  , p=0.0000  , df_denom=2256, df_num=98
#
# Granger Causality
# number of lags (no zero) 99
# ssr based F test:         F=1.7205  , p=0.0000  , df_denom=2253, df_num=99
# ssr based chi2 test:   chi2=185.3705, p=0.0000  , df=99
# likelihood ratio test: chi2=178.6978, p=0.0000  , df=99
# parameter F test:         F=1.7205  , p=0.0000  , df_denom=2253, df_num=99
#
# Granger Causality
# number of lags (no zero) 100
# ssr based F test:         F=1.7145  , p=0.0000  , df_denom=2250, df_num=100
# ssr based chi2 test:   chi2=186.7707, p=0.0000  , df=100
# likelihood ratio test: chi2=179.9966, p=0.0000  , df=100
# parameter F test:         F=1.7145  , p=0.0000  , df_denom=2250, df_num=100

# %%
def find_lags(test):
    lag_found = False
    lags = []
    
    for i in range(1, maxlag):
        p = test[i][0]['ssr_ftest'][1]
        if (p < 0.05):
            lags.append(test[i][0]['ssr_ftest'])
            lag_found = True

    if (lag_found == True):
        return lags
    else:
        print("lag not found")

# %%
lags_info = find_lags(test)

# %% [markdown]
# ###### lags_info

# %% [markdown]
# # Granger Tests - RUN

# %%
maxlag = 100
ticker = 'RUN'
series = 'daily_tweets'

# %%
input_data = np.asarray(run[['closing_price', series]])
test = grangercausalitytests(input_data, maxlag, addconst = True, verbose=True);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.0828  , p=0.0793  , df_denom=1407, df_num=1
# ssr based chi2 test:   chi2=3.0894  , p=0.0788  , df=1
# likelihood ratio test: chi2=3.0860  , p=0.0790  , df=1
# parameter F test:         F=3.0828  , p=0.0793  , df_denom=1407, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.6767  , p=0.0095  , df_denom=1404, df_num=2
# ssr based chi2 test:   chi2=9.3866  , p=0.0092  , df=2
# likelihood ratio test: chi2=9.3555  , p=0.0093  , df=2
# parameter F test:         F=4.6767  , p=0.0095  , df_denom=1404, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8605  , p=0.0091  , df_denom=1401, df_num=3
# ssr based chi2 test:   chi2=11.6394 , p=0.0087  , df=3
# likelihood ratio test: chi2=11.5916 , p=0.0089  , df=3
# parameter F test:         F=3.8605  , p=0.0091  , df_denom=1401, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.1958  , p=0.0126  , df_denom=1398, df_num=4
# ssr based chi2 test:   chi2=12.8656 , p=0.0120  , df=4
# likelihood ratio test: chi2=12.8071 , p=0.0123  , df=4
# parameter F test:         F=3.1958  , p=0.0126  , df_denom=1398, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2252  , p=0.0067  , df_denom=1395, df_num=5
# ssr based chi2 test:   chi2=16.2529 , p=0.0062  , df=5
# likelihood ratio test: chi2=16.1597 , p=0.0064  , df=5
# parameter F test:         F=3.2252  , p=0.0067  , df_denom=1395, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.8705  , p=0.0088  , df_denom=1392, df_num=6
# ssr based chi2 test:   chi2=17.3838 , p=0.0080  , df=6
# likelihood ratio test: chi2=17.2771 , p=0.0083  , df=6
# parameter F test:         F=2.8705  , p=0.0088  , df_denom=1392, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.6656  , p=0.0097  , df_denom=1389, df_num=7
# ssr based chi2 test:   chi2=18.8609 , p=0.0086  , df=7
# likelihood ratio test: chi2=18.7353 , p=0.0091  , df=7
# parameter F test:         F=2.6656  , p=0.0097  , df_denom=1389, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.5379  , p=0.0096  , df_denom=1386, df_num=8
# ssr based chi2 test:   chi2=20.5522 , p=0.0084  , df=8
# likelihood ratio test: chi2=20.4031 , p=0.0089  , df=8
# parameter F test:         F=2.5379  , p=0.0096  , df_denom=1386, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.2885  , p=0.0151  , df_denom=1383, df_num=9
# ssr based chi2 test:   chi2=20.8798 , p=0.0132  , df=9
# likelihood ratio test: chi2=20.7259 , p=0.0139  , df=9
# parameter F test:         F=2.2885  , p=0.0151  , df_denom=1383, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.1534  , p=0.0183  , df_denom=1380, df_num=10
# ssr based chi2 test:   chi2=21.8613 , p=0.0158  , df=10
# likelihood ratio test: chi2=21.6924 , p=0.0168  , df=10
# parameter F test:         F=2.1534  , p=0.0183  , df_denom=1380, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.9768  , p=0.0273  , df_denom=1377, df_num=11
# ssr based chi2 test:   chi2=22.1075 , p=0.0236  , df=11
# likelihood ratio test: chi2=21.9348 , p=0.0249  , df=11
# parameter F test:         F=1.9768  , p=0.0273  , df_denom=1377, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.9808  , p=0.0227  , df_denom=1374, df_num=12
# ssr based chi2 test:   chi2=24.2020 , p=0.0191  , df=12
# likelihood ratio test: chi2=23.9950 , p=0.0204  , df=12
# parameter F test:         F=1.9808  , p=0.0227  , df_denom=1374, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.7750  , p=0.0420  , df_denom=1371, df_num=13
# ssr based chi2 test:   chi2=23.5298 , p=0.0357  , df=13
# likelihood ratio test: chi2=23.3340 , p=0.0378  , df=13
# parameter F test:         F=1.7750  , p=0.0420  , df_denom=1371, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.7597  , p=0.0396  , df_denom=1368, df_num=14
# ssr based chi2 test:   chi2=25.1579 , p=0.0330  , df=14
# likelihood ratio test: chi2=24.9340 , p=0.0352  , df=14
# parameter F test:         F=1.7597  , p=0.0396  , df_denom=1368, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.1240  , p=0.0072  , df_denom=1365, df_num=15
# ssr based chi2 test:   chi2=32.5839 , p=0.0054  , df=15
# likelihood ratio test: chi2=32.2094 , p=0.0060  , df=15
# parameter F test:         F=2.1240  , p=0.0072  , df_denom=1365, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.2801  , p=0.0027  , df_denom=1362, df_num=16
# ssr based chi2 test:   chi2=37.3660 , p=0.0019  , df=16
# likelihood ratio test: chi2=36.8743 , p=0.0022  , df=16
# parameter F test:         F=2.2801  , p=0.0027  , df_denom=1362, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=2.0636  , p=0.0066  , df_denom=1359, df_num=17
# ssr based chi2 test:   chi2=35.9839 , p=0.0046  , df=17
# likelihood ratio test: chi2=35.5273 , p=0.0053  , df=17
# parameter F test:         F=2.0636  , p=0.0066  , df_denom=1359, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.9769  , p=0.0086  , df_denom=1356, df_num=18
# ssr based chi2 test:   chi2=36.5545 , p=0.0060  , df=18
# likelihood ratio test: chi2=36.0831 , p=0.0069  , df=18
# parameter F test:         F=1.9769  , p=0.0086  , df_denom=1356, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=2.0165  , p=0.0059  , df_denom=1353, df_num=19
# ssr based chi2 test:   chi2=39.4182 , p=0.0039  , df=19
# likelihood ratio test: chi2=38.8704 , p=0.0046  , df=19
# parameter F test:         F=2.0165  , p=0.0059  , df_denom=1353, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.8853  , p=0.0104  , df_denom=1350, df_num=20
# ssr based chi2 test:   chi2=38.8503 , p=0.0070  , df=20
# likelihood ratio test: chi2=38.3176 , p=0.0081  , df=20
# parameter F test:         F=1.8853  , p=0.0104  , df_denom=1350, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.7456  , p=0.0196  , df_denom=1347, df_num=21
# ssr based chi2 test:   chi2=37.8271 , p=0.0135  , df=21
# likelihood ratio test: chi2=37.3215 , p=0.0155  , df=21
# parameter F test:         F=1.7456  , p=0.0196  , df_denom=1347, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.6677  , p=0.0271  , df_denom=1344, df_num=22
# ssr based chi2 test:   chi2=37.9174 , p=0.0187  , df=22
# likelihood ratio test: chi2=37.4091 , p=0.0213  , df=22
# parameter F test:         F=1.6677  , p=0.0271  , df_denom=1344, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.6647  , p=0.0252  , df_denom=1341, df_num=23
# ssr based chi2 test:   chi2=39.6298 , p=0.0169  , df=23
# likelihood ratio test: chi2=39.0746 , p=0.0195  , df=23
# parameter F test:         F=1.6647  , p=0.0252  , df_denom=1341, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.6263  , p=0.0287  , df_denom=1338, df_num=24
# ssr based chi2 test:   chi2=40.4602 , p=0.0191  , df=24
# likelihood ratio test: chi2=39.8813 , p=0.0220  , df=24
# parameter F test:         F=1.6263  , p=0.0287  , df_denom=1338, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.5747  , p=0.0357  , df_denom=1335, df_num=25
# ssr based chi2 test:   chi2=40.8720 , p=0.0237  , df=25
# likelihood ratio test: chi2=40.2810 , p=0.0273  , df=25
# parameter F test:         F=1.5747  , p=0.0357  , df_denom=1335, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.8355  , p=0.0065  , df_denom=1332, df_num=26
# ssr based chi2 test:   chi2=49.6210 , p=0.0035  , df=26
# likelihood ratio test: chi2=48.7527 , p=0.0044  , df=26
# parameter F test:         F=1.8355  , p=0.0065  , df_denom=1332, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.8170  , p=0.0065  , df_denom=1329, df_num=27
# ssr based chi2 test:   chi2=51.0905 , p=0.0034  , df=27
# likelihood ratio test: chi2=50.1700 , p=0.0043  , df=27
# parameter F test:         F=1.8170  , p=0.0065  , df_denom=1329, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.8621  , p=0.0042  , df_denom=1326, df_num=28
# ssr based chi2 test:   chi2=54.3797 , p=0.0020  , df=28
# likelihood ratio test: chi2=53.3378 , p=0.0027  , df=28
# parameter F test:         F=1.8621  , p=0.0042  , df_denom=1326, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.6529  , p=0.0163  , df_denom=1323, df_num=29
# ssr based chi2 test:   chi2=50.0718 , p=0.0089  , df=29
# likelihood ratio test: chi2=49.1860 , p=0.0110  , df=29
# parameter F test:         F=1.6529  , p=0.0163  , df_denom=1323, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.5861  , p=0.0236  , df_denom=1320, df_num=30
# ssr based chi2 test:   chi2=49.7813 , p=0.0131  , df=30
# likelihood ratio test: chi2=48.9051 , p=0.0161  , df=30
# parameter F test:         F=1.5861  , p=0.0236  , df_denom=1320, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.5676  , p=0.0249  , df_denom=1317, df_num=31
# ssr based chi2 test:   chi2=50.9202 , p=0.0135  , df=31
# likelihood ratio test: chi2=50.0033 , p=0.0167  , df=31
# parameter F test:         F=1.5676  , p=0.0249  , df_denom=1317, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.5447  , p=0.0273  , df_denom=1314, df_num=32
# ssr based chi2 test:   chi2=51.8746 , p=0.0146  , df=32
# likelihood ratio test: chi2=50.9227 , p=0.0181  , df=32
# parameter F test:         F=1.5447  , p=0.0273  , df_denom=1314, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.5507  , p=0.0246  , df_denom=1311, df_num=33
# ssr based chi2 test:   chi2=53.7896 , p=0.0126  , df=33
# likelihood ratio test: chi2=52.7663 , p=0.0159  , df=33
# parameter F test:         F=1.5507  , p=0.0246  , df_denom=1311, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.5059  , p=0.0318  , df_denom=1308, df_num=34
# ssr based chi2 test:   chi2=53.8999 , p=0.0164  , df=34
# likelihood ratio test: chi2=52.8718 , p=0.0205  , df=34
# parameter F test:         F=1.5059  , p=0.0318  , df_denom=1308, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.5494  , p=0.0220  , df_denom=1305, df_num=35
# ssr based chi2 test:   chi2=57.1800 , p=0.0104  , df=35
# likelihood ratio test: chi2=56.0239 , p=0.0135  , df=35
# parameter F test:         F=1.5494  , p=0.0220  , df_denom=1305, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.4988  , p=0.0300  , df_denom=1302, df_num=36
# ssr based chi2 test:   chi2=56.9807 , p=0.0144  , df=36
# likelihood ratio test: chi2=55.8317 , p=0.0186  , df=36
# parameter F test:         F=1.4988  , p=0.0300  , df_denom=1302, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.4305  , p=0.0465  , df_denom=1299, df_num=37
# ssr based chi2 test:   chi2=55.9838 , p=0.0234  , df=37
# likelihood ratio test: chi2=54.8733 , p=0.0294  , df=37
# parameter F test:         F=1.4305  , p=0.0465  , df_denom=1299, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.4002  , p=0.0551  , df_denom=1296, df_num=38
# ssr based chi2 test:   chi2=56.3688 , p=0.0278  , df=38
# likelihood ratio test: chi2=55.2425 , p=0.0349  , df=38
# parameter F test:         F=1.4002  , p=0.0551  , df_denom=1296, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.3745  , p=0.0635  , df_denom=1293, df_num=39
# ssr based chi2 test:   chi2=56.8823 , p=0.0321  , df=39
# likelihood ratio test: chi2=55.7348 , p=0.0401  , df=39
# parameter F test:         F=1.3745  , p=0.0635  , df_denom=1293, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.3585  , p=0.0686  , df_denom=1290, df_num=40
# ssr based chi2 test:   chi2=57.7530 , p=0.0342  , df=40
# likelihood ratio test: chi2=56.5697 , p=0.0430  , df=40
# parameter F test:         F=1.3585  , p=0.0686  , df_denom=1290, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.3253  , p=0.0836  , df_denom=1287, df_num=41
# ssr based chi2 test:   chi2=57.8420 , p=0.0423  , df=41
# likelihood ratio test: chi2=56.6542 , p=0.0527  , df=41
# parameter F test:         F=1.3253  , p=0.0836  , df_denom=1287, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.3544  , p=0.0665  , df_denom=1284, df_num=42
# ssr based chi2 test:   chi2=60.6497 , p=0.0312  , df=42
# likelihood ratio test: chi2=59.3446 , p=0.0399  , df=42
# parameter F test:         F=1.3544  , p=0.0665  , df_denom=1284, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.3168  , p=0.0842  , df_denom=1281, df_num=43
# ssr based chi2 test:   chi2=60.4684 , p=0.0404  , df=43
# likelihood ratio test: chi2=59.1701 , p=0.0512  , df=43
# parameter F test:         F=1.3168  , p=0.0842  , df_denom=1281, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.4864  , p=0.0221  , df_denom=1278, df_num=44
# ssr based chi2 test:   chi2=69.9549 , p=0.0077  , df=44
# likelihood ratio test: chi2=68.2238 , p=0.0111  , df=44
# parameter F test:         F=1.4864  , p=0.0221  , df_denom=1278, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.4572  , p=0.0270  , df_denom=1275, df_num=45
# ssr based chi2 test:   chi2=70.2549 , p=0.0094  , df=45
# likelihood ratio test: chi2=68.5079 , p=0.0135  , df=45
# parameter F test:         F=1.4572  , p=0.0270  , df_denom=1275, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.4798  , p=0.0213  , df_denom=1272, df_num=46
# ssr based chi2 test:   chi2=73.0453 , p=0.0068  , df=46
# likelihood ratio test: chi2=71.1579 , p=0.0101  , df=46
# parameter F test:         F=1.4798  , p=0.0213  , df_denom=1272, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.4522  , p=0.0258  , df_denom=1269, df_num=47
# ssr based chi2 test:   chi2=73.3616 , p=0.0083  , df=47
# likelihood ratio test: chi2=71.4568 , p=0.0122  , df=47
# parameter F test:         F=1.4522  , p=0.0258  , df_denom=1269, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.4385  , p=0.0279  , df_denom=1266, df_num=48
# ssr based chi2 test:   chi2=74.3392 , p=0.0087  , df=48
# likelihood ratio test: chi2=72.3828 , p=0.0130  , df=48
# parameter F test:         F=1.4385  , p=0.0279  , df_denom=1266, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.5352  , p=0.0111  , df_denom=1263, df_num=49
# ssr based chi2 test:   chi2=81.1207 , p=0.0027  , df=49
# likelihood ratio test: chi2=78.7968 , p=0.0044  , df=49
# parameter F test:         F=1.5352  , p=0.0111  , df_denom=1263, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.5237  , p=0.0117  , df_denom=1260, df_num=50
# ssr based chi2 test:   chi2=82.2916 , p=0.0027  , df=50
# likelihood ratio test: chi2=79.8997 , p=0.0046  , df=50
# parameter F test:         F=1.5237  , p=0.0117  , df_denom=1260, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=1.5243  , p=0.0110  , df_denom=1257, df_num=51
# ssr based chi2 test:   chi2=84.1101 , p=0.0024  , df=51
# likelihood ratio test: chi2=81.6116 , p=0.0042  , df=51
# parameter F test:         F=1.5243  , p=0.0110  , df_denom=1257, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=1.4534  , p=0.0207  , df_denom=1254, df_num=52
# ssr based chi2 test:   chi2=81.9035 , p=0.0051  , df=52
# likelihood ratio test: chi2=79.5303 , p=0.0083  , df=52
# parameter F test:         F=1.4534  , p=0.0207  , df_denom=1254, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=1.4037  , p=0.0314  , df_denom=1251, df_num=53
# ssr based chi2 test:   chi2=80.7615 , p=0.0083  , df=53
# likelihood ratio test: chi2=78.4512 , p=0.0131  , df=53
# parameter F test:         F=1.4037  , p=0.0314  , df_denom=1251, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=1.3689  , p=0.0414  , df_denom=1248, df_num=54
# ssr based chi2 test:   chi2=80.3760 , p=0.0114  , df=54
# likelihood ratio test: chi2=78.0856 , p=0.0177  , df=54
# parameter F test:         F=1.3689  , p=0.0414  , df_denom=1248, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=1.3610  , p=0.0430  , df_denom=1245, df_num=55
# ssr based chi2 test:   chi2=81.5285 , p=0.0116  , df=55
# likelihood ratio test: chi2=79.1716 , p=0.0181  , df=55
# parameter F test:         F=1.3610  , p=0.0430  , df_denom=1245, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=1.3939  , p=0.0310  , df_denom=1242, df_num=56
# ssr based chi2 test:   chi2=85.1593 , p=0.0072  , df=56
# likelihood ratio test: chi2=82.5903 , p=0.0119  , df=56
# parameter F test:         F=1.3939  , p=0.0310  , df_denom=1242, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=1.6243  , p=0.0027  , df_denom=1239, df_num=57
# ssr based chi2 test:   chi2=101.1807, p=0.0003  , df=57
# likelihood ratio test: chi2=97.5786 , p=0.0007  , df=57
# parameter F test:         F=1.6243  , p=0.0027  , df_denom=1239, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=1.6241  , p=0.0025  , df_denom=1236, df_num=58
# ssr based chi2 test:   chi2=103.1149, p=0.0002  , df=58
# likelihood ratio test: chi2=99.3745 , p=0.0006  , df=58
# parameter F test:         F=1.6241  , p=0.0025  , df_denom=1236, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=1.6335  , p=0.0021  , df_denom=1233, df_num=59
# ssr based chi2 test:   chi2=105.6767, p=0.0002  , df=59
# likelihood ratio test: chi2=101.7501, p=0.0005  , df=59
# parameter F test:         F=1.6335  , p=0.0021  , df_denom=1233, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=1.6097  , p=0.0026  , df_denom=1230, df_num=60
# ssr based chi2 test:   chi2=106.0823, p=0.0002  , df=60
# likelihood ratio test: chi2=102.1234, p=0.0006  , df=60
# parameter F test:         F=1.6097  , p=0.0026  , df_denom=1230, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=1.5834  , p=0.0033  , df_denom=1227, df_num=61
# ssr based chi2 test:   chi2=106.2718, p=0.0003  , df=61
# likelihood ratio test: chi2=102.2963, p=0.0007  , df=61
# parameter F test:         F=1.5834  , p=0.0033  , df_denom=1227, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=1.6919  , p=0.0008  , df_denom=1224, df_num=62
# ssr based chi2 test:   chi2=115.6120, p=0.0000  , df=62
# likelihood ratio test: chi2=110.9239, p=0.0001  , df=62
# parameter F test:         F=1.6919  , p=0.0008  , df_denom=1224, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=1.6691  , p=0.0010  , df_denom=1221, df_num=63
# ssr based chi2 test:   chi2=116.0920, p=0.0001  , df=63
# likelihood ratio test: chi2=111.3627, p=0.0002  , df=63
# parameter F test:         F=1.6691  , p=0.0010  , df_denom=1221, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=1.8057  , p=0.0001  , df_denom=1218, df_num=64
# ssr based chi2 test:   chi2=127.8072, p=0.0000  , df=64
# likelihood ratio test: chi2=122.1020, p=0.0000  , df=64
# parameter F test:         F=1.8057  , p=0.0001  , df_denom=1218, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=1.8673  , p=0.0001  , df_denom=1215, df_num=65
# ssr based chi2 test:   chi2=134.4642, p=0.0000  , df=65
# likelihood ratio test: chi2=128.1641, p=0.0000  , df=65
# parameter F test:         F=1.8673  , p=0.0001  , df_denom=1215, df_num=65
#
# Granger Causality
# number of lags (no zero) 66
# ssr based F test:         F=1.9812  , p=0.0000  , df_denom=1212, df_num=66
# ssr based chi2 test:   chi2=145.1084, p=0.0000  , df=66
# likelihood ratio test: chi2=137.8018, p=0.0000  , df=66
# parameter F test:         F=1.9812  , p=0.0000  , df_denom=1212, df_num=66
#
# Granger Causality
# number of lags (no zero) 67
# ssr based F test:         F=1.9123  , p=0.0000  , df_denom=1209, df_num=67
# ssr based chi2 test:   chi2=142.4327, p=0.0000  , df=67
# likelihood ratio test: chi2=135.3796, p=0.0000  , df=67
# parameter F test:         F=1.9123  , p=0.0000  , df_denom=1209, df_num=67
#
# Granger Causality
# number of lags (no zero) 68
# ssr based F test:         F=2.0287  , p=0.0000  , df_denom=1206, df_num=68
# ssr based chi2 test:   chi2=153.6210, p=0.0000  , df=68
# likelihood ratio test: chi2=145.4523, p=0.0000  , df=68
# parameter F test:         F=2.0287  , p=0.0000  , df_denom=1206, df_num=68
#
# Granger Causality
# number of lags (no zero) 69
# ssr based F test:         F=2.0139  , p=0.0000  , df_denom=1203, df_num=69
# ssr based chi2 test:   chi2=155.0175, p=0.0000  , df=69
# likelihood ratio test: chi2=146.6991, p=0.0000  , df=69
# parameter F test:         F=2.0139  , p=0.0000  , df_denom=1203, df_num=69
#
# Granger Causality
# number of lags (no zero) 70
# ssr based F test:         F=2.0111  , p=0.0000  , df_denom=1200, df_num=70
# ssr based chi2 test:   chi2=157.3151, p=0.0000  , df=70
# likelihood ratio test: chi2=148.7512, p=0.0000  , df=70
# parameter F test:         F=2.0111  , p=0.0000  , df_denom=1200, df_num=70
#
# Granger Causality
# number of lags (no zero) 71
# ssr based F test:         F=1.9981  , p=0.0000  , df_denom=1197, df_num=71
# ssr based chi2 test:   chi2=158.8149, p=0.0000  , df=71
# likelihood ratio test: chi2=150.0868, p=0.0000  , df=71
# parameter F test:         F=1.9981  , p=0.0000  , df_denom=1197, df_num=71
#
# Granger Causality
# number of lags (no zero) 72
# ssr based F test:         F=2.0344  , p=0.0000  , df_denom=1194, df_num=72
# ssr based chi2 test:   chi2=164.2658, p=0.0000  , df=72
# likelihood ratio test: chi2=154.9449, p=0.0000  , df=72
# parameter F test:         F=2.0344  , p=0.0000  , df_denom=1194, df_num=72
#
# Granger Causality
# number of lags (no zero) 73
# ssr based F test:         F=2.0350  , p=0.0000  , df_denom=1191, df_num=73
# ssr based chi2 test:   chi2=166.8914, p=0.0000  , df=73
# likelihood ratio test: chi2=157.2749, p=0.0000  , df=73
# parameter F test:         F=2.0350  , p=0.0000  , df_denom=1191, df_num=73
#
# Granger Causality
# number of lags (no zero) 74
# ssr based F test:         F=1.9901  , p=0.0000  , df_denom=1188, df_num=74
# ssr based chi2 test:   chi2=165.7363, p=0.0000  , df=74
# likelihood ratio test: chi2=156.2409, p=0.0000  , df=74
# parameter F test:         F=1.9901  , p=0.0000  , df_denom=1188, df_num=74
#
# Granger Causality
# number of lags (no zero) 75
# ssr based F test:         F=1.9677  , p=0.0000  , df_denom=1185, df_num=75
# ssr based chi2 test:   chi2=166.3842, p=0.0000  , df=75
# likelihood ratio test: chi2=156.8107, p=0.0000  , df=75
# parameter F test:         F=1.9677  , p=0.0000  , df_denom=1185, df_num=75
#
# Granger Causality
# number of lags (no zero) 76
# ssr based F test:         F=1.9356  , p=0.0000  , df_denom=1182, df_num=76
# ssr based chi2 test:   chi2=166.1482, p=0.0000  , df=76
# likelihood ratio test: chi2=156.5942, p=0.0000  , df=76
# parameter F test:         F=1.9356  , p=0.0000  , df_denom=1182, df_num=76
#
# Granger Causality
# number of lags (no zero) 77
# ssr based F test:         F=1.9011  , p=0.0000  , df_denom=1179, df_num=77
# ssr based chi2 test:   chi2=165.6255, p=0.0000  , df=77
# likelihood ratio test: chi2=156.1226, p=0.0000  , df=77
# parameter F test:         F=1.9011  , p=0.0000  , df_denom=1179, df_num=77
#
# Granger Causality
# number of lags (no zero) 78
# ssr based F test:         F=1.9308  , p=0.0000  , df_denom=1176, df_num=78
# ssr based chi2 test:   chi2=170.7095, p=0.0000  , df=78
# likelihood ratio test: chi2=160.6305, p=0.0000  , df=78
# parameter F test:         F=1.9308  , p=0.0000  , df_denom=1176, df_num=78
#
# Granger Causality
# number of lags (no zero) 79
# ssr based F test:         F=1.9193  , p=0.0000  , df_denom=1173, df_num=79
# ssr based chi2 test:   chi2=172.1779, p=0.0000  , df=79
# likelihood ratio test: chi2=161.9245, p=0.0000  , df=79
# parameter F test:         F=1.9193  , p=0.0000  , df_denom=1173, df_num=79
#
# Granger Causality
# number of lags (no zero) 80
# ssr based F test:         F=1.9050  , p=0.0000  , df_denom=1170, df_num=80
# ssr based chi2 test:   chi2=173.3717, p=0.0000  , df=80
# likelihood ratio test: chi2=162.9740, p=0.0000  , df=80
# parameter F test:         F=1.9050  , p=0.0000  , df_denom=1170, df_num=80
#
# Granger Causality
# number of lags (no zero) 81
# ssr based F test:         F=1.8827  , p=0.0000  , df_denom=1167, df_num=81
# ssr based chi2 test:   chi2=173.8005, p=0.0000  , df=81
# likelihood ratio test: chi2=163.3461, p=0.0000  , df=81
# parameter F test:         F=1.8827  , p=0.0000  , df_denom=1167, df_num=81
#
# Granger Causality
# number of lags (no zero) 82
# ssr based F test:         F=1.8585  , p=0.0000  , df_denom=1164, df_num=82
# ssr based chi2 test:   chi2=174.0024, p=0.0000  , df=82
# likelihood ratio test: chi2=163.5174, p=0.0000  , df=82
# parameter F test:         F=1.8585  , p=0.0000  , df_denom=1164, df_num=82
#
# Granger Causality
# number of lags (no zero) 83
# ssr based F test:         F=1.8910  , p=0.0000  , df_denom=1161, df_num=83
# ssr based chi2 test:   chi2=179.5291, p=0.0000  , df=83
# likelihood ratio test: chi2=168.3876, p=0.0000  , df=83
# parameter F test:         F=1.8910  , p=0.0000  , df_denom=1161, df_num=83
#
# Granger Causality
# number of lags (no zero) 84
# ssr based F test:         F=1.8862  , p=0.0000  , df_denom=1158, df_num=84
# ssr based chi2 test:   chi2=181.5674, p=0.0000  , df=84
# likelihood ratio test: chi2=170.1741, p=0.0000  , df=84
# parameter F test:         F=1.8862  , p=0.0000  , df_denom=1158, df_num=84
#
# Granger Causality
# number of lags (no zero) 85
# ssr based F test:         F=1.9168  , p=0.0000  , df_denom=1155, df_num=85
# ssr based chi2 test:   chi2=187.0451, p=0.0000  , df=85
# likelihood ratio test: chi2=174.9754, p=0.0000  , df=85
# parameter F test:         F=1.9168  , p=0.0000  , df_denom=1155, df_num=85
#
# Granger Causality
# number of lags (no zero) 86
# ssr based F test:         F=1.9155  , p=0.0000  , df_denom=1152, df_num=86
# ssr based chi2 test:   chi2=189.4718, p=0.0000  , df=86
# likelihood ratio test: chi2=177.0919, p=0.0000  , df=86
# parameter F test:         F=1.9155  , p=0.0000  , df_denom=1152, df_num=86
#
# Granger Causality
# number of lags (no zero) 87
# ssr based F test:         F=1.9126  , p=0.0000  , df_denom=1149, df_num=87
# ssr based chi2 test:   chi2=191.7386, p=0.0000  , df=87
# likelihood ratio test: chi2=179.0649, p=0.0000  , df=87
# parameter F test:         F=1.9126  , p=0.0000  , df_denom=1149, df_num=87
#
# Granger Causality
# number of lags (no zero) 88
# ssr based F test:         F=1.8863  , p=0.0000  , df_denom=1146, df_num=88
# ssr based chi2 test:   chi2=191.6373, p=0.0000  , df=88
# likelihood ratio test: chi2=178.9676, p=0.0000  , df=88
# parameter F test:         F=1.8863  , p=0.0000  , df_denom=1146, df_num=88
#
# Granger Causality
# number of lags (no zero) 89
# ssr based F test:         F=1.9208  , p=0.0000  , df_denom=1143, df_num=89
# ssr based chi2 test:   chi2=197.7248, p=0.0000  , df=89
# likelihood ratio test: chi2=184.2650, p=0.0000  , df=89
# parameter F test:         F=1.9208  , p=0.0000  , df_denom=1143, df_num=89
#
# Granger Causality
# number of lags (no zero) 90
# ssr based F test:         F=1.9544  , p=0.0000  , df_denom=1140, df_num=90
# ssr based chi2 test:   chi2=203.8239, p=0.0000  , df=90
# likelihood ratio test: chi2=189.5502, p=0.0000  , df=90
# parameter F test:         F=1.9544  , p=0.0000  , df_denom=1140, df_num=90
#
# Granger Causality
# number of lags (no zero) 91
# ssr based F test:         F=1.9755  , p=0.0000  , df_denom=1137, df_num=91
# ssr based chi2 test:   chi2=208.7054, p=0.0000  , df=91
# likelihood ratio test: chi2=193.7622, p=0.0000  , df=91
# parameter F test:         F=1.9755  , p=0.0000  , df_denom=1137, df_num=91
#
# Granger Causality
# number of lags (no zero) 92
# ssr based F test:         F=1.9866  , p=0.0000  , df_denom=1134, df_num=92
# ssr based chi2 test:   chi2=212.5881, p=0.0000  , df=92
# likelihood ratio test: chi2=197.0998, p=0.0000  , df=92
# parameter F test:         F=1.9866  , p=0.0000  , df_denom=1134, df_num=92
#
# Granger Causality
# number of lags (no zero) 93
# ssr based F test:         F=2.0417  , p=0.0000  , df_denom=1131, df_num=93
# ssr based chi2 test:   chi2=221.2778, p=0.0000  , df=93
# likelihood ratio test: chi2=204.5509, p=0.0000  , df=93
# parameter F test:         F=2.0417  , p=0.0000  , df_denom=1131, df_num=93
#
# Granger Causality
# number of lags (no zero) 94
# ssr based F test:         F=2.0755  , p=0.0000  , df_denom=1128, df_num=94
# ssr based chi2 test:   chi2=227.7893, p=0.0000  , df=94
# likelihood ratio test: chi2=210.1024, p=0.0000  , df=94
# parameter F test:         F=2.0755  , p=0.0000  , df_denom=1128, df_num=94
#
# Granger Causality
# number of lags (no zero) 95
# ssr based F test:         F=2.0791  , p=0.0000  , df_denom=1125, df_num=95
# ssr based chi2 test:   chi2=231.0486, p=0.0000  , df=95
# likelihood ratio test: chi2=212.8658, p=0.0000  , df=95
# parameter F test:         F=2.0791  , p=0.0000  , df_denom=1125, df_num=95
#
# Granger Causality
# number of lags (no zero) 96
# ssr based F test:         F=2.0837  , p=0.0000  , df_denom=1122, df_num=96
# ssr based chi2 test:   chi2=234.4481, p=0.0000  , df=96
# likelihood ratio test: chi2=215.7417, p=0.0000  , df=96
# parameter F test:         F=2.0837  , p=0.0000  , df_denom=1122, df_num=96
#
# Granger Causality
# number of lags (no zero) 97
# ssr based F test:         F=2.0893  , p=0.0000  , df_denom=1119, df_num=97
# ssr based chi2 test:   chi2=237.9797, p=0.0000  , df=97
# likelihood ratio test: chi2=218.7224, p=0.0000  , df=97
# parameter F test:         F=2.0893  , p=0.0000  , df_denom=1119, df_num=97
#
# Granger Causality
# number of lags (no zero) 98
# ssr based F test:         F=2.0893  , p=0.0000  , df_denom=1116, df_num=98
# ssr based chi2 test:   chi2=240.8894, p=0.0000  , df=98
# likelihood ratio test: chi2=221.1702, p=0.0000  , df=98
# parameter F test:         F=2.0893  , p=0.0000  , df_denom=1116, df_num=98
#
# Granger Causality
# number of lags (no zero) 99
# ssr based F test:         F=2.0629  , p=0.0000  , df_denom=1113, df_num=99
# ssr based chi2 test:   chi2=240.7468, p=0.0000  , df=99
# likelihood ratio test: chi2=221.0363, p=0.0000  , df=99
# parameter F test:         F=2.0629  , p=0.0000  , df_denom=1113, df_num=99
#
# Granger Causality
# number of lags (no zero) 100
# ssr based F test:         F=2.0586  , p=0.0000  , df_denom=1110, df_num=100
# ssr based chi2 test:   chi2=243.1408, p=0.0000  , df=100
# likelihood ratio test: chi2=223.0439, p=0.0000  , df=100
# parameter F test:         F=2.0586  , p=0.0000  , df_denom=1110, df_num=100

# %%
def find_lags(test):
    lag_found = False
    lags = []
    
    for i in range(1, maxlag):
        p = test[i][0]['ssr_ftest'][1]
        if (p < 0.05):
            lags.append(test[i][0]['ssr_ftest'])
            lag_found = True

    if (lag_found == True):
        return lags
    else:
        print("lag not found")

# %%
lags_info = find_lags(test)

# %%
lags_info
# Out:
# [(4.67665716394449, 0.009455598466436625, 1404.0, 2),
#  (3.860515101622571, 0.00914537353782133, 1401.0, 3),
#  (3.1958285483035485, 0.012649652161026186, 1398.0, 4),
#  (3.2251543850978472, 0.006701374840649255, 1395.0, 5),
#  (2.870490570075504, 0.008775915531736504, 1392.0, 6),
#  (2.6656241313792512, 0.009652268241394804, 1389.0, 7),
#  (2.5378956790217955, 0.009607263892511458, 1386.0, 8),
#  (2.288541097818356, 0.01508296283382455, 1383.0, 9),
#  (2.1533573149512235, 0.018292329786755927, 1380.0, 10),
#  (1.9767586691841674, 0.027273971963543985, 1377.0, 11),
#  (1.980790060910298, 0.022675409176040127, 1374.0, 12),
#  (1.7750289709766338, 0.04197816859958426, 1371.0, 13),
#  (1.7596885115468297, 0.039576037369767746, 1368.0, 14),
#  (2.124022063671396, 0.007196383560891782, 1365.0, 15),
#  (2.2801296605047674, 0.0027258214817474594, 1362.0, 16),
#  (2.0635530535485307, 0.006557183251586267, 1359.0, 17),
#  (1.9768631885616441, 0.008584938356373984, 1356.0, 18),
#  (2.0165172105797735, 0.005903712324091856, 1353.0, 19),
#  (1.8852570434132079, 0.010371939303967508, 1350.0, 20),
#  (1.745567303567231, 0.019598794990142852, 1347.0, 21),
#  (1.6676793856985765, 0.027054190878728044, 1344.0, 22),
#  (1.6646882979978523, 0.025184695255930204, 1341.0, 23),
#  (1.6262837154187486, 0.02874510806032223, 1338.0, 24),
#  (1.5747228384727041, 0.03573614435012, 1335.0, 25),
#  (1.835465931361973, 0.006489892225523722, 1332.0, 26),
#  (1.8170418737728522, 0.00652880307442036, 1329.0, 27),
#  (1.8620888228901242, 0.004221167559998239, 1326.0, 28),
#  (1.6529016601740922, 0.016301928761888337, 1323.0, 29),
#  (1.586081165473934, 0.023583118939025635, 1320.0, 30),
#  (1.567599847121747, 0.024937185982025562, 1317.0, 31),
#  (1.544669932173379, 0.02732285843184896, 1314.0, 32),
#  (1.5507363677963062, 0.0246444921133654, 1311.0, 33),
#  (1.5058547887174036, 0.03177163832633652, 1308.0, 34),
#  (1.5494165408198182, 0.02200580703766095, 1305.0, 35),
#  (1.4987662733574318, 0.030035776173312854, 1302.0, 36),
#  (1.430484142972931, 0.04647793548362275, 1299.0, 37),
#  (1.48637348152418, 0.022140935387748587, 1278.0, 44),
#  (1.4572151597070144, 0.026969926024582827, 1275.0, 45),
#  (1.479751388210251, 0.02130068407100993, 1272.0, 46),
#  (1.452172765069509, 0.02582029615939169, 1269.0, 47),
#  (1.4385154904072617, 0.02785230875142288, 1266.0, 48),
#  (1.5351890999873499, 0.011070732649557227, 1263.0, 49),
#  (1.5236938857682971, 0.011709520689839341, 1260.0, 50),
#  (1.5243128583352916, 0.011044515709511838, 1257.0, 51),
#  (1.4533725243960778, 0.020700941404436634, 1254.0, 52),
#  (1.4037375851681606, 0.03135567504327688, 1251.0, 53),
#  (1.368885456169398, 0.041350751277579846, 1248.0, 54),
#  (1.3609941611420964, 0.043031707461468664, 1245.0, 55),
#  (1.3938827210978002, 0.031000321466034864, 1242.0, 56),
#  (1.6243341113187941, 0.002671536272639794, 1239.0, 57),
#  (1.6241053460105, 0.0025053555564846937, 1236.0, 58),
#  (1.6334798001050392, 0.002097176148264412, 1233.0, 59),
#  (1.609687089595841, 0.0026054530543678234, 1230.0, 60),
#  (1.5834303040440858, 0.003343210342635711, 1227.0, 61),
#  (1.6919228463314018, 0.0008176064531084829, 1224.0, 62),
#  (1.6691205133357576, 0.001017511953158164, 1221.0, 63),
#  (1.805739629140852, 0.0001478569684172356, 1218.0, 64),
#  (1.8673453407433567, 5.493051605963433e-05, 1215.0, 65),
#  (1.9812030938526421, 8.656929780727585e-06, 1212.0, 66),
#  (1.9123266695222982, 2.2316357464395545e-05, 1209.0, 67),
#  (2.0286777675201892, 3.103077079518571e-06, 1206.0, 68),
#  (2.013932191216853, 3.448140948194755e-06, 1203.0, 69),
#  (2.0110586673206057, 3.1630597803773045e-06, 1200.0, 70),
#  (1.9981229469759973, 3.4401668968551745e-06, 1197.0, 71),
#  (2.034409671772692, 1.627965531183317e-06, 1194.0, 72),
#  (2.0350113944086132, 1.4055360419806536e-06, 1191.0, 73),
#  (1.9900815567939336, 2.6815277284201286e-06, 1188.0, 74),
#  (1.967717723709874, 3.484112305473936e-06, 1185.0, 75),
#  (1.9356123388858217, 5.387876846070885e-06, 1182.0, 76),
#  (1.9010540690143567, 8.735237931623416e-06, 1179.0, 77),
#  (1.9308130767920322, 4.65590206673349e-06, 1176.0, 78),
#  (1.9193059587809986, 5.096765806090603e-06, 1173.0, 79),
#  (1.9050044439014833, 5.8851705557445665e-06, 1170.0, 80),
#  (1.8827178878349478, 7.865641792412218e-06, 1167.0, 81),
#  (1.8585295180139318, 1.092155956996564e-05, 1164.0, 82),
#  (1.8909970042329298, 5.5024017258349376e-06, 1161.0, 83),
#  (1.8862369980245035, 5.410141391758381e-06, 1158.0, 84),
#  (1.9167516241680767, 2.7634781895197316e-06, 1155.0, 85),
#  (1.915502535038177, 2.539998049246536e-06, 1152.0, 86),
#  (1.9125920166961652, 2.411936826660852e-06, 1149.0, 87),
#  (1.8863489487975715, 3.584424173858324e-06, 1146.0, 88),
#  (1.9208165930600993, 1.662078830659196e-06, 1143.0, 89),
#  (1.9544052729498849, 7.677202438730616e-07, 1140.0, 90),
#  (1.9755083647255272, 4.479291387251726e-07, 1137.0, 91),
#  (1.9866405508013512, 3.175850572908369e-07, 1134.0, 92),
#  (2.0417478361306043, 8.908280408521475e-08, 1131.0, 93),
#  (2.075528678590724, 3.8040546841454366e-08, 1128.0, 94),
#  (2.0791043386234236, 3.0849677659632e-08, 1125.0, 95),
#  (2.08373532003636, 2.4425348357816936e-08, 1122.0, 96),
#  (2.0893099130088624, 1.8915102819242505e-08, 1119.0, 97),
#  (2.0892528893030327, 1.6591292989844932e-08, 1116.0, 98),
#  (2.062940087039423, 2.626529316073162e-08, 1113.0, 99)]

# %% [markdown]
# # Granger Tests - PLUG

# %%
maxlag = 100
ticker = 'PLUG'
series = 'daily_tweets'

# %%
input_data = np.asarray(plug[['closing_price', series]])
test = grangercausalitytests(input_data, maxlag, addconst = True, verbose=True);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0939  , p=0.7593  , df_denom=2341, df_num=1
# ssr based chi2 test:   chi2=0.0940  , p=0.7592  , df=1
# likelihood ratio test: chi2=0.0940  , p=0.7592  , df=1
# parameter F test:         F=0.0939  , p=0.7593  , df_denom=2341, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5579  , p=0.5725  , df_denom=2338, df_num=2
# ssr based chi2 test:   chi2=1.1182  , p=0.5717  , df=2
# likelihood ratio test: chi2=1.1179  , p=0.5718  , df=2
# parameter F test:         F=0.5579  , p=0.5725  , df_denom=2338, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.3354  , p=0.0047  , df_denom=2335, df_num=3
# ssr based chi2 test:   chi2=13.0453 , p=0.0045  , df=3
# likelihood ratio test: chi2=13.0091 , p=0.0046  , df=3
# parameter F test:         F=4.3354  , p=0.0047  , df_denom=2335, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6513  , p=0.1587  , df_denom=2332, df_num=4
# ssr based chi2 test:   chi2=6.6308  , p=0.1567  , df=4
# likelihood ratio test: chi2=6.6214  , p=0.1573  , df=4
# parameter F test:         F=1.6513  , p=0.1587  , df_denom=2332, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=10.5208 , p=0.0000  , df_denom=2329, df_num=5
# ssr based chi2 test:   chi2=52.8527 , p=0.0000  , df=5
# likelihood ratio test: chi2=52.2646 , p=0.0000  , df=5
# parameter F test:         F=10.5208 , p=0.0000  , df_denom=2329, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=7.8749  , p=0.0000  , df_denom=2326, df_num=6
# ssr based chi2 test:   chi2=47.5136 , p=0.0000  , df=6
# likelihood ratio test: chi2=47.0375 , p=0.0000  , df=6
# parameter F test:         F=7.8749  , p=0.0000  , df_denom=2326, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=6.0049  , p=0.0000  , df_denom=2323, df_num=7
# ssr based chi2 test:   chi2=42.3054 , p=0.0000  , df=7
# likelihood ratio test: chi2=41.9272 , p=0.0000  , df=7
# parameter F test:         F=6.0049  , p=0.0000  , df_denom=2323, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=6.3953  , p=0.0000  , df_denom=2320, df_num=8
# ssr based chi2 test:   chi2=51.5374 , p=0.0000  , df=8
# likelihood ratio test: chi2=50.9773 , p=0.0000  , df=8
# parameter F test:         F=6.3953  , p=0.0000  , df_denom=2320, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=5.9765  , p=0.0000  , df_denom=2317, df_num=9
# ssr based chi2 test:   chi2=54.2299 , p=0.0000  , df=9
# likelihood ratio test: chi2=53.6100 , p=0.0000  , df=9
# parameter F test:         F=5.9765  , p=0.0000  , df_denom=2317, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=5.4976  , p=0.0000  , df_denom=2314, df_num=10
# ssr based chi2 test:   chi2=55.4746 , p=0.0000  , df=10
# likelihood ratio test: chi2=54.8259 , p=0.0000  , df=10
# parameter F test:         F=5.4976  , p=0.0000  , df_denom=2314, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=5.0022  , p=0.0000  , df_denom=2311, df_num=11
# ssr based chi2 test:   chi2=55.5724 , p=0.0000  , df=11
# likelihood ratio test: chi2=54.9211 , p=0.0000  , df=11
# parameter F test:         F=5.0022  , p=0.0000  , df_denom=2311, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=5.6157  , p=0.0000  , df_denom=2308, df_num=12
# ssr based chi2 test:   chi2=68.1186 , p=0.0000  , df=12
# likelihood ratio test: chi2=67.1431 , p=0.0000  , df=12
# parameter F test:         F=5.6157  , p=0.0000  , df_denom=2308, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=5.6917  , p=0.0000  , df_denom=2305, df_num=13
# ssr based chi2 test:   chi2=74.8583 , p=0.0000  , df=13
# likelihood ratio test: chi2=73.6819 , p=0.0000  , df=13
# parameter F test:         F=5.6917  , p=0.0000  , df_denom=2305, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=6.1941  , p=0.0000  , df_denom=2302, df_num=14
# ssr based chi2 test:   chi2=87.8100 , p=0.0000  , df=14
# likelihood ratio test: chi2=86.1965 , p=0.0000  , df=14
# parameter F test:         F=6.1941  , p=0.0000  , df_denom=2302, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=6.0421  , p=0.0000  , df_denom=2299, df_num=15
# ssr based chi2 test:   chi2=91.8537 , p=0.0000  , df=15
# likelihood ratio test: chi2=90.0894 , p=0.0000  , df=15
# parameter F test:         F=6.0421  , p=0.0000  , df_denom=2299, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=5.7734  , p=0.0000  , df_denom=2296, df_num=16
# ssr based chi2 test:   chi2=93.7019 , p=0.0000  , df=16
# likelihood ratio test: chi2=91.8660 , p=0.0000  , df=16
# parameter F test:         F=5.7734  , p=0.0000  , df_denom=2296, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=7.7431  , p=0.0000  , df_denom=2293, df_num=17
# ssr based chi2 test:   chi2=133.6419, p=0.0000  , df=17
# likelihood ratio test: chi2=129.9467, p=0.0000  , df=17
# parameter F test:         F=7.7431  , p=0.0000  , df_denom=2293, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=7.8756  , p=0.0000  , df_denom=2290, df_num=18
# ssr based chi2 test:   chi2=144.0505, p=0.0000  , df=18
# likelihood ratio test: chi2=139.7677, p=0.0000  , df=18
# parameter F test:         F=7.8756  , p=0.0000  , df_denom=2290, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=8.2305  , p=0.0000  , df_denom=2287, df_num=19
# ssr based chi2 test:   chi2=159.0469, p=0.0000  , df=19
# likelihood ratio test: chi2=153.8450, p=0.0000  , df=19
# parameter F test:         F=8.2305  , p=0.0000  , df_denom=2287, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=8.3771  , p=0.0000  , df_denom=2284, df_num=20
# ssr based chi2 test:   chi2=170.5490, p=0.0000  , df=20
# likelihood ratio test: chi2=164.5838, p=0.0000  , df=20
# parameter F test:         F=8.3771  , p=0.0000  , df_denom=2284, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=7.8162  , p=0.0000  , df_denom=2281, df_num=21
# ssr based chi2 test:   chi2=167.2351, p=0.0000  , df=21
# likelihood ratio test: chi2=161.4919, p=0.0000  , df=21
# parameter F test:         F=7.8162  , p=0.0000  , df_denom=2281, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=8.3969  , p=0.0000  , df_denom=2278, df_num=22
# ssr based chi2 test:   chi2=188.3813, p=0.0000  , df=22
# likelihood ratio test: chi2=181.1323, p=0.0000  , df=22
# parameter F test:         F=8.3969  , p=0.0000  , df_denom=2278, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=8.0591  , p=0.0000  , df_denom=2275, df_num=23
# ssr based chi2 test:   chi2=189.1898, p=0.0000  , df=23
# likelihood ratio test: chi2=181.8771, p=0.0000  , df=23
# parameter F test:         F=8.0591  , p=0.0000  , df_denom=2275, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=8.5068  , p=0.0000  , df_denom=2272, df_num=24
# ssr based chi2 test:   chi2=208.5661, p=0.0000  , df=24
# likelihood ratio test: chi2=199.7212, p=0.0000  , df=24
# parameter F test:         F=8.5068  , p=0.0000  , df_denom=2272, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=8.2451  , p=0.0000  , df_denom=2269, df_num=25
# ssr based chi2 test:   chi2=210.7594, p=0.0000  , df=25
# likelihood ratio test: chi2=201.7292, p=0.0000  , df=25
# parameter F test:         F=8.2451  , p=0.0000  , df_denom=2269, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=7.9432  , p=0.0000  , df_denom=2266, df_num=26
# ssr based chi2 test:   chi2=211.3541, p=0.0000  , df=26
# likelihood ratio test: chi2=202.2706, p=0.0000  , df=26
# parameter F test:         F=7.9432  , p=0.0000  , df_denom=2266, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=8.4410  , p=0.0000  , df_denom=2263, df_num=27
# ssr based chi2 test:   chi2=233.4473, p=0.0000  , df=27
# likelihood ratio test: chi2=222.4260, p=0.0000  , df=27
# parameter F test:         F=8.4410  , p=0.0000  , df_denom=2263, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=8.3077  , p=0.0000  , df_denom=2260, df_num=28
# ssr based chi2 test:   chi2=238.4817, p=0.0000  , df=28
# likelihood ratio test: chi2=226.9907, p=0.0000  , df=28
# parameter F test:         F=8.3077  , p=0.0000  , df_denom=2260, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=9.5149  , p=0.0000  , df_denom=2257, df_num=29
# ssr based chi2 test:   chi2=283.1446, p=0.0000  , df=29
# likelihood ratio test: chi2=267.1294, p=0.0000  , df=29
# parameter F test:         F=9.5149  , p=0.0000  , df_denom=2257, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=9.3719  , p=0.0000  , df_denom=2254, df_num=30
# ssr based chi2 test:   chi2=288.7669, p=0.0000  , df=30
# likelihood ratio test: chi2=272.1271, p=0.0000  , df=30
# parameter F test:         F=9.3719  , p=0.0000  , df_denom=2254, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=9.7780  , p=0.0000  , df_denom=2251, df_num=31
# ssr based chi2 test:   chi2=311.6013, p=0.0000  , df=31
# likelihood ratio test: chi2=292.3330, p=0.0000  , df=31
# parameter F test:         F=9.7780  , p=0.0000  , df_denom=2251, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=9.8728  , p=0.0000  , df_denom=2248, df_num=32
# ssr based chi2 test:   chi2=325.0642, p=0.0000  , df=32
# likelihood ratio test: chi2=304.1595, p=0.0000  , df=32
# parameter F test:         F=9.8728  , p=0.0000  , df_denom=2248, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=10.4993 , p=0.0000  , df_denom=2245, df_num=33
# ssr based chi2 test:   chi2=356.8187, p=0.0000  , df=33
# likelihood ratio test: chi2=331.8251, p=0.0000  , df=33
# parameter F test:         F=10.4993 , p=0.0000  , df_denom=2245, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=10.3052 , p=0.0000  , df_denom=2242, df_num=34
# ssr based chi2 test:   chi2=361.1586, p=0.0000  , df=34
# likelihood ratio test: chi2=335.5717, p=0.0000  , df=34
# parameter F test:         F=10.3052 , p=0.0000  , df_denom=2242, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=10.1124 , p=0.0000  , df_denom=2239, df_num=35
# ssr based chi2 test:   chi2=365.1574, p=0.0000  , df=35
# likelihood ratio test: chi2=339.0172, p=0.0000  , df=35
# parameter F test:         F=10.1124 , p=0.0000  , df_denom=2239, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=10.3811 , p=0.0000  , df_denom=2236, df_num=36
# ssr based chi2 test:   chi2=385.9220, p=0.0000  , df=36
# likelihood ratio test: chi2=356.8669, p=0.0000  , df=36
# parameter F test:         F=10.3811 , p=0.0000  , df_denom=2236, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=10.0688 , p=0.0000  , df_denom=2233, df_num=37
# ssr based chi2 test:   chi2=385.0598, p=0.0000  , df=37
# likelihood ratio test: chi2=356.1168, p=0.0000  , df=37
# parameter F test:         F=10.0688 , p=0.0000  , df_denom=2233, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=9.6859  , p=0.0000  , df_denom=2230, df_num=38
# ssr based chi2 test:   chi2=380.7737, p=0.0000  , df=38
# likelihood ratio test: chi2=352.4294, p=0.0000  , df=38
# parameter F test:         F=9.6859  , p=0.0000  , df_denom=2230, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=9.8035  , p=0.0000  , df_denom=2227, df_num=39
# ssr based chi2 test:   chi2=395.9000, p=0.0000  , df=39
# likelihood ratio test: chi2=365.3645, p=0.0000  , df=39
# parameter F test:         F=9.8035  , p=0.0000  , df_denom=2227, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=9.9567  , p=0.0000  , df_denom=2224, df_num=40
# ssr based chi2 test:   chi2=412.7721, p=0.0000  , df=40
# likelihood ratio test: chi2=379.7068, p=0.0000  , df=40
# parameter F test:         F=9.9567  , p=0.0000  , df_denom=2224, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=10.0277 , p=0.0000  , df_denom=2221, df_num=41
# ssr based chi2 test:   chi2=426.5009, p=0.0000  , df=41
# likelihood ratio test: chi2=391.3075, p=0.0000  , df=41
# parameter F test:         F=10.0277 , p=0.0000  , df_denom=2221, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=9.4434  , p=0.0000  , df_denom=2218, df_num=42
# ssr based chi2 test:   chi2=411.8221, p=0.0000  , df=42
# likelihood ratio test: chi2=378.8753, p=0.0000  , df=42
# parameter F test:         F=9.4434  , p=0.0000  , df_denom=2218, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=9.2397  , p=0.0000  , df_denom=2215, df_num=43
# ssr based chi2 test:   chi2=412.9137, p=0.0000  , df=43
# likelihood ratio test: chi2=379.7883, p=0.0000  , df=43
# parameter F test:         F=9.2397  , p=0.0000  , df_denom=2215, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=8.9405  , p=0.0000  , df_denom=2212, df_num=44
# ssr based chi2 test:   chi2=409.2114, p=0.0000  , df=44
# likelihood ratio test: chi2=376.6342, p=0.0000  , df=44
# parameter F test:         F=8.9405  , p=0.0000  , df_denom=2212, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=8.8657  , p=0.0000  , df_denom=2209, df_num=45
# ssr based chi2 test:   chi2=415.3919, p=0.0000  , df=45
# likelihood ratio test: chi2=381.8624, p=0.0000  , df=45
# parameter F test:         F=8.8657  , p=0.0000  , df_denom=2209, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=8.4923  , p=0.0000  , df_denom=2206, df_num=46
# ssr based chi2 test:   chi2=407.1122, p=0.0000  , df=46
# likelihood ratio test: chi2=374.8261, p=0.0000  , df=46
# parameter F test:         F=8.4923  , p=0.0000  , df_denom=2206, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=8.2571  , p=0.0000  , df_denom=2203, df_num=47
# ssr based chi2 test:   chi2=404.8184, p=0.0000  , df=47
# likelihood ratio test: chi2=372.8641, p=0.0000  , df=47
# parameter F test:         F=8.2571  , p=0.0000  , df_denom=2203, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=8.3520  , p=0.0000  , df_denom=2200, df_num=48
# ssr based chi2 test:   chi2=418.5705, p=0.0000  , df=48
# likelihood ratio test: chi2=384.5135, p=0.0000  , df=48
# parameter F test:         F=8.3520  , p=0.0000  , df_denom=2200, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=8.1131  , p=0.0000  , df_denom=2197, df_num=49
# ssr based chi2 test:   chi2=415.4533, p=0.0000  , df=49
# likelihood ratio test: chi2=381.8622, p=0.0000  , df=49
# parameter F test:         F=8.1131  , p=0.0000  , df_denom=2197, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=8.0146  , p=0.0000  , df_denom=2194, df_num=50
# ssr based chi2 test:   chi2=419.1788, p=0.0000  , df=50
# likelihood ratio test: chi2=385.0014, p=0.0000  , df=50
# parameter F test:         F=8.0146  , p=0.0000  , df_denom=2194, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=8.0574  , p=0.0000  , df_denom=2191, df_num=51
# ssr based chi2 test:   chi2=430.2468, p=0.0000  , df=51
# likelihood ratio test: chi2=394.3271, p=0.0000  , df=51
# parameter F test:         F=8.0574  , p=0.0000  , df_denom=2191, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=7.4814  , p=0.0000  , df_denom=2188, df_num=52
# ssr based chi2 test:   chi2=407.7041, p=0.0000  , df=52
# likelihood ratio test: chi2=375.2529, p=0.0000  , df=52
# parameter F test:         F=7.4814  , p=0.0000  , df_denom=2188, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=6.9307  , p=0.0000  , df_denom=2185, df_num=53
# ssr based chi2 test:   chi2=385.3171, p=0.0000  , df=53
# likelihood ratio test: chi2=356.1548, p=0.0000  , df=53
# parameter F test:         F=6.9307  , p=0.0000  , df_denom=2185, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=6.4186  , p=0.0000  , df_denom=2182, df_num=54
# ssr based chi2 test:   chi2=363.9210, p=0.0000  , df=54
# likelihood ratio test: chi2=337.7541, p=0.0000  , df=54
# parameter F test:         F=6.4186  , p=0.0000  , df_denom=2182, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=6.6457  , p=0.0000  , df_denom=2179, df_num=55
# ssr based chi2 test:   chi2=384.1347, p=0.0000  , df=55
# likelihood ratio test: chi2=355.1196, p=0.0000  , df=55
# parameter F test:         F=6.6457  , p=0.0000  , df_denom=2179, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=6.5220  , p=0.0000  , df_denom=2176, df_num=56
# ssr based chi2 test:   chi2=384.1968, p=0.0000  , df=56
# likelihood ratio test: chi2=355.1613, p=0.0000  , df=56
# parameter F test:         F=6.5220  , p=0.0000  , df_denom=2176, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=6.5028  , p=0.0000  , df_denom=2173, df_num=57
# ssr based chi2 test:   chi2=390.2757, p=0.0000  , df=57
# likelihood ratio test: chi2=360.3488, p=0.0000  , df=57
# parameter F test:         F=6.5028  , p=0.0000  , df_denom=2173, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=6.0378  , p=0.0000  , df_denom=2170, df_num=58
# ssr based chi2 test:   chi2=369.0744, p=0.0000  , df=58
# likelihood ratio test: chi2=342.1542, p=0.0000  , df=58
# parameter F test:         F=6.0378  , p=0.0000  , df_denom=2170, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=5.9970  , p=0.0000  , df_denom=2167, df_num=59
# ssr based chi2 test:   chi2=373.2508, p=0.0000  , df=59
# likelihood ratio test: chi2=345.7366, p=0.0000  , df=59
# parameter F test:         F=5.9970  , p=0.0000  , df_denom=2167, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=6.0000  , p=0.0000  , df_denom=2164, df_num=60
# ssr based chi2 test:   chi2=380.1289, p=0.0000  , df=60
# likelihood ratio test: chi2=351.6304, p=0.0000  , df=60
# parameter F test:         F=6.0000  , p=0.0000  , df_denom=2164, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=6.0950  , p=0.0000  , df_denom=2161, df_num=61
# ssr based chi2 test:   chi2=392.9584, p=0.0000  , df=61
# likelihood ratio test: chi2=362.5917, p=0.0000  , df=61
# parameter F test:         F=6.0950  , p=0.0000  , df_denom=2161, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=6.1128  , p=0.0000  , df_denom=2158, df_num=62
# ssr based chi2 test:   chi2=400.9494, p=0.0000  , df=62
# likelihood ratio test: chi2=369.3871, p=0.0000  , df=62
# parameter F test:         F=6.1128  , p=0.0000  , df_denom=2158, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=5.9498  , p=0.0000  , df_denom=2155, df_num=63
# ssr based chi2 test:   chi2=396.9249, p=0.0000  , df=63
# likelihood ratio test: chi2=365.9491, p=0.0000  , df=63
# parameter F test:         F=5.9498  , p=0.0000  , df_denom=2155, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=5.8560  , p=0.0000  , df_denom=2152, df_num=64
# ssr based chi2 test:   chi2=397.2475, p=0.0000  , df=64
# likelihood ratio test: chi2=366.2117, p=0.0000  , df=64
# parameter F test:         F=5.8560  , p=0.0000  , df_denom=2152, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=5.7850  , p=0.0000  , df_denom=2149, df_num=65
# ssr based chi2 test:   chi2=398.9440, p=0.0000  , df=65
# likelihood ratio test: chi2=367.6438, p=0.0000  , df=65
# parameter F test:         F=5.7850  , p=0.0000  , df_denom=2149, df_num=65
#
# Granger Causality
# number of lags (no zero) 66
# ssr based F test:         F=5.7327  , p=0.0000  , df_denom=2146, df_num=66
# ssr based chi2 test:   chi2=401.8066, p=0.0000  , df=66
# likelihood ratio test: chi2=370.0662, p=0.0000  , df=66
# parameter F test:         F=5.7327  , p=0.0000  , df_denom=2146, df_num=66
#
# Granger Causality
# number of lags (no zero) 67
# ssr based F test:         F=5.8166  , p=0.0000  , df_denom=2143, df_num=67
# ssr based chi2 test:   chi2=414.2630, p=0.0000  , df=67
# likelihood ratio test: chi2=380.6179, p=0.0000  , df=67
# parameter F test:         F=5.8166  , p=0.0000  , df_denom=2143, df_num=67
#
# Granger Causality
# number of lags (no zero) 68
# ssr based F test:         F=5.6366  , p=0.0000  , df_denom=2140, df_num=68
# ssr based chi2 test:   chi2=407.8287, p=0.0000  , df=68
# likelihood ratio test: chi2=375.1543, p=0.0000  , df=68
# parameter F test:         F=5.6366  , p=0.0000  , df_denom=2140, df_num=68
#
# Granger Causality
# number of lags (no zero) 69
# ssr based F test:         F=5.5512  , p=0.0000  , df_denom=2137, df_num=69
# ssr based chi2 test:   chi2=407.9459, p=0.0000  , df=69
# likelihood ratio test: chi2=375.2408, p=0.0000  , df=69
# parameter F test:         F=5.5512  , p=0.0000  , df_denom=2137, df_num=69
#
# Granger Causality
# number of lags (no zero) 70
# ssr based F test:         F=5.5005  , p=0.0000  , df_denom=2134, df_num=70
# ssr based chi2 test:   chi2=410.4755, p=0.0000  , df=70
# likelihood ratio test: chi2=377.3719, p=0.0000  , df=70
# parameter F test:         F=5.5005  , p=0.0000  , df_denom=2134, df_num=70
#
# Granger Causality
# number of lags (no zero) 71
# ssr based F test:         F=5.3908  , p=0.0000  , df_denom=2131, df_num=71
# ssr based chi2 test:   chi2=408.4277, p=0.0000  , df=71
# likelihood ratio test: chi2=375.6235, p=0.0000  , df=71
# parameter F test:         F=5.3908  , p=0.0000  , df_denom=2131, df_num=71
#
# Granger Causality
# number of lags (no zero) 72
# ssr based F test:         F=5.3142  , p=0.0000  , df_denom=2128, df_num=72
# ssr based chi2 test:   chi2=408.6943, p=0.0000  , df=72
# likelihood ratio test: chi2=375.8366, p=0.0000  , df=72
# parameter F test:         F=5.3142  , p=0.0000  , df_denom=2128, df_num=72
#
# Granger Causality
# number of lags (no zero) 73
# ssr based F test:         F=5.2224  , p=0.0000  , df_denom=2125, df_num=73
# ssr based chi2 test:   chi2=407.6082, p=0.0000  , df=73
# likelihood ratio test: chi2=374.9029, p=0.0000  , df=73
# parameter F test:         F=5.2224  , p=0.0000  , df_denom=2125, df_num=73
#
# Granger Causality
# number of lags (no zero) 74
# ssr based F test:         F=5.0603  , p=0.0000  , df_denom=2122, df_num=74
# ssr based chi2 test:   chi2=400.7573, p=0.0000  , df=74
# likelihood ratio test: chi2=369.0742, p=0.0000  , df=74
# parameter F test:         F=5.0603  , p=0.0000  , df_denom=2122, df_num=74
#
# Granger Causality
# number of lags (no zero) 75
# ssr based F test:         F=5.0522  , p=0.0000  , df_denom=2119, df_num=75
# ssr based chi2 test:   chi2=405.9193, p=0.0000  , df=75
# likelihood ratio test: chi2=373.4448, p=0.0000  , df=75
# parameter F test:         F=5.0522  , p=0.0000  , df_denom=2119, df_num=75
#
# Granger Causality
# number of lags (no zero) 76
# ssr based F test:         F=5.3377  , p=0.0000  , df_denom=2116, df_num=76
# ssr based chi2 test:   chi2=434.9940, p=0.0000  , df=76
# likelihood ratio test: chi2=397.9616, p=0.0000  , df=76
# parameter F test:         F=5.3377  , p=0.0000  , df_denom=2116, df_num=76
#
# Granger Causality
# number of lags (no zero) 77
# ssr based F test:         F=5.3238  , p=0.0000  , df_denom=2113, df_num=77
# ssr based chi2 test:   chi2=440.0053, p=0.0000  , df=77
# likelihood ratio test: chi2=402.1479, p=0.0000  , df=77
# parameter F test:         F=5.3238  , p=0.0000  , df_denom=2113, df_num=77
#
# Granger Causality
# number of lags (no zero) 78
# ssr based F test:         F=5.4508  , p=0.0000  , df_denom=2110, df_num=78
# ssr based chi2 test:   chi2=456.7962, p=0.0000  , df=78
# likelihood ratio test: chi2=416.1514, p=0.0000  , df=78
# parameter F test:         F=5.4508  , p=0.0000  , df_denom=2110, df_num=78
#
# Granger Causality
# number of lags (no zero) 79
# ssr based F test:         F=5.4066  , p=0.0000  , df_denom=2107, df_num=79
# ssr based chi2 test:   chi2=459.3493, p=0.0000  , df=79
# likelihood ratio test: chi2=418.2593, p=0.0000  , df=79
# parameter F test:         F=5.4066  , p=0.0000  , df_denom=2107, df_num=79
#
# Granger Causality
# number of lags (no zero) 80
# ssr based F test:         F=5.4952  , p=0.0000  , df_denom=2104, df_num=80
# ssr based chi2 test:   chi2=473.2590, p=0.0000  , df=80
# likelihood ratio test: chi2=429.7782, p=0.0000  , df=80
# parameter F test:         F=5.4952  , p=0.0000  , df_denom=2104, df_num=80
#
# Granger Causality
# number of lags (no zero) 81
# ssr based F test:         F=5.4683  , p=0.0000  , df_denom=2101, df_num=81
# ssr based chi2 test:   chi2=477.2993, p=0.0000  , df=81
# likelihood ratio test: chi2=433.1006, p=0.0000  , df=81
# parameter F test:         F=5.4683  , p=0.0000  , df_denom=2101, df_num=81
#
# Granger Causality
# number of lags (no zero) 82
# ssr based F test:         F=5.3037  , p=0.0000  , df_denom=2098, df_num=82
# ssr based chi2 test:   chi2=469.1043, p=0.0000  , df=82
# likelihood ratio test: chi2=426.3057, p=0.0000  , df=82
# parameter F test:         F=5.3037  , p=0.0000  , df_denom=2098, df_num=82
#
# Granger Causality
# number of lags (no zero) 83
# ssr based F test:         F=5.3008  , p=0.0000  , df_denom=2095, df_num=83
# ssr based chi2 test:   chi2=475.0346, p=0.0000  , df=83
# likelihood ratio test: chi2=431.1953, p=0.0000  , df=83
# parameter F test:         F=5.3008  , p=0.0000  , df_denom=2095, df_num=83
#
# Granger Causality
# number of lags (no zero) 84
# ssr based F test:         F=5.3712  , p=0.0000  , df_denom=2092, df_num=84
# ssr based chi2 test:   chi2=487.6248, p=0.0000  , df=84
# likelihood ratio test: chi2=441.5586, p=0.0000  , df=84
# parameter F test:         F=5.3712  , p=0.0000  , df_denom=2092, df_num=84
#
# Granger Causality
# number of lags (no zero) 85
# ssr based F test:         F=5.3366  , p=0.0000  , df_denom=2089, df_num=85
# ssr based chi2 test:   chi2=490.7428, p=0.0000  , df=85
# likelihood ratio test: chi2=444.1039, p=0.0000  , df=85
# parameter F test:         F=5.3366  , p=0.0000  , df_denom=2089, df_num=85
#
# Granger Causality
# number of lags (no zero) 86
# ssr based F test:         F=5.2912  , p=0.0000  , df_denom=2086, df_num=86
# ssr based chi2 test:   chi2=492.7812, p=0.0000  , df=86
# likelihood ratio test: chi2=445.7598, p=0.0000  , df=86
# parameter F test:         F=5.2912  , p=0.0000  , df_denom=2086, df_num=86
#
# Granger Causality
# number of lags (no zero) 87
# ssr based F test:         F=5.2685  , p=0.0000  , df_denom=2083, df_num=87
# ssr based chi2 test:   chi2=496.8684, p=0.0000  , df=87
# likelihood ratio test: chi2=449.0941, p=0.0000  , df=87
# parameter F test:         F=5.2685  , p=0.0000  , df_denom=2083, df_num=87
#
# Granger Causality
# number of lags (no zero) 88
# ssr based F test:         F=5.2997  , p=0.0000  , df_denom=2080, df_num=88
# ssr based chi2 test:   chi2=506.0643, p=0.0000  , df=88
# likelihood ratio test: chi2=456.5997, p=0.0000  , df=88
# parameter F test:         F=5.2997  , p=0.0000  , df_denom=2080, df_num=88
#
# Granger Causality
# number of lags (no zero) 89
# ssr based F test:         F=5.2318  , p=0.0000  , df_denom=2077, df_num=89
# ssr based chi2 test:   chi2=505.7557, p=0.0000  , df=89
# likelihood ratio test: chi2=456.3285, p=0.0000  , df=89
# parameter F test:         F=5.2318  , p=0.0000  , df_denom=2077, df_num=89
#
# Granger Causality
# number of lags (no zero) 90
# ssr based F test:         F=5.2017  , p=0.0000  , df_denom=2074, df_num=90
# ssr based chi2 test:   chi2=509.0113, p=0.0000  , df=90
# likelihood ratio test: chi2=458.9670, p=0.0000  , df=90
# parameter F test:         F=5.2017  , p=0.0000  , df_denom=2074, df_num=90
#
# Granger Causality
# number of lags (no zero) 91
# ssr based F test:         F=5.2145  , p=0.0000  , df_denom=2071, df_num=91
# ssr based chi2 test:   chi2=516.4536, p=0.0000  , df=91
# likelihood ratio test: chi2=465.0107, p=0.0000  , df=91
# parameter F test:         F=5.2145  , p=0.0000  , df_denom=2071, df_num=91
#
# Granger Causality
# number of lags (no zero) 92
# ssr based F test:         F=5.1620  , p=0.0000  , df_denom=2068, df_num=92
# ssr based chi2 test:   chi2=517.3905, p=0.0000  , df=92
# likelihood ratio test: chi2=465.7528, p=0.0000  , df=92
# parameter F test:         F=5.1620  , p=0.0000  , df_denom=2068, df_num=92
#
# Granger Causality
# number of lags (no zero) 93
# ssr based F test:         F=4.9170  , p=0.0000  , df_denom=2065, df_num=93
# ssr based chi2 test:   chi2=498.6863, p=0.0000  , df=93
# likelihood ratio test: chi2=450.4715, p=0.0000  , df=93
# parameter F test:         F=4.9170  , p=0.0000  , df_denom=2065, df_num=93
#
# Granger Causality
# number of lags (no zero) 94
# ssr based F test:         F=4.8756  , p=0.0000  , df_denom=2062, df_num=94
# ssr based chi2 test:   chi2=500.3143, p=0.0000  , df=94
# likelihood ratio test: chi2=451.7850, p=0.0000  , df=94
# parameter F test:         F=4.8756  , p=0.0000  , df_denom=2062, df_num=94
#
# Granger Causality
# number of lags (no zero) 95
# ssr based F test:         F=4.8318  , p=0.0000  , df_denom=2059, df_num=95
# ssr based chi2 test:   chi2=501.6005, p=0.0000  , df=95
# likelihood ratio test: chi2=452.8182, p=0.0000  , df=95
# parameter F test:         F=4.8318  , p=0.0000  , df_denom=2059, df_num=95
#
# Granger Causality
# number of lags (no zero) 96
# ssr based F test:         F=4.7728  , p=0.0000  , df_denom=2056, df_num=96
# ssr based chi2 test:   chi2=501.2004, p=0.0000  , df=96
# likelihood ratio test: chi2=452.4720, p=0.0000  , df=96
# parameter F test:         F=4.7728  , p=0.0000  , df_denom=2056, df_num=96
#
# Granger Causality
# number of lags (no zero) 97
# ssr based F test:         F=4.6647  , p=0.0000  , df_denom=2053, df_num=97
# ssr based chi2 test:   chi2=495.4520, p=0.0000  , df=97
# likelihood ratio test: chi2=447.7478, p=0.0000  , df=97
# parameter F test:         F=4.6647  , p=0.0000  , df_denom=2053, df_num=97
#
# Granger Causality
# number of lags (no zero) 98
# ssr based F test:         F=4.6656  , p=0.0000  , df_denom=2050, df_num=98
# ssr based chi2 test:   chi2=501.1701, p=0.0000  , df=98
# likelihood ratio test: chi2=452.4093, p=0.0000  , df=98
# parameter F test:         F=4.6656  , p=0.0000  , df_denom=2050, df_num=98
#
# Granger Causality
# number of lags (no zero) 99
# ssr based F test:         F=4.6269  , p=0.0000  , df_denom=2047, df_num=99
# ssr based chi2 test:   chi2=502.5927, p=0.0000  , df=99
# likelihood ratio test: chi2=453.5532, p=0.0000  , df=99
# parameter F test:         F=4.6269  , p=0.0000  , df_denom=2047, df_num=99
#
# Granger Causality
# number of lags (no zero) 100
# ssr based F test:         F=4.5989  , p=0.0000  , df_denom=2044, df_num=100
# ssr based chi2 test:   chi2=505.1140, p=0.0000  , df=100
# likelihood ratio test: chi2=455.5932, p=0.0000  , df=100
# parameter F test:         F=4.5989  , p=0.0000  , df_denom=2044, df_num=100

# %%
def find_lags(test):
    lag_found = False
    lags = []
    
    for i in range(1, maxlag):
        p = test[i][0]['ssr_ftest'][1]
        if (p < 0.05):
            lags.append(test[i][0]['ssr_ftest'])
            lag_found = True

    if (lag_found == True):
        return lags
    else:
        print("lag not found")

# %%
lags_info = find_lags(test)

# %%
lags_info
# Out:
# [(4.335420898565926, 0.0046954716929617285, 2335.0, 3),
#  (10.520840664094639, 5.263024481661221e-10, 2329.0, 5),
#  (7.8749280829708015, 2.03590045036183e-08, 2326.0, 6),
#  (6.004859579915518, 5.931483969145837e-07, 2323.0, 7),
#  (6.395310007873432, 3.035105421929556e-08, 2320.0, 8),
#  (5.9765392578267145, 2.6158453410312594e-08, 2317.0, 9),
#  (5.497567338474687, 4.04074729341447e-08, 2314.0, 10),
#  (5.002248212206874, 9.624518877239073e-08, 2311.0, 11),
#  (5.615718932340288, 1.3973426410956862e-09, 2308.0, 12),
#  (5.691658241671992, 2.2381462771027075e-10, 2305.0, 13),
#  (6.194111853932694, 2.851533430295851e-12, 2302.0, 14),
#  (6.0421054817530955, 1.4340351250640405e-12, 2299.0, 15),
#  (5.773388541018176, 1.7518863627807352e-12, 2296.0, 16),
#  (7.743098032822977, 3.791186969427095e-19, 2293.0, 17),
#  (7.875555823732201, 1.5386254826853225e-20, 2290.0, 18),
#  (8.230532730346393, 9.741193857718579e-23, 2287.0, 19),
#  (8.377074587213084, 2.6816597925519364e-24, 2284.0, 20),
#  (7.816229862285832, 3.1376625317822443e-23, 2281.0, 21),
#  (8.39691092591143, 1.8041148903828305e-26, 2278.0, 22),
#  (8.059148504202236, 3.9850138880288403e-26, 2275.0, 23),
#  (8.50678730927009, 5.092221305257246e-29, 2272.0, 24),
#  (8.24505442610874, 6.552002598807768e-29, 2269.0, 25),
#  (7.943217478435332, 1.5721210527509643e-28, 2266.0, 26),
#  (8.441043203802275, 7.656792556366347e-32, 2263.0, 27),
#  (8.307674764979978, 3.26157778543928e-32, 2260.0, 28),
#  (9.514879555872701, 2.5137740810322205e-39, 2257.0, 29),
#  (9.371930436099953, 9.259667320047145e-40, 2254.0, 30),
#  (9.777993326395801, 4.300102501747181e-43, 2251.0, 31),
#  (9.872788513898747, 7.999200446212445e-45, 2248.0, 32),
#  (10.499343806859342, 1.3820946476590282e-49, 2245.0, 33),
#  (10.305158655862249, 9.275489976691364e-50, 2242.0, 34),
#  (10.112399503483857, 7.07684178642635e-50, 2239.0, 35),
#  (10.381137156858987, 9.576514833847846e-53, 2236.0, 36),
#  (10.068839619815558, 4.651144855686121e-52, 2233.0, 37),
#  (9.685913260206108, 8.005186788428957e-51, 2230.0, 38),
#  (9.803514882998718, 9.645045231068642e-53, 2227.0, 39),
#  (9.956672210542678, 6.332132105570335e-55, 2224.0, 40),
#  (10.027719859276019, 1.3861656604128043e-56, 2221.0, 41),
#  (9.44339086318754, 1.057424636659919e-53, 2218.0, 42),
#  (9.239730153991552, 2.383411748702265e-53, 2215.0, 43),
#  (8.940536720969648, 3.0579955408382264e-52, 2212.0, 44),
#  (8.86570641053609, 1.0579746201112348e-52, 2209.0, 45),
#  (8.492250385557757, 6.895173640791799e-51, 2206.0, 46),
#  (8.257087505260087, 5.015161042505311e-50, 2203.0, 47),
#  (8.351973259520156, 1.1273847149787154e-51, 2200.0, 48),
#  (8.113053082824802, 1.0859451301950076e-50, 2197.0, 49),
#  (8.014625867236184, 8.96707101018882e-51, 2194.0, 50),
#  (8.057428432221775, 5.480340102385607e-52, 2191.0, 51),
#  (7.4814365355369965, 4.897971928420691e-48, 2188.0, 52),
#  (6.930734470768244, 3.85308985330942e-44, 2185.0, 53),
#  (6.418640196003423, 1.9694558117687414e-40, 2182.0, 54),
#  (6.645729075050284, 4.696917875312125e-43, 2179.0, 55),
#  (6.521970900360332, 1.2842048435829555e-42, 2176.0, 56),
#  (6.502799534703972, 4.341191750679863e-43, 2173.0, 57),
#  (6.037810815037326, 1.768589480671328e-39, 2170.0, 58),
#  (5.996963164357755, 1.1235539678468251e-39, 2167.0, 59),
#  (5.999991557883267, 2.8489471233752026e-40, 2164.0, 60),
#  (6.0950242423122765, 9.647331710338162e-42, 2161.0, 61),
#  (6.112845935934778, 1.7238409836350444e-42, 2158.0, 62),
#  (5.949760408701008, 1.7983178801383651e-41, 2155.0, 63),
#  (5.8559614382659895, 4.268702296311509e-41, 2152.0, 64),
#  (5.784957902928449, 6.351758407715944e-41, 2149.0, 65),
#  (5.73269027659368, 6.386779940097597e-41, 2146.0, 66),
#  (5.816607784466838, 2.6581755475013002e-42, 2143.0, 67),
#  (5.636631275965345, 5.847482534502114e-41, 2140.0, 68),
#  (5.551185240640563, 1.4502387510750472e-40, 2137.0, 69),
#  (5.500500453428112, 1.6193267125074867e-40, 2134.0, 70),
#  (5.3907576356054445, 8.04214518206506e-40, 2131.0, 71),
#  (5.31420488165861, 1.8580139843182838e-39, 2128.0, 72),
#  (5.22240628482448, 6.601205126975273e-39, 2125.0, 73),
#  (5.06031938461146, 1.4808308382943005e-37, 2122.0, 74),
#  (5.052234479133845, 6.910672893719836e-38, 2119.0, 75),
#  (5.337659508177988, 1.5479078004330962e-41, 2116.0, 76),
#  (5.323822748965454, 7.874453095418338e-42, 2113.0, 77),
#  (5.450781794885085, 9.469211396025968e-44, 2110.0, 78),
#  (5.406555189960228, 1.0762548841173777e-43, 2107.0, 79),
#  (5.495237197803575, 3.3665703845688714e-45, 2104.0, 80),
#  (5.468338497901466, 2.4239995091368166e-45, 2101.0, 81),
#  (5.303670446686469, 8.157138707316945e-44, 2098.0, 82),
#  (5.300765696625415, 3.2256471731437163e-44, 2095.0, 83),
#  (5.3711539437876565, 1.6110399602495218e-45, 2092.0, 84),
#  (5.336604265201952, 1.5593907130172674e-45, 2089.0, 85),
#  (5.291194565397961, 2.1099617897322125e-45, 2086.0, 86),
#  (5.268505725205932, 1.5152303180582518e-45, 2083.0, 87),
#  (5.299742734169361, 2.270167863522937e-46, 2080.0, 88),
#  (5.231764637867294, 6.3389524467012505e-46, 2077.0, 89),
#  (5.201721637944203, 5.925138880248245e-46, 2074.0, 90),
#  (5.214541104757048, 1.552571666646347e-46, 2071.0, 91),
#  (5.162023227061586, 2.9503790057797562e-46, 2068.0, 92),
#  (4.916954405559136, 2.0829941763841993e-43, 2065.0, 93),
#  (4.875601547726038, 3.1195813748257468e-43, 2062.0, 94),
#  (4.831791236047527, 5.16289816547333e-43, 2059.0, 95),
#  (4.772806370503148, 1.4072926169011562e-42, 2056.0, 96),
#  (4.664687196099793, 1.8577644150157912e-41, 2053.0, 97),
#  (4.665624972164581, 8.159480323963112e-42, 2050.0, 98),
#  (4.626889066114933, 1.276028566102189e-41, 2047.0, 99)]

# %% [markdown]
# # SPWR Redo

# %%
maxlag = 100
ticker = 'SPWR'
series = 'daily_tweets'

# %%
input_data = np.asarray(spwr[['closing_price', series]])
test = grangercausalitytests(input_data, maxlag, addconst = True, verbose=True);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.8549  , p=0.0089  , df_denom=2553, df_num=1
# ssr based chi2 test:   chi2=6.8629  , p=0.0088  , df=1
# likelihood ratio test: chi2=6.8537  , p=0.0088  , df=1
# parameter F test:         F=6.8549  , p=0.0089  , df_denom=2553, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.5794  , p=0.0760  , df_denom=2550, df_num=2
# ssr based chi2 test:   chi2=5.1689  , p=0.0754  , df=2
# likelihood ratio test: chi2=5.1637  , p=0.0756  , df=2
# parameter F test:         F=2.5794  , p=0.0760  , df_denom=2550, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7283  , p=0.0426  , df_denom=2547, df_num=3
# ssr based chi2 test:   chi2=8.2073  , p=0.0419  , df=3
# likelihood ratio test: chi2=8.1941  , p=0.0422  , df=3
# parameter F test:         F=2.7283  , p=0.0426  , df_denom=2547, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7892  , p=0.1282  , df_denom=2544, df_num=4
# ssr based chi2 test:   chi2=7.1820  , p=0.1266  , df=4
# likelihood ratio test: chi2=7.1720  , p=0.1271  , df=4
# parameter F test:         F=1.7892  , p=0.1282  , df_denom=2544, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8054  , p=0.1084  , df_denom=2541, df_num=5
# ssr based chi2 test:   chi2=9.0660  , p=0.1065  , df=5
# likelihood ratio test: chi2=9.0499  , p=0.1071  , df=5
# parameter F test:         F=1.8054  , p=0.1084  , df_denom=2541, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0545  , p=0.0555  , df_denom=2538, df_num=6
# ssr based chi2 test:   chi2=12.3900 , p=0.0538  , df=6
# likelihood ratio test: chi2=12.3601 , p=0.0544  , df=6
# parameter F test:         F=2.0545  , p=0.0555  , df_denom=2538, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8779  , p=0.0691  , df_denom=2535, df_num=7
# ssr based chi2 test:   chi2=13.2233 , p=0.0669  , df=7
# likelihood ratio test: chi2=13.1891 , p=0.0676  , df=7
# parameter F test:         F=1.8779  , p=0.0691  , df_denom=2535, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6249  , p=0.1125  , df_denom=2532, df_num=8
# ssr based chi2 test:   chi2=13.0865 , p=0.1089  , df=8
# likelihood ratio test: chi2=13.0530 , p=0.1100  , df=8
# parameter F test:         F=1.6249  , p=0.1125  , df_denom=2532, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4601  , p=0.1570  , df_denom=2529, df_num=9
# ssr based chi2 test:   chi2=13.2392 , p=0.1521  , df=9
# likelihood ratio test: chi2=13.2049 , p=0.1535  , df=9
# parameter F test:         F=1.4601  , p=0.1570  , df_denom=2529, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4204  , p=0.1647  , df_denom=2526, df_num=10
# ssr based chi2 test:   chi2=14.3219 , p=0.1588  , df=10
# likelihood ratio test: chi2=14.2818 , p=0.1605  , df=10
# parameter F test:         F=1.4204  , p=0.1647  , df_denom=2526, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.3621  , p=0.1841  , df_denom=2523, df_num=11
# ssr based chi2 test:   chi2=15.1199 , p=0.1771  , df=11
# likelihood ratio test: chi2=15.0752 , p=0.1791  , df=11
# parameter F test:         F=1.3621  , p=0.1841  , df_denom=2523, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.2443  , p=0.2460  , df_denom=2520, df_num=12
# ssr based chi2 test:   chi2=15.0793 , p=0.2371  , df=12
# likelihood ratio test: chi2=15.0348 , p=0.2395  , df=12
# parameter F test:         F=1.2443  , p=0.2460  , df_denom=2520, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.1676  , p=0.2971  , df_denom=2517, df_num=13
# ssr based chi2 test:   chi2=15.3420 , p=0.2865  , df=13
# likelihood ratio test: chi2=15.2959 , p=0.2892  , df=13
# parameter F test:         F=1.1676  , p=0.2971  , df_denom=2517, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.2147  , p=0.2567  , df_denom=2514, df_num=14
# ssr based chi2 test:   chi2=17.2023 , p=0.2456  , df=14
# likelihood ratio test: chi2=17.1444 , p=0.2486  , df=14
# parameter F test:         F=1.2147  , p=0.2567  , df_denom=2514, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.2196  , p=0.2485  , df_denom=2511, df_num=15
# ssr based chi2 test:   chi2=18.5199 , p=0.2363  , df=15
# likelihood ratio test: chi2=18.4528 , p=0.2396  , df=15
# parameter F test:         F=1.2196  , p=0.2485  , df_denom=2511, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.3476  , p=0.1590  , df_denom=2508, df_num=16
# ssr based chi2 test:   chi2=21.8456 , p=0.1482  , df=16
# likelihood ratio test: chi2=21.7523 , p=0.1514  , df=16
# parameter F test:         F=1.3476  , p=0.1590  , df_denom=2508, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.3606  , p=0.1463  , df_denom=2505, df_num=17
# ssr based chi2 test:   chi2=23.4525 , p=0.1351  , df=17
# likelihood ratio test: chi2=23.3449 , p=0.1384  , df=17
# parameter F test:         F=1.3606  , p=0.1463  , df_denom=2505, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.4022  , p=0.1197  , df_denom=2502, df_num=18
# ssr based chi2 test:   chi2=25.6121 , p=0.1090  , df=18
# likelihood ratio test: chi2=25.4838 , p=0.1122  , df=18
# parameter F test:         F=1.4022  , p=0.1197  , df_denom=2502, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.3744  , p=0.1283  , df_denom=2499, df_num=19
# ssr based chi2 test:   chi2=26.5220 , p=0.1163  , df=19
# likelihood ratio test: chi2=26.3843 , p=0.1198  , df=19
# parameter F test:         F=1.3744  , p=0.1283  , df_denom=2499, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.3795  , p=0.1208  , df_denom=2496, df_num=20
# ssr based chi2 test:   chi2=28.0427 , p=0.1084  , df=20
# likelihood ratio test: chi2=27.8889 , p=0.1121  , df=20
# parameter F test:         F=1.3795  , p=0.1208  , df_denom=2496, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.2951  , p=0.1658  , df_denom=2493, df_num=21
# ssr based chi2 test:   chi2=27.6667 , p=0.1499  , df=21
# likelihood ratio test: chi2=27.5169 , p=0.1544  , df=21
# parameter F test:         F=1.2951  , p=0.1658  , df_denom=2493, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.6290  , p=0.0325  , df_denom=2490, df_num=22
# ssr based chi2 test:   chi2=36.4862 , p=0.0269  , df=22
# likelihood ratio test: chi2=36.2261 , p=0.0287  , df=22
# parameter F test:         F=1.6290  , p=0.0325  , df_denom=2490, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.5390  , p=0.0486  , df_denom=2487, df_num=23
# ssr based chi2 test:   chi2=36.0648 , p=0.0406  , df=23
# likelihood ratio test: chi2=35.8105 , p=0.0431  , df=23
# parameter F test:         F=1.5390  , p=0.0486  , df_denom=2487, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.5385  , p=0.0457  , df_denom=2484, df_num=24
# ssr based chi2 test:   chi2=37.6533 , p=0.0376  , df=24
# likelihood ratio test: chi2=37.3762 , p=0.0401  , df=24
# parameter F test:         F=1.5385  , p=0.0457  , df_denom=2484, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.5001  , p=0.0529  , df_denom=2481, df_num=25
# ssr based chi2 test:   chi2=38.2740 , p=0.0435  , df=25
# likelihood ratio test: chi2=37.9876 , p=0.0464  , df=25
# parameter F test:         F=1.5001  , p=0.0529  , df_denom=2481, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.4762  , p=0.0571  , df_denom=2478, df_num=26
# ssr based chi2 test:   chi2=39.2024 , p=0.0466  , df=26
# likelihood ratio test: chi2=38.9019 , p=0.0498  , df=26
# parameter F test:         F=1.4762  , p=0.0571  , df_denom=2478, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.3890  , p=0.0877  , df_denom=2475, df_num=27
# ssr based chi2 test:   chi2=38.3360 , p=0.0727  , df=27
# likelihood ratio test: chi2=38.0485 , p=0.0771  , df=27
# parameter F test:         F=1.3890  , p=0.0877  , df_denom=2475, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.3419  , p=0.1085  , df_denom=2472, df_num=28
# ssr based chi2 test:   chi2=38.4389 , p=0.0904  , df=28
# likelihood ratio test: chi2=38.1497 , p=0.0956  , df=28
# parameter F test:         F=1.3419  , p=0.1085  , df_denom=2472, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.4327  , p=0.0632  , df_denom=2469, df_num=29
# ssr based chi2 test:   chi2=42.5422 , p=0.0502  , df=29
# likelihood ratio test: chi2=42.1882 , p=0.0540  , df=29
# parameter F test:         F=1.4327  , p=0.0632  , df_denom=2469, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.3809  , p=0.0818  , df_denom=2466, df_num=30
# ssr based chi2 test:   chi2=42.4504 , p=0.0655  , df=30
# likelihood ratio test: chi2=42.0978 , p=0.0702  , df=30
# parameter F test:         F=1.3809  , p=0.0818  , df_denom=2466, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.3509  , p=0.0938  , df_denom=2463, df_num=31
# ssr based chi2 test:   chi2=42.9490 , p=0.0750  , df=31
# likelihood ratio test: chi2=42.5880 , p=0.0804  , df=31
# parameter F test:         F=1.3509  , p=0.0938  , df_denom=2463, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.3377  , p=0.0980  , df_denom=2460, df_num=32
# ssr based chi2 test:   chi2=43.9362 , p=0.0778  , df=32
# likelihood ratio test: chi2=43.5583 , p=0.0836  , df=32
# parameter F test:         F=1.3377  , p=0.0980  , df_denom=2460, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.2668  , p=0.1421  , df_denom=2457, df_num=33
# ssr based chi2 test:   chi2=42.9428 , p=0.1152  , df=33
# likelihood ratio test: chi2=42.5816 , p=0.1227  , df=33
# parameter F test:         F=1.2668  , p=0.1421  , df_denom=2457, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.2705  , p=0.1363  , df_denom=2454, df_num=34
# ssr based chi2 test:   chi2=44.4101 , p=0.1090  , df=34
# likelihood ratio test: chi2=44.0237 , p=0.1166  , df=34
# parameter F test:         F=1.2705  , p=0.1363  , df_denom=2454, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.3525  , p=0.0816  , df_denom=2451, df_num=35
# ssr based chi2 test:   chi2=48.7072 , p=0.0617  , df=35
# likelihood ratio test: chi2=48.2428 , p=0.0674  , df=35
# parameter F test:         F=1.3525  , p=0.0816  , df_denom=2451, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.3008  , p=0.1090  , df_denom=2448, df_num=36
# ssr based chi2 test:   chi2=48.2256 , p=0.0837  , df=36
# likelihood ratio test: chi2=47.7702 , p=0.0907  , df=36
# parameter F test:         F=1.3008  , p=0.1090  , df_denom=2448, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.3044  , p=0.1040  , df_denom=2445, df_num=37
# ssr based chi2 test:   chi2=49.7447 , p=0.0786  , df=37
# likelihood ratio test: chi2=49.2601 , p=0.0856  , df=37
# parameter F test:         F=1.3044  , p=0.1040  , df_denom=2445, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.2693  , p=0.1260  , df_denom=2442, df_num=38
# ssr based chi2 test:   chi2=49.7527 , p=0.0960  , df=38
# likelihood ratio test: chi2=49.2678 , p=0.1042  , df=38
# parameter F test:         F=1.2693  , p=0.1260  , df_denom=2442, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.2362  , p=0.1506  , df_denom=2439, df_num=39
# ssr based chi2 test:   chi2=49.7728 , p=0.1157  , df=39
# likelihood ratio test: chi2=49.2872 , p=0.1251  , df=39
# parameter F test:         F=1.2362  , p=0.1506  , df_denom=2439, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.2120  , p=0.1707  , df_denom=2436, df_num=40
# ssr based chi2 test:   chi2=50.0907 , p=0.1317  , df=40
# likelihood ratio test: chi2=49.5988 , p=0.1421  , df=40
# parameter F test:         F=1.2120  , p=0.1707  , df_denom=2436, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.1890  , p=0.1921  , df_denom=2433, df_num=41
# ssr based chi2 test:   chi2=50.4135 , p=0.1488  , df=41
# likelihood ratio test: chi2=49.9151 , p=0.1602  , df=41
# parameter F test:         F=1.1890  , p=0.1921  , df_denom=2433, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.1589  , p=0.2248  , df_denom=2430, df_num=42
# ssr based chi2 test:   chi2=50.3759 , p=0.1759  , df=42
# likelihood ratio test: chi2=49.8780 , p=0.1887  , df=42
# parameter F test:         F=1.1589  , p=0.2248  , df_denom=2430, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.1777  , p=0.2002  , df_denom=2427, df_num=43
# ssr based chi2 test:   chi2=52.4553 , p=0.1529  , df=43
# likelihood ratio test: chi2=51.9156 , p=0.1653  , df=43
# parameter F test:         F=1.1777  , p=0.2002  , df_denom=2427, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.1451  , p=0.2381  , df_denom=2424, df_num=44
# ssr based chi2 test:   chi2=52.2361 , p=0.1844  , df=44
# likelihood ratio test: chi2=51.7006 , p=0.1984  , df=44
# parameter F test:         F=1.1451  , p=0.2381  , df_denom=2424, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.1365  , p=0.2478  , df_denom=2421, df_num=45
# ssr based chi2 test:   chi2=53.0642 , p=0.1912  , df=45
# likelihood ratio test: chi2=52.5115 , p=0.2058  , df=45
# parameter F test:         F=1.1365  , p=0.2478  , df_denom=2421, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.1645  , p=0.2095  , df_denom=2418, df_num=46
# ssr based chi2 test:   chi2=55.6280 , p=0.1563  , df=46
# likelihood ratio test: chi2=55.0208 , p=0.1701  , df=46
# parameter F test:         F=1.1645  , p=0.2095  , df_denom=2418, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.1811  , p=0.1876  , df_denom=2415, df_num=47
# ssr based chi2 test:   chi2=57.6936 , p=0.1364  , df=47
# likelihood ratio test: chi2=57.0405 , p=0.1497  , df=47
# parameter F test:         F=1.1811  , p=0.1876  , df_denom=2415, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.1601  , p=0.2110  , df_denom=2412, df_num=48
# ssr based chi2 test:   chi2=57.9238 , p=0.1545  , df=48
# likelihood ratio test: chi2=57.2653 , p=0.1691  , df=48
# parameter F test:         F=1.1601  , p=0.2110  , df_denom=2412, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.1465  , p=0.2269  , df_denom=2409, df_num=49
# ssr based chi2 test:   chi2=58.4851 , p=0.1663  , df=49
# likelihood ratio test: chi2=57.8136 , p=0.1818  , df=49
# parameter F test:         F=1.1465  , p=0.2269  , df_denom=2409, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.1217  , p=0.2601  , df_denom=2406, df_num=50
# ssr based chi2 test:   chi2=58.4407 , p=0.1931  , df=50
# likelihood ratio test: chi2=57.7699 , p=0.2101  , df=50
# parameter F test:         F=1.1217  , p=0.2601  , df_denom=2406, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=1.1181  , p=0.2640  , df_denom=2403, df_num=51
# ssr based chi2 test:   chi2=59.4667 , p=0.1946  , df=51
# likelihood ratio test: chi2=58.7721 , p=0.2122  , df=51
# parameter F test:         F=1.1181  , p=0.2640  , df_denom=2403, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=1.1619  , p=0.2011  , df_denom=2400, df_num=52
# ssr based chi2 test:   chi2=63.0611 , p=0.1400  , df=52
# likelihood ratio test: chi2=62.2804 , p=0.1556  , df=52
# parameter F test:         F=1.1619  , p=0.2011  , df_denom=2400, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=1.1277  , p=0.2464  , df_denom=2397, df_num=53
# ssr based chi2 test:   chi2=62.4377 , p=0.1759  , df=53
# likelihood ratio test: chi2=61.6720 , p=0.1937  , df=53
# parameter F test:         F=1.1277  , p=0.2464  , df_denom=2397, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=1.0902  , p=0.3045  , df_denom=2394, df_num=54
# ssr based chi2 test:   chi2=61.5525 , p=0.2240  , df=54
# likelihood ratio test: chi2=60.8079 , p=0.2442  , df=54
# parameter F test:         F=1.0902  , p=0.3045  , df_denom=2394, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=1.0724  , p=0.3345  , df_denom=2391, df_num=55
# ssr based chi2 test:   chi2=61.7209 , p=0.2484  , df=55
# likelihood ratio test: chi2=60.9719 , p=0.2699  , df=55
# parameter F test:         F=1.0724  , p=0.3345  , df_denom=2391, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=1.0730  , p=0.3325  , df_denom=2388, df_num=56
# ssr based chi2 test:   chi2=62.9289 , p=0.2445  , df=56
# likelihood ratio test: chi2=62.1502 , p=0.2664  , df=56
# parameter F test:         F=1.0730  , p=0.3325  , df_denom=2388, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=1.0636  , p=0.3489  , df_denom=2385, df_num=57
# ssr based chi2 test:   chi2=63.5467 , p=0.2569  , df=57
# likelihood ratio test: chi2=62.7525 , p=0.2797  , df=57
# parameter F test:         F=1.0636  , p=0.3489  , df_denom=2385, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=1.0626  , p=0.3500  , df_denom=2382, df_num=58
# ssr based chi2 test:   chi2=64.6550 , p=0.2556  , df=58
# likelihood ratio test: chi2=63.8328 , p=0.2790  , df=58
# parameter F test:         F=1.0626  , p=0.3500  , df_denom=2382, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=1.0541  , p=0.3655  , df_denom=2379, df_num=59
# ssr based chi2 test:   chi2=65.3010 , p=0.2671  , df=59
# likelihood ratio test: chi2=64.4620 , p=0.2915  , df=59
# parameter F test:         F=1.0541  , p=0.3655  , df_denom=2379, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=1.1174  , p=0.2517  , df_denom=2376, df_num=60
# ssr based chi2 test:   chi2=70.4563 , p=0.1675  , df=60
# likelihood ratio test: chi2=69.4806 , p=0.1884  , df=60
# parameter F test:         F=1.1174  , p=0.2517  , df_denom=2376, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=1.0986  , p=0.2816  , df_denom=2373, df_num=61
# ssr based chi2 test:   chi2=70.4891 , p=0.1900  , df=61
# likelihood ratio test: chi2=69.5121 , p=0.2127  , df=61
# parameter F test:         F=1.0986  , p=0.2816  , df_denom=2373, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=1.1245  , p=0.2376  , df_denom=2370, df_num=62
# ssr based chi2 test:   chi2=73.3967 , p=0.1525  , df=62
# likelihood ratio test: chi2=72.3378 , p=0.1735  , df=62
# parameter F test:         F=1.1245  , p=0.2376  , df_denom=2370, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=1.1960  , p=0.1409  , df_denom=2367, df_num=63
# ssr based chi2 test:   chi2=79.3896 , p=0.0796  , df=63
# likelihood ratio test: chi2=78.1522 , p=0.0946  , df=63
# parameter F test:         F=1.1960  , p=0.1409  , df_denom=2367, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=1.1822  , p=0.1550  , df_denom=2364, df_num=64
# ssr based chi2 test:   chi2=79.7921 , p=0.0880  , df=64
# likelihood ratio test: chi2=78.5418 , p=0.1044  , df=64
# parameter F test:         F=1.1822  , p=0.1550  , df_denom=2364, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=1.1620  , p=0.1787  , df_denom=2361, df_num=65
# ssr based chi2 test:   chi2=79.7229 , p=0.1034  , df=65
# likelihood ratio test: chi2=78.4742 , p=0.1217  , df=65
# parameter F test:         F=1.1620  , p=0.1787  , df_denom=2361, df_num=65
#
# Granger Causality
# number of lags (no zero) 66
# ssr based F test:         F=1.1887  , p=0.1442  , df_denom=2358, df_num=66
# ssr based chi2 test:   chi2=82.8793 , p=0.0783  , df=66
# likelihood ratio test: chi2=81.5303 , p=0.0942  , df=66
# parameter F test:         F=1.1887  , p=0.1442  , df_denom=2358, df_num=66
#
# Granger Causality
# number of lags (no zero) 67
# ssr based F test:         F=1.1799  , p=0.1530  , df_denom=2355, df_num=67
# ssr based chi2 test:   chi2=83.5850 , p=0.0829  , df=67
# likelihood ratio test: chi2=82.2127 , p=0.0998  , df=67
# parameter F test:         F=1.1799  , p=0.1530  , df_denom=2355, df_num=67
#
# Granger Causality
# number of lags (no zero) 68
# ssr based F test:         F=1.1795  , p=0.1520  , df_denom=2352, df_num=68
# ssr based chi2 test:   chi2=84.8759 , p=0.0810  , df=68
# likelihood ratio test: chi2=83.4608 , p=0.0980  , df=68
# parameter F test:         F=1.1795  , p=0.1520  , df_denom=2352, df_num=68
#
# Granger Causality
# number of lags (no zero) 69
# ssr based F test:         F=1.1929  , p=0.1349  , df_denom=2349, df_num=69
# ssr based chi2 test:   chi2=87.1837 , p=0.0687  , df=69
# likelihood ratio test: chi2=85.6909 , p=0.0844  , df=69
# parameter F test:         F=1.1929  , p=0.1349  , df_denom=2349, df_num=69
#
# Granger Causality
# number of lags (no zero) 70
# ssr based F test:         F=1.1820  , p=0.1459  , df_denom=2346, df_num=70
# ssr based chi2 test:   chi2=87.7134 , p=0.0747  , df=70
# likelihood ratio test: chi2=86.2021 , p=0.0915  , df=70
# parameter F test:         F=1.1820  , p=0.1459  , df_denom=2346, df_num=70
#
# Granger Causality
# number of lags (no zero) 71
# ssr based F test:         F=1.1871  , p=0.1385  , df_denom=2343, df_num=71
# ssr based chi2 test:   chi2=89.4267 , p=0.0688  , df=71
# likelihood ratio test: chi2=87.8558 , p=0.0852  , df=71
# parameter F test:         F=1.1871  , p=0.1385  , df_denom=2343, df_num=71
#
# Granger Causality
# number of lags (no zero) 72
# ssr based F test:         F=1.1757  , p=0.1507  , df_denom=2340, df_num=72
# ssr based chi2 test:   chi2=89.8922 , p=0.0753  , df=72
# likelihood ratio test: chi2=88.3045 , p=0.0930  , df=72
# parameter F test:         F=1.1757  , p=0.1507  , df_denom=2340, df_num=72
#
# Granger Causality
# number of lags (no zero) 73
# ssr based F test:         F=1.2027  , p=0.1185  , df_denom=2337, df_num=73
# ssr based chi2 test:   chi2=93.3210 , p=0.0547  , df=73
# likelihood ratio test: chi2=91.6107 , p=0.0694  , df=73
# parameter F test:         F=1.2027  , p=0.1185  , df_denom=2337, df_num=73
#
# Granger Causality
# number of lags (no zero) 74
# ssr based F test:         F=1.2962  , p=0.0475  , df_denom=2334, df_num=74
# ssr based chi2 test:   chi2=102.0384, p=0.0171  , df=74
# likelihood ratio test: chi2=99.9975 , p=0.0238  , df=74
# parameter F test:         F=1.2962  , p=0.0475  , df_denom=2334, df_num=74
#
# Granger Causality
# number of lags (no zero) 75
# ssr based F test:         F=1.3029  , p=0.0433  , df_denom=2331, df_num=75
# ssr based chi2 test:   chi2=104.0453, p=0.0149  , df=75
# likelihood ratio test: chi2=101.9236, p=0.0211  , df=75
# parameter F test:         F=1.3029  , p=0.0433  , df_denom=2331, df_num=75
#
# Granger Causality
# number of lags (no zero) 76
# ssr based F test:         F=1.2879  , p=0.0497  , df_denom=2328, df_num=76
# ssr based chi2 test:   chi2=104.3156, p=0.0173  , df=76
# likelihood ratio test: chi2=102.1821, p=0.0243  , df=76
# parameter F test:         F=1.2879  , p=0.0497  , df_denom=2328, df_num=76
#
# Granger Causality
# number of lags (no zero) 77
# ssr based F test:         F=1.2800  , p=0.0530  , df_denom=2325, df_num=77
# ssr based chi2 test:   chi2=105.1308, p=0.0183  , df=77
# likelihood ratio test: chi2=102.9636, p=0.0258  , df=77
# parameter F test:         F=1.2800  , p=0.0530  , df_denom=2325, df_num=77
#
# Granger Causality
# number of lags (no zero) 78
# ssr based F test:         F=1.2777  , p=0.0532  , df_denom=2322, df_num=78
# ssr based chi2 test:   chi2=106.4003, p=0.0180  , df=78
# likelihood ratio test: chi2=104.1802, p=0.0255  , df=78
# parameter F test:         F=1.2777  , p=0.0532  , df_denom=2322, df_num=78
#
# Granger Causality
# number of lags (no zero) 79
# ssr based F test:         F=1.2755  , p=0.0535  , df_denom=2319, df_num=79
# ssr based chi2 test:   chi2=107.6729, p=0.0177  , df=79
# likelihood ratio test: chi2=105.3993, p=0.0253  , df=79
# parameter F test:         F=1.2755  , p=0.0535  , df_denom=2319, df_num=79
#
# Granger Causality
# number of lags (no zero) 80
# ssr based F test:         F=1.2660  , p=0.0581  , df_denom=2316, df_num=80
# ssr based chi2 test:   chi2=108.3241, p=0.0192  , df=80
# likelihood ratio test: chi2=106.0223, p=0.0274  , df=80
# parameter F test:         F=1.2660  , p=0.0581  , df_denom=2316, df_num=80
#
# Granger Causality
# number of lags (no zero) 81
# ssr based F test:         F=1.2726  , p=0.0532  , df_denom=2313, df_num=81
# ssr based chi2 test:   chi2=110.3453, p=0.0168  , df=81
# likelihood ratio test: chi2=107.9571, p=0.0243  , df=81
# parameter F test:         F=1.2726  , p=0.0532  , df_denom=2313, df_num=81
#
# Granger Causality
# number of lags (no zero) 82
# ssr based F test:         F=1.2895  , p=0.0433  , df_denom=2310, df_num=82
# ssr based chi2 test:   chi2=113.2888, p=0.0126  , df=82
# likelihood ratio test: chi2=110.7725, p=0.0189  , df=82
# parameter F test:         F=1.2895  , p=0.0433  , df_denom=2310, df_num=82
#
# Granger Causality
# number of lags (no zero) 83
# ssr based F test:         F=1.2950  , p=0.0399  , df_denom=2307, df_num=83
# ssr based chi2 test:   chi2=115.2663, p=0.0111  , df=83
# likelihood ratio test: chi2=112.6617, p=0.0168  , df=83
# parameter F test:         F=1.2950  , p=0.0399  , df_denom=2307, df_num=83
#
# Granger Causality
# number of lags (no zero) 84
# ssr based F test:         F=1.2839  , p=0.0444  , df_denom=2304, df_num=84
# ssr based chi2 test:   chi2=115.7554, p=0.0124  , df=84
# likelihood ratio test: chi2=113.1280, p=0.0188  , df=84
# parameter F test:         F=1.2839  , p=0.0444  , df_denom=2304, df_num=84
#
# Granger Causality
# number of lags (no zero) 85
# ssr based F test:         F=1.2675  , p=0.0524  , df_denom=2301, df_num=85
# ssr based chi2 test:   chi2=115.7472, p=0.0149  , df=85
# likelihood ratio test: chi2=113.1190, p=0.0224  , df=85
# parameter F test:         F=1.2675  , p=0.0524  , df_denom=2301, df_num=85
#
# Granger Causality
# number of lags (no zero) 86
# ssr based F test:         F=1.2731  , p=0.0484  , df_denom=2298, df_num=86
# ssr based chi2 test:   chi2=117.7248, p=0.0131  , df=86
# likelihood ratio test: chi2=115.0064, p=0.0201  , df=86
# parameter F test:         F=1.2731  , p=0.0484  , df_denom=2298, df_num=86
#
# Granger Causality
# number of lags (no zero) 87
# ssr based F test:         F=1.2899  , p=0.0391  , df_denom=2295, df_num=87
# ssr based chi2 test:   chi2=120.7822, p=0.0097  , df=87
# likelihood ratio test: chi2=117.9220, p=0.0153  , df=87
# parameter F test:         F=1.2899  , p=0.0391  , df_denom=2295, df_num=87
#
# Granger Causality
# number of lags (no zero) 88
# ssr based F test:         F=1.2749  , p=0.0457  , df_denom=2292, df_num=88
# ssr based chi2 test:   chi2=120.8559, p=0.0116  , df=88
# likelihood ratio test: chi2=117.9911, p=0.0181  , df=88
# parameter F test:         F=1.2749  , p=0.0457  , df_denom=2292, df_num=88
#
# Granger Causality
# number of lags (no zero) 89
# ssr based F test:         F=1.2676  , p=0.0488  , df_denom=2289, df_num=89
# ssr based chi2 test:   chi2=121.6387, p=0.0123  , df=89
# likelihood ratio test: chi2=118.7361, p=0.0193  , df=89
# parameter F test:         F=1.2676  , p=0.0488  , df_denom=2289, df_num=89
#
# Granger Causality
# number of lags (no zero) 90
# ssr based F test:         F=1.2574  , p=0.0540  , df_denom=2286, df_num=90
# ssr based chi2 test:   chi2=122.1275, p=0.0137  , df=90
# likelihood ratio test: chi2=119.2008, p=0.0214  , df=90
# parameter F test:         F=1.2574  , p=0.0540  , df_denom=2286, df_num=90
#
# Granger Causality
# number of lags (no zero) 91
# ssr based F test:         F=1.2394  , p=0.0651  , df_denom=2283, df_num=91
# ssr based chi2 test:   chi2=121.8293, p=0.0171  , df=91
# likelihood ratio test: chi2=118.9155, p=0.0264  , df=91
# parameter F test:         F=1.2394  , p=0.0651  , df_denom=2283, df_num=91
#
# Granger Causality
# number of lags (no zero) 92
# ssr based F test:         F=1.2256  , p=0.0747  , df_denom=2280, df_num=92
# ssr based chi2 test:   chi2=121.9081, p=0.0201  , df=92
# likelihood ratio test: chi2=118.9894, p=0.0307  , df=92
# parameter F test:         F=1.2256  , p=0.0747  , df_denom=2280, df_num=92
#
# Granger Causality
# number of lags (no zero) 93
# ssr based F test:         F=1.2178  , p=0.0804  , df_denom=2277, df_num=93
# ssr based chi2 test:   chi2=122.5528, p=0.0217  , df=93
# likelihood ratio test: chi2=119.6025, p=0.0330  , df=93
# parameter F test:         F=1.2178  , p=0.0804  , df_denom=2277, df_num=93
#
# Granger Causality
# number of lags (no zero) 94
# ssr based F test:         F=1.2013  , p=0.0947  , df_denom=2274, df_num=94
# ssr based chi2 test:   chi2=122.3063, p=0.0265  , df=94
# likelihood ratio test: chi2=119.3665, p=0.0398  , df=94
# parameter F test:         F=1.2013  , p=0.0947  , df_denom=2274, df_num=94
#
# Granger Causality
# number of lags (no zero) 95
# ssr based F test:         F=1.1876  , p=0.1081  , df_denom=2271, df_num=95
# ssr based chi2 test:   chi2=122.3060, p=0.0311  , df=95
# likelihood ratio test: chi2=119.3651, p=0.0462  , df=95
# parameter F test:         F=1.1876  , p=0.1081  , df_denom=2271, df_num=95
#
# Granger Causality
# number of lags (no zero) 96
# ssr based F test:         F=1.1765  , p=0.1199  , df_denom=2268, df_num=96
# ssr based chi2 test:   chi2=122.5550, p=0.0351  , df=96
# likelihood ratio test: chi2=119.6011, p=0.0518  , df=96
# parameter F test:         F=1.1765  , p=0.1199  , df_denom=2268, df_num=96
#
# Granger Causality
# number of lags (no zero) 97
# ssr based F test:         F=1.1615  , p=0.1380  , df_denom=2265, df_num=97
# ssr based chi2 test:   chi2=122.3678, p=0.0418  , df=97
# likelihood ratio test: chi2=119.4217, p=0.0609  , df=97
# parameter F test:         F=1.1615  , p=0.1380  , df_denom=2265, df_num=97
#
# Granger Causality
# number of lags (no zero) 98
# ssr based F test:         F=1.1698  , p=0.1262  , df_denom=2262, df_num=98
# ssr based chi2 test:   chi2=124.6207, p=0.0360  , df=98
# likelihood ratio test: chi2=121.5657, p=0.0536  , df=98
# parameter F test:         F=1.1698  , p=0.1262  , df_denom=2262, df_num=98
#
# Granger Causality
# number of lags (no zero) 99
# ssr based F test:         F=1.1600  , p=0.1381  , df_denom=2259, df_num=99
# ssr based chi2 test:   chi2=124.9526, p=0.0400  , df=99
# likelihood ratio test: chi2=121.8803, p=0.0592  , df=99
# parameter F test:         F=1.1600  , p=0.1381  , df_denom=2259, df_num=99
#
# Granger Causality
# number of lags (no zero) 100
# ssr based F test:         F=1.1452  , p=0.1583  , df_denom=2256, df_num=100
# ssr based chi2 test:   chi2=124.7279, p=0.0476  , df=100
# likelihood ratio test: chi2=121.6653, p=0.0695  , df=100
# parameter F test:         F=1.1452  , p=0.1583  , df_denom=2256, df_num=100

# %%
def find_lags(test):
    lag_found = False
    lags = []
    
    for i in range(1, maxlag):
        p = test[i][0]['ssr_ftest'][1]
        if (p < 0.05):
            lags.append(test[i][0]['ssr_ftest'])
            lag_found = True

    if (lag_found == True):
        return lags
    else:
        print("lag not found")

# %%
lags_info = find_lags(test)

# %%
lags_info
# Out:
# [(6.854887048877872, 0.008892152923251908, 2553.0, 1),
#  (2.7282638599560327, 0.04256318812607709, 2547.0, 3),
#  (1.629021833476311, 0.03248569474635154, 2490.0, 22),
#  (1.5389502462969213, 0.048616272648732355, 2487.0, 23),
#  (1.5385389025190406, 0.045653272951460426, 2484.0, 24),
#  (1.2961527699351476, 0.047495157276531696, 2334.0, 74),
#  (1.30287128520494, 0.04330564929261734, 2331.0, 75),
#  (1.2879282783214345, 0.04968714930528524, 2328.0, 76),
#  (1.289465532662237, 0.04334812815319663, 2310.0, 82),
#  (1.295007065125162, 0.03990273388599102, 2307.0, 83),
#  (1.2838683290979036, 0.04440085239520086, 2304.0, 84),
#  (1.273053512344386, 0.048354679591573635, 2298.0, 86),
#  (1.289939706120427, 0.03905711823519204, 2295.0, 87),
#  (1.2749075486057169, 0.04566845123015441, 2292.0, 88),
#  (1.2676003226601216, 0.04881740528765871, 2289.0, 89)]
