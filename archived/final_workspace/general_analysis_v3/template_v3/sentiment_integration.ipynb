# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_colwidth', 100)

from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# # Import Twitter Sentiment Data

# %%
path_twitter_sentiment = '../../../../data/team/NLTK Time Series/sentiment_nltk_fixed_final.csv'

# %%
twitter_sentiment = pd.read_csv(path_twitter_sentiment)
twitter_sentiment.drop('Unnamed: 0', axis=1, inplace=True)
twitter_sentiment['Date'] = pd.to_datetime(twitter_sentiment['CreatedAt'].str[:10], errors='coerce')
twitter_sentiment.set_index('Date',inplace=True);
twitter_sentiment.drop('CreatedAt', axis=1, inplace=True)

# %%
twitter_sentiment
# Out:
#                     company  \
# Date
# 2021-04-01      first_solar
# 2021-03-31      first_solar
# 2021-03-31      first_solar
# 2021-03-31      first_solar
# 2021-03-31      first_solar
# ...                     ...
# 2011-01-10  meridian_energy
# 2011-01-07  meridian_energy
# 2011-01-06  meridian_energy
# 2011-01-02  meridian_energy
# NaT                     NaN
#
#                                                                                                       TweetText  \
# Date
# 2021-04-01  First Solar Completes Sale of North American O&amp;M Business to NovaSource $FSLR https://t.co/j...
# 2021-03-31  $ALYI To Reveal New Significant Investment In Company From Leading Texas Based Private Equity Fu...
# 2021-03-31  @SolarPowerEU @renewableH2EU @EU_Commission @Akuo_Energy @enelgreenpower @EdpRenewables @Enapter...
# 2021-03-31                                                  $FSLR sector move confirmed https://t.co/h08Dwn5CIF
# ...

# %%
twitter_sentiment_daily = twitter_sentiment.groupby(['Date']).mean()

# %%
twitter_sentiment_daily
# Out:
#                  neg       neu       pos  compound
# Date
# 2011-01-01  0.006700  0.908400  0.084900  0.133425
# 2011-01-02  0.013154  0.709000  0.277846  0.482962
# 2011-01-03  0.014765  0.799088  0.186147  0.283909
# 2011-01-04  0.029500  0.772545  0.197955  0.271441
# 2011-01-05  0.000000  0.837762  0.162238  0.296990
# ...              ...       ...       ...       ...
# 2021-03-28  0.057020  0.785038  0.157945  0.213032
# 2021-03-29  0.057377  0.797468  0.145151  0.185867
# 2021-03-30  0.049820  0.792677  0.157501  0.213929
# 2021-03-31  0.056327  0.791030  0.152643  0.211125
# 2021-04-01  0.030713  0.819483  0.146743  0.235765
#
# [3743 rows x 4 columns]

# %%
twitter_sentiment_daily.to_csv('twitter_sentiment_daily_all.csv')
