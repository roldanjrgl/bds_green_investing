# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Data Cleaning

# %%
stock_prices = pd.read_csv('../../data/team/Stock Price Time Series/stock_prices_time_series_converged.csv')

# %%
stock_prices.drop(columns=['Unnamed: 9','Unnamed: 10'], inplace=True)

# %%
stock_prices.drop(columns=['mean delta', '-0.073169045'], inplace=True)

# %% [markdown]
# # Index datetime

# %%
stock_prices
# Out:
#       Ticker timestamp   open    high    low  close   volume  delta  deltaNorm
# 0       SPWR   4/23/21  28.07  29.420  27.51  29.01  3461071   0.94   0.243455
# 1       SPWR   4/22/21  27.92  28.980  27.40  27.66  4502055  -0.26  -0.044894
# 2       SPWR   4/21/21  25.60  27.410  25.02  27.38  2589691   1.78   0.445300
# 3       SPWR   4/20/21  26.50  26.898  25.17  25.93  3248555  -0.57  -0.119384
# 4       SPWR   4/19/21  27.45  28.220  26.07  26.54  3803556  -0.91  -0.201083
# ...      ...       ...    ...     ...    ...    ...      ...    ...        ...
# 32000  VWDRY   7/19/07  24.00  24.000  24.00  24.00     3763   0.00   0.017582
# 32001  VWDRY   7/18/07  23.25  23.450  23.25  23.25     8735   0.00   0.017582
# 32002  VWDRY   7/17/07  23.40  23.400  23.40  23.40     4464   0.00   0.017582
# 32003  VWDRY   7/16/07  23.55  23.550  23.55  23.55    10016   0.00   0.017582
# 32004  VWDRY   7/13/07  23.50  23.500  23.50  23.50     4679   0.00   0.017582
#
# ...

# %%
stock_prices['Ticker'].unique()
# Out:
# array(['SPWR', 'COENF', 'DNNGY', 'DQ', 'ENPH', 'FSLR', 'GCTAY', 'ORA',
#        'RUN', 'SCTY', 'TSLA', 'VWDRY'], dtype=object)

# %%
stock_prices.index = pd.to_datetime(stock_prices['timestamp'])

# %%
stock_prices['volume']['2019-01-01':'2020-01-01'].plot(figsize=(12,6));

# %%
spwr_prices = stock_prices[(stock_prices['Ticker'] == 'SPWR')]

# %%
spwr_prices.drop(columns='timestamp', inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
spwr_prices
# Out:
#            Ticker   open    high    low  close    volume  delta  deltaNorm
# timestamp
# 2021-04-23   SPWR  28.07  29.420  27.51  29.01   3461071   0.94   0.243455
# 2021-04-22   SPWR  27.92  28.980  27.40  27.66   4502055  -0.26  -0.044894
# 2021-04-21   SPWR  25.60  27.410  25.02  27.38   2589691   1.78   0.445300
# 2021-04-20   SPWR  26.50  26.898  25.17  25.93   3248555  -0.57  -0.119384
# 2021-04-19   SPWR  27.45  28.220  26.07  26.54   3803556  -0.91  -0.201083
# ...           ...    ...     ...    ...    ...       ...    ...        ...
# 2005-11-23   SPWR  25.15  25.580  25.02  25.14    510000  -0.01   0.015179
# 2005-11-22   SPWR  26.73  26.730  25.03  25.10    375900  -1.63  -0.374093
# 2005-11-21   SPWR  27.10  27.950  25.75  26.60    571700  -0.50  -0.102564
# 2005-11-18   SPWR  25.55  27.510  24.80  27.10   2155300   1.55   0.390033
# 2005-11-17   SPWR  28.00  28.010  24.81  25.45  10566900  -2.55  -0.595160
#
# [3883 rows x 8 columns]

# %%
spwr_prices['high'].plot(figsize=(12,6));

# %%
stock_prices[(stock_prices['Ticker'] == 'SPWR')]['high'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
stock_prices[(stock_prices['Ticker'] == 'COENF')]['high'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
stock_prices[(stock_prices['Ticker'] == 'COENF')]['high'].plot(figsize=(12,6))

# %%
stock_prices['Ticker'].unique()
# Out:
# array(['SPWR', 'COENF', 'DNNGY', 'DQ', 'ENPH', 'FSLR', 'GCTAY', 'ORA',
#        'RUN', 'SCTY', 'TSLA', 'VWDRY'], dtype=object)

# %%
stock_prices[(stock_prices['Ticker'] == 'DNNGY')]['high'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
stock_prices[(stock_prices['Ticker'] == 'DQ')]['high'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
stock_prices[(stock_prices['Ticker'] == 'SPWR')]['high'].plot(figsize=(16,6))
stock_prices[(stock_prices['Ticker'] == 'COENF')]['high'].plot(figsize=(16,6))
stock_prices[(stock_prices['Ticker'] == 'DNNGY')]['high'].plot(figsize=(16,6))
stock_prices[(stock_prices['Ticker'] == 'DQ')]['high'].plot(figsize=(16,6))
stock_prices[(stock_prices['Ticker'] == 'FSLR')]['high'].plot(figsize=(16,6))
stock_prices[(stock_prices['Ticker'] == 'GCT')]['high'].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
stock_prices['Ticker'].unique()
# Out:
# array(['SPWR', 'COENF', 'DNNGY', 'DQ', 'ENPH', 'FSLR', 'GCTAY', 'ORA',
#        'RUN', 'SCTY', 'TSLA', 'VWDRY'], dtype=object)

# %%
ax = stock_prices[(stock_prices['Ticker'] == 'SPWR')]['high'].plot(figsize=(16,6))
stock_prices[(stock_prices['Ticker'] == 'COENF')]['high'].plot(ax=ax, figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
stock_prices[(stock_prices['Ticker'] == 'SPWR')]['high']
# Out:
# timestamp
# 2021-04-23    29.420
# 2021-04-22    28.980
# 2021-04-21    27.410
# 2021-04-20    26.898
# 2021-04-19    28.220
#                ...
# 2005-11-23    25.580
# 2005-11-22    26.730
# 2005-11-21    27.950
# 2005-11-18    27.510
# 2005-11-17    28.010
# Name: high, Length: 3883, dtype: float64
