# %%
# create an autocorrelation plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

# %% [markdown]
# # Import Dataset

# %%
path = './GCTAY.csv'

# %%
series = read_csv(path, header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
print(type(series))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Close

# %%
autocorrelation_plot(series[["close"]])
pyplot.show()

# %% [markdown]
# # Delta

# %%
autocorrelation_plot(series[["delta"]])
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-00847626f840> in <module>
# ----> 1 autocorrelation_plot(series[["delta"]])
#       2 pyplot.show()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['delta'], dtype='object')] are in the [columns]"

# %% [markdown]
# # Volume

# %%
autocorrelation_plot(series[["volume"]])
pyplot.show()

# %% [markdown]
# # Open

# %%
autocorrelation_plot(series[["open"]])
pyplot.show()

# %% [markdown]
# # High

# %%
autocorrelation_plot(series[["high"]])
pyplot.show()

# %% [markdown]
# # Low

# %%
autocorrelation_plot(series[["low"]])
pyplot.show()

# %%
import matplotlib.pyplot as plt
import pandas
from pandas.plotting import autocorrelation_plot
import numpy as np
import pandas as pd

plt.figure();

spacing = np.linspace(-9 * np.pi, 9 * np.pi, num=1000)

data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(spacing))
print(data)

autocorrelation_plot(data);
# Out:
# 0      0.113895
# 1      0.327267
# 2     -0.027511
# 3      0.005035
# 4     -0.010543
#          ...
# 995    0.416066
# 996    0.534021
# 997    0.227055
# 998    0.709163
# 999    0.141840
# Length: 1000, dtype: float64

# %%
np.random.seed(5)
x = np.cumsum(np.random.normal(loc=1, scale=5, size=50))
s = pd.Series(x)
s.plot()
# Out:
# <AxesSubplot:>

# %%
pd.plotting.lag_plot(s, lag=1)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
autocorrelation_plot(s);

# %%
import matplotlib.pyplot as plt
import numpy as np


# Fixing random state for reproducibility
np.random.seed(19680801)


x, y = np.random.randn(2, 100)
fig, [ax1, ax2] = plt.subplots(2, 1, sharex=True)
ax1.xcorr(series[["low"]].to_numpy().flatten(), series[["delta"]].to_numpy().flatten(), usevlines=True, maxlags=50, normed=True, lw=2)
ax1.grid(True)

#ax2.acorr(series[["low"]].to_numpy().flatten(), usevlines=True, normed=True, maxlags=50, lw=2)
ax2.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-004cb111f1d4> in <module>
#       9 x, y = np.random.randn(2, 100)
#      10 fig, [ax1, ax2] = plt.subplots(2, 1, sharex=True)
# ---> 11 ax1.xcorr(series[["low"]].to_numpy().flatten(), series[["delta"]].to_numpy().flatten(), usevlines=True, maxlags=50, normed=True, lw=2)
#      12 ax1.grid(True)
#      13
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['delta'], dtype='object')] are in the [columns]"

# %%
series = read_csv('D://NYU//Semester 2//Big Data Science//Project Idea//Final Project//Code Testing//TS//STP_CSV.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
