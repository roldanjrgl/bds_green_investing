# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_colwidth', 100)

from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# # Import data

# %%
fslr = pd.read_csv('./data_first_solar_FSLR.csv')
gctay = pd.read_csv('./data_siemens_gamesa_GCTAY.csv')
spwr = pd.read_csv('./data_sunpower_SPWR.csv')
run = pd.read_csv('./data_sunrun_RUN.csv')
plug = pd.read_csv('./data_plug_power_PLUG.csv')

# %% [markdown]
# ## Set datatime index

# %%
def set_datetime_index(df):
    df['date'] = pd.to_datetime(df['Date'], errors='coerce')
    df.set_index('date', inplace=True)
    df.drop('Date', axis=1, inplace=True)
    return df

# %%
fslr = set_datetime_index(fslr)
gctay = set_datetime_index(gctay)
spwr = set_datetime_index(spwr)
run = set_datetime_index(run)
plug = set_datetime_index(plug)

# %% [markdown]
# # Import data normalized

# %%
fslr_normalized = pd.read_csv('./data_first_solar_FSLR_normalized.csv')
gctay_normalized = pd.read_csv('./data_siemens_gamesa_GCTAY_normalized.csv')
spwr_normalized = pd.read_csv('./data_sunpower_SPWR_normalized.csv')
run_normalized = pd.read_csv('./data_sunrun_RUN_normalized.csv')
plug_normalized = pd.read_csv('./data_plug_power_PLUG_normalized.csv')

# %%
fslr_normalized = set_datetime_index(fslr_normalized)
gctay_normalized = set_datetime_index(gctay_normalized)
spwr_normalized = set_datetime_index(spwr_normalized)
run_normalized = set_datetime_index(run_normalized)
plug_normalized = set_datetime_index(plug_normalized)

# %% [markdown]
# # Granger Tests - FSLR

# %%
maxlag = 100
ticker = 'FSLR'
series = 'neg_sentiment'

# %%
input_data = np.asarray(fslr[['closing_price', series]])
test = grangercausalitytests(input_data, maxlag, addconst = True, verbose=True);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0899  , p=0.0045  , df_denom=2536, df_num=1
# ssr based chi2 test:   chi2=8.0994  , p=0.0044  , df=1
# likelihood ratio test: chi2=8.0865  , p=0.0045  , df=1
# parameter F test:         F=8.0899  , p=0.0045  , df_denom=2536, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.6287  , p=0.0098  , df_denom=2533, df_num=2
# ssr based chi2 test:   chi2=9.2757  , p=0.0097  , df=2
# likelihood ratio test: chi2=9.2588  , p=0.0098  , df=2
# parameter F test:         F=4.6287  , p=0.0098  , df_denom=2533, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.5041  , p=0.0148  , df_denom=2530, df_num=3
# ssr based chi2 test:   chi2=10.5415 , p=0.0145  , df=3
# likelihood ratio test: chi2=10.5197 , p=0.0146  , df=3
# parameter F test:         F=3.5041  , p=0.0148  , df_denom=2530, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.6045  , p=0.0342  , df_denom=2527, df_num=4
# ssr based chi2 test:   chi2=10.4551 , p=0.0334  , df=4
# likelihood ratio test: chi2=10.4336 , p=0.0337  , df=4
# parameter F test:         F=2.6045  , p=0.0342  , df_denom=2527, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0794  , p=0.0651  , df_denom=2524, df_num=5
# ssr based chi2 test:   chi2=10.4423 , p=0.0636  , df=5
# likelihood ratio test: chi2=10.4209 , p=0.0642  , df=5
# parameter F test:         F=2.0794  , p=0.0651  , df_denom=2524, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0220  , p=0.0595  , df_denom=2521, df_num=6
# ssr based chi2 test:   chi2=12.1945 , p=0.0578  , df=6
# likelihood ratio test: chi2=12.1652 , p=0.0584  , df=6
# parameter F test:         F=2.0220  , p=0.0595  , df_denom=2521, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0231  , p=0.0488  , df_denom=2518, df_num=7
# ssr based chi2 test:   chi2=14.2463 , p=0.0470  , df=7
# likelihood ratio test: chi2=14.2063 , p=0.0476  , df=7
# parameter F test:         F=2.0231  , p=0.0488  , df_denom=2518, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.2308  , p=0.0227  , df_denom=2515, df_num=8
# ssr based chi2 test:   chi2=17.9671 , p=0.0215  , df=8
# likelihood ratio test: chi2=17.9037 , p=0.0220  , df=8
# parameter F test:         F=2.2308  , p=0.0227  , df_denom=2515, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0080  , p=0.0348  , df_denom=2512, df_num=9
# ssr based chi2 test:   chi2=18.2084 , p=0.0328  , df=9
# likelihood ratio test: chi2=18.1432 , p=0.0335  , df=9
# parameter F test:         F=2.0080  , p=0.0348  , df_denom=2512, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7910  , p=0.0571  , df_denom=2509, df_num=10
# ssr based chi2 test:   chi2=18.0603 , p=0.0540  , df=10
# likelihood ratio test: chi2=17.9961 , p=0.0550  , df=10
# parameter F test:         F=1.7910  , p=0.0571  , df_denom=2509, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.7541  , p=0.0567  , df_denom=2506, df_num=11
# ssr based chi2 test:   chi2=19.4717 , p=0.0531  , df=11
# likelihood ratio test: chi2=19.3971 , p=0.0543  , df=11
# parameter F test:         F=1.7541  , p=0.0567  , df_denom=2506, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.6281  , p=0.0772  , df_denom=2503, df_num=12
# ssr based chi2 test:   chi2=19.7322 , p=0.0723  , df=12
# likelihood ratio test: chi2=19.6556 , p=0.0739  , df=12
# parameter F test:         F=1.6281  , p=0.0772  , df_denom=2503, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.9960  , p=0.0177  , df_denom=2500, df_num=13
# ssr based chi2 test:   chi2=26.2282 , p=0.0158  , df=13
# likelihood ratio test: chi2=26.0930 , p=0.0165  , df=13
# parameter F test:         F=1.9960  , p=0.0177  , df_denom=2500, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.0386  , p=0.0124  , df_denom=2497, df_num=14
# ssr based chi2 test:   chi2=28.8721 , p=0.0109  , df=14
# likelihood ratio test: chi2=28.7084 , p=0.0114  , df=14
# parameter F test:         F=2.0386  , p=0.0124  , df_denom=2497, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.7179  , p=0.0413  , df_denom=2494, df_num=15
# ssr based chi2 test:   chi2=26.0883 , p=0.0371  , df=15
# likelihood ratio test: chi2=25.9545 , p=0.0385  , df=15
# parameter F test:         F=1.7179  , p=0.0413  , df_denom=2494, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.5388  , p=0.0778  , df_denom=2491, df_num=16
# ssr based chi2 test:   chi2=24.9466 , p=0.0708  , df=16
# likelihood ratio test: chi2=24.8241 , p=0.0730  , df=16
# parameter F test:         F=1.5388  , p=0.0778  , df_denom=2491, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.5617  , p=0.0660  , df_denom=2488, df_num=17
# ssr based chi2 test:   chi2=26.9232 , p=0.0592  , df=17
# likelihood ratio test: chi2=26.7805 , p=0.0614  , df=17
# parameter F test:         F=1.5617  , p=0.0660  , df_denom=2488, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.4425  , p=0.1018  , df_denom=2485, df_num=18
# ssr based chi2 test:   chi2=26.3508 , p=0.0920  , df=18
# likelihood ratio test: chi2=26.2141 , p=0.0950  , df=18
# parameter F test:         F=1.4425  , p=0.1018  , df_denom=2485, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.7319  , p=0.0253  , df_denom=2482, df_num=19
# ssr based chi2 test:   chi2=33.4232 , p=0.0215  , df=19
# likelihood ratio test: chi2=33.2036 , p=0.0228  , df=19
# parameter F test:         F=1.7319  , p=0.0253  , df_denom=2482, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.6545  , p=0.0338  , df_denom=2479, df_num=20
# ssr based chi2 test:   chi2=33.6382 , p=0.0287  , df=20
# likelihood ratio test: chi2=33.4157 , p=0.0304  , df=20
# parameter F test:         F=1.6545  , p=0.0338  , df_denom=2479, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.8078  , p=0.0135  , df_denom=2476, df_num=21
# ssr based chi2 test:   chi2=38.6235 , p=0.0109  , df=21
# likelihood ratio test: chi2=38.3303 , p=0.0118  , df=21
# parameter F test:         F=1.8078  , p=0.0135  , df_denom=2476, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.6264  , p=0.0329  , df_denom=2473, df_num=22
# ssr based chi2 test:   chi2=36.4322 , p=0.0273  , df=22
# likelihood ratio test: chi2=36.1711 , p=0.0291  , df=22
# parameter F test:         F=1.6264  , p=0.0329  , df_denom=2473, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.6072  , p=0.0337  , df_denom=2470, df_num=23
# ssr based chi2 test:   chi2=37.6684 , p=0.0276  , df=23
# likelihood ratio test: chi2=37.3893 , p=0.0296  , df=23
# parameter F test:         F=1.6072  , p=0.0337  , df_denom=2470, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.5550  , p=0.0417  , df_denom=2467, df_num=24
# ssr based chi2 test:   chi2=38.0617 , p=0.0342  , df=24
# likelihood ratio test: chi2=37.7766 , p=0.0365  , df=24
# parameter F test:         F=1.5550  , p=0.0417  , df_denom=2467, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.5312  , p=0.0446  , df_denom=2464, df_num=25
# ssr based chi2 test:   chi2=39.0712 , p=0.0362  , df=25
# likelihood ratio test: chi2=38.7708 , p=0.0388  , df=25
# parameter F test:         F=1.5312  , p=0.0446  , df_denom=2464, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.5625  , p=0.0349  , df_denom=2461, df_num=26
# ssr based chi2 test:   chi2=41.4996 , p=0.0276  , df=26
# likelihood ratio test: chi2=41.1608 , p=0.0299  , df=26
# parameter F test:         F=1.5625  , p=0.0349  , df_denom=2461, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.5696  , p=0.0312  , df_denom=2458, df_num=27
# ssr based chi2 test:   chi2=43.3262 , p=0.0242  , df=27
# likelihood ratio test: chi2=42.9570 , p=0.0264  , df=27
# parameter F test:         F=1.5696  , p=0.0312  , df_denom=2458, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.5667  , p=0.0297  , df_denom=2455, df_num=28
# ssr based chi2 test:   chi2=44.8865 , p=0.0227  , df=28
# likelihood ratio test: chi2=44.4901 , p=0.0248  , df=28
# parameter F test:         F=1.5667  , p=0.0297  , df_denom=2455, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.6326  , p=0.0180  , df_denom=2452, df_num=29
# ssr based chi2 test:   chi2=48.4861 , p=0.0131  , df=29
# likelihood ratio test: chi2=48.0239 , p=0.0146  , df=29
# parameter F test:         F=1.6326  , p=0.0180  , df_denom=2452, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.5674  , p=0.0258  , df_denom=2449, df_num=30
# ssr based chi2 test:   chi2=48.1920 , p=0.0190  , df=30
# likelihood ratio test: chi2=47.7352 , p=0.0211  , df=30
# parameter F test:         F=1.5674  , p=0.0258  , df_denom=2449, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.5165  , p=0.0339  , df_denom=2446, df_num=31
# ssr based chi2 test:   chi2=48.2215 , p=0.0251  , df=31
# likelihood ratio test: chi2=47.7640 , p=0.0277  , df=31
# parameter F test:         F=1.5165  , p=0.0339  , df_denom=2446, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.4248  , p=0.0580  , df_denom=2443, df_num=32
# ssr based chi2 test:   chi2=46.8077 , p=0.0441  , df=32
# likelihood ratio test: chi2=46.3762 , p=0.0482  , df=32
# parameter F test:         F=1.4248  , p=0.0580  , df_denom=2443, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.3942  , p=0.0675  , df_denom=2440, df_num=33
# ssr based chi2 test:   chi2=47.2725 , p=0.0513  , df=33
# likelihood ratio test: chi2=46.8324 , p=0.0560  , df=33
# parameter F test:         F=1.3942  , p=0.0675  , df_denom=2440, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.4922  , p=0.0338  , df_denom=2437, df_num=34
# ssr based chi2 test:   chi2=52.1698 , p=0.0239  , df=34
# likelihood ratio test: chi2=51.6342 , p=0.0268  , df=34
# parameter F test:         F=1.4922  , p=0.0338  , df_denom=2437, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.4153  , p=0.0544  , df_denom=2434, df_num=35
# ssr based chi2 test:   chi2=50.9816 , p=0.0396  , df=35
# likelihood ratio test: chi2=50.4698 , p=0.0438  , df=35
# parameter F test:         F=1.4153  , p=0.0544  , df_denom=2434, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.4249  , p=0.0489  , df_denom=2431, df_num=36
# ssr based chi2 test:   chi2=52.8354 , p=0.0348  , df=36
# likelihood ratio test: chi2=52.2857 , p=0.0388  , df=36
# parameter F test:         F=1.4249  , p=0.0489  , df_denom=2431, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.4553  , p=0.0377  , df_denom=2428, df_num=37
# ssr based chi2 test:   chi2=55.5097 , p=0.0258  , df=37
# likelihood ratio test: chi2=54.9031 , p=0.0293  , df=37
# parameter F test:         F=1.4553  , p=0.0377  , df_denom=2428, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.3886  , p=0.0580  , df_denom=2425, df_num=38
# ssr based chi2 test:   chi2=54.4418 , p=0.0408  , df=38
# likelihood ratio test: chi2=53.8580 , p=0.0457  , df=38
# parameter F test:         F=1.3886  , p=0.0580  , df_denom=2425, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.3067  , p=0.0974  , df_denom=2422, df_num=39
# ssr based chi2 test:   chi2=52.6253 , p=0.0713  , df=39
# likelihood ratio test: chi2=52.0793 , p=0.0785  , df=39
# parameter F test:         F=1.3067  , p=0.0974  , df_denom=2422, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.2915  , p=0.1048  , df_denom=2419, df_num=40
# ssr based chi2 test:   chi2=53.3911 , p=0.0764  , df=40
# likelihood ratio test: chi2=52.8290 , p=0.0842  , df=40
# parameter F test:         F=1.2915  , p=0.1048  , df_denom=2419, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.3093  , p=0.0910  , df_denom=2416, df_num=41
# ssr based chi2 test:   chi2=55.5243 , p=0.0645  , df=41
# likelihood ratio test: chi2=54.9164 , p=0.0718  , df=41
# parameter F test:         F=1.3093  , p=0.0910  , df_denom=2416, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.2449  , p=0.1354  , df_denom=2413, df_num=42
# ssr based chi2 test:   chi2=54.1284 , p=0.0994  , df=42
# likelihood ratio test: chi2=53.5503 , p=0.1090  , df=42
# parameter F test:         F=1.2449  , p=0.1354  , df_denom=2413, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.2208  , p=0.1548  , df_denom=2410, df_num=43
# ssr based chi2 test:   chi2=54.3903 , p=0.1142  , df=43
# likelihood ratio test: chi2=53.8064 , p=0.1250  , df=43
# parameter F test:         F=1.2208  , p=0.1548  , df_denom=2410, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.1965  , p=0.1770  , df_denom=2407, df_num=44
# ssr based chi2 test:   chi2=54.5949 , p=0.1315  , df=44
# likelihood ratio test: chi2=54.0064 , p=0.1434  , df=44
# parameter F test:         F=1.1965  , p=0.1770  , df_denom=2407, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.1706  , p=0.2041  , df_denom=2404, df_num=45
# ssr based chi2 test:   chi2=54.6720 , p=0.1530  , df=45
# likelihood ratio test: chi2=54.0816 , p=0.1663  , df=45
# parameter F test:         F=1.1706  , p=0.2041  , df_denom=2404, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.1412  , p=0.2396  , df_denom=2401, df_num=46
# ssr based chi2 test:   chi2=54.5275 , p=0.1820  , df=46
# likelihood ratio test: chi2=53.9399 , p=0.1968  , df=46
# parameter F test:         F=1.1412  , p=0.2396  , df_denom=2401, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.1232  , p=0.2629  , df_denom=2398, df_num=47
# ssr based chi2 test:   chi2=54.8813 , p=0.2006  , df=47
# likelihood ratio test: chi2=54.2859 , p=0.2166  , df=47
# parameter F test:         F=1.1232  , p=0.2629  , df_denom=2398, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.1526  , p=0.2206  , df_denom=2395, df_num=48
# ssr based chi2 test:   chi2=57.5664 , p=0.1623  , df=48
# likelihood ratio test: chi2=56.9116 , p=0.1773  , df=48
# parameter F test:         F=1.1526  , p=0.2206  , df_denom=2395, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.3226  , p=0.0671  , df_denom=2392, df_num=49
# ssr based chi2 test:   chi2=67.4917 , p=0.0410  , df=49
# likelihood ratio test: chi2=66.5936 , p=0.0479  , df=49
# parameter F test:         F=1.3226  , p=0.0671  , df_denom=2392, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.3417  , p=0.0561  , df_denom=2389, df_num=50
# ssr based chi2 test:   chi2=69.9194 , p=0.0328  , df=50
# likelihood ratio test: chi2=68.9557 , p=0.0390  , df=50
# parameter F test:         F=1.3417  , p=0.0561  , df_denom=2389, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=1.2983  , p=0.0773  , df_denom=2386, df_num=51
# ssr based chi2 test:   chi2=69.0714 , p=0.0467  , df=51
# likelihood ratio test: chi2=68.1303 , p=0.0547  , df=51
# parameter F test:         F=1.2983  , p=0.0773  , df_denom=2386, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=1.2878  , p=0.0821  , df_denom=2383, df_num=52
# ssr based chi2 test:   chi2=69.9188 , p=0.0493  , df=52
# likelihood ratio test: chi2=68.9544 , p=0.0578  , df=52
# parameter F test:         F=1.2878  , p=0.0821  , df_denom=2383, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=1.2224  , p=0.1319  , df_denom=2380, df_num=53
# ssr based chi2 test:   chi2=67.6989 , p=0.0842  , df=53
# likelihood ratio test: chi2=66.7939 , p=0.0965  , df=53
# parameter F test:         F=1.2224  , p=0.1319  , df_denom=2380, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=1.2122  , p=0.1399  , df_denom=2377, df_num=54
# ssr based chi2 test:   chi2=68.4581 , p=0.0891  , df=54
# likelihood ratio test: chi2=67.5325 , p=0.1021  , df=54
# parameter F test:         F=1.2122  , p=0.1399  , df_denom=2377, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=1.2066  , p=0.1437  , df_denom=2374, df_num=55
# ssr based chi2 test:   chi2=69.4657 , p=0.0907  , df=55
# likelihood ratio test: chi2=68.5125 , p=0.1042  , df=55
# parameter F test:         F=1.2066  , p=0.1437  , df_denom=2374, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=1.2202  , p=0.1283  , df_denom=2371, df_num=56
# ssr based chi2 test:   chi2=71.5877 , p=0.0783  , df=56
# likelihood ratio test: chi2=70.5755 , p=0.0909  , df=56
# parameter F test:         F=1.2202  , p=0.1283  , df_denom=2371, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=1.2001  , p=0.1468  , df_denom=2368, df_num=57
# ssr based chi2 test:   chi2=71.7291 , p=0.0906  , df=57
# likelihood ratio test: chi2=70.7126 , p=0.1047  , df=57
# parameter F test:         F=1.2001  , p=0.1468  , df_denom=2368, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=1.2139  , p=0.1309  , df_denom=2365, df_num=58
# ssr based chi2 test:   chi2=73.8867 , p=0.0779  , df=58
# likelihood ratio test: chi2=72.8083 , p=0.0912  , df=58
# parameter F test:         F=1.2139  , p=0.1309  , df_denom=2365, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=1.2257  , p=0.1178  , df_denom=2362, df_num=59
# ssr based chi2 test:   chi2=75.9576 , p=0.0678  , df=59
# likelihood ratio test: chi2=74.8181 , p=0.0803  , df=59
# parameter F test:         F=1.2257  , p=0.1178  , df_denom=2362, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=1.1897  , p=0.1530  , df_denom=2359, df_num=60
# ssr based chi2 test:   chi2=75.0412 , p=0.0914  , df=60
# likelihood ratio test: chi2=73.9283 , p=0.1067  , df=60
# parameter F test:         F=1.1897  , p=0.1530  , df_denom=2359, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=1.2321  , p=0.1087  , df_denom=2356, df_num=61
# ssr based chi2 test:   chi2=79.0792 , p=0.0597  , df=61
# likelihood ratio test: chi2=77.8441 , p=0.0718  , df=61
# parameter F test:         F=1.2321  , p=0.1087  , df_denom=2356, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=1.2333  , p=0.1060  , df_denom=2353, df_num=62
# ssr based chi2 test:   chi2=80.5259 , p=0.0570  , df=62
# likelihood ratio test: chi2=79.2451 , p=0.0690  , df=62
# parameter F test:         F=1.2333  , p=0.1060  , df_denom=2353, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=1.2207  , p=0.1158  , df_denom=2350, df_num=63
# ssr based chi2 test:   chi2=81.0605 , p=0.0624  , df=63
# likelihood ratio test: chi2=79.7624 , p=0.0754  , df=63
# parameter F test:         F=1.2207  , p=0.1158  , df_denom=2350, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=1.2397  , p=0.0974  , df_denom=2347, df_num=64
# ssr based chi2 test:   chi2=83.6990 , p=0.0498  , df=64
# likelihood ratio test: chi2=82.3155 , p=0.0613  , df=64
# parameter F test:         F=1.2397  , p=0.0974  , df_denom=2347, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=1.2386  , p=0.0968  , df_denom=2344, df_num=65
# ssr based chi2 test:   chi2=85.0073 , p=0.0486  , df=65
# likelihood ratio test: chi2=83.5800 , p=0.0602  , df=65
# parameter F test:         F=1.2386  , p=0.0968  , df_denom=2344, df_num=65
#
# Granger Causality
# number of lags (no zero) 66
# ssr based F test:         F=1.2364  , p=0.0971  , df_denom=2341, df_num=66
# ssr based chi2 test:   chi2=86.2389 , p=0.0480  , df=66
# likelihood ratio test: chi2=84.7699 , p=0.0597  , df=66
# parameter F test:         F=1.2364  , p=0.0971  , df_denom=2341, df_num=66
#
# Granger Causality
# number of lags (no zero) 67
# ssr based F test:         F=1.2162  , p=0.1138  , df_denom=2338, df_num=67
# ssr based chi2 test:   chi2=86.1885 , p=0.0573  , df=67
# likelihood ratio test: chi2=84.7206 , p=0.0708  , df=67
# parameter F test:         F=1.2162  , p=0.1138  , df_denom=2338, df_num=67
#
# Granger Causality
# number of lags (no zero) 68
# ssr based F test:         F=1.1943  , p=0.1349  , df_denom=2335, df_num=68
# ssr based chi2 test:   chi2=85.9773 , p=0.0695  , df=68
# likelihood ratio test: chi2=84.5159 , p=0.0851  , df=68
# parameter F test:         F=1.1943  , p=0.1349  , df_denom=2335, df_num=68
#
# Granger Causality
# number of lags (no zero) 69
# ssr based F test:         F=1.2224  , p=0.1050  , df_denom=2332, df_num=69
# ssr based chi2 test:   chi2=89.3744 , p=0.0501  , df=69
# likelihood ratio test: chi2=87.7961 , p=0.0630  , df=69
# parameter F test:         F=1.2224  , p=0.1050  , df_denom=2332, df_num=69
#
# Granger Causality
# number of lags (no zero) 70
# ssr based F test:         F=1.2101  , p=0.1153  , df_denom=2329, df_num=70
# ssr based chi2 test:   chi2=89.8343 , p=0.0553  , df=70
# likelihood ratio test: chi2=88.2393 , p=0.0694  , df=70
# parameter F test:         F=1.2101  , p=0.1153  , df_denom=2329, df_num=70
#
# Granger Causality
# number of lags (no zero) 71
# ssr based F test:         F=1.2073  , p=0.1167  , df_denom=2326, df_num=71
# ssr based chi2 test:   chi2=90.9846 , p=0.0552  , df=71
# likelihood ratio test: chi2=89.3483 , p=0.0696  , df=71
# parameter F test:         F=1.2073  , p=0.1167  , df_denom=2326, df_num=71
#
# Granger Causality
# number of lags (no zero) 72
# ssr based F test:         F=1.1718  , p=0.1556  , df_denom=2323, df_num=72
# ssr based chi2 test:   chi2=89.6366 , p=0.0780  , df=72
# likelihood ratio test: chi2=88.0472 , p=0.0962  , df=72
# parameter F test:         F=1.1718  , p=0.1556  , df_denom=2323, df_num=72
#
# Granger Causality
# number of lags (no zero) 73
# ssr based F test:         F=1.1735  , p=0.1520  , df_denom=2320, df_num=73
# ssr based chi2 test:   chi2=91.0926 , p=0.0745  , df=73
# likelihood ratio test: chi2=89.4511 , p=0.0926  , df=73
# parameter F test:         F=1.1735  , p=0.1520  , df_denom=2320, df_num=73
#
# Granger Causality
# number of lags (no zero) 74
# ssr based F test:         F=1.2219  , p=0.0986  , df_denom=2317, df_num=74
# ssr based chi2 test:   chi2=96.2339 , p=0.0423  , df=74
# likelihood ratio test: chi2=94.4037 , p=0.0551  , df=74
# parameter F test:         F=1.2219  , p=0.0986  , df_denom=2317, df_num=74
#
# Granger Causality
# number of lags (no zero) 75
# ssr based F test:         F=1.2089  , p=0.1095  , df_denom=2314, df_num=75
# ssr based chi2 test:   chi2=96.5843 , p=0.0474  , df=75
# likelihood ratio test: chi2=94.7401 , p=0.0615  , df=75
# parameter F test:         F=1.2089  , p=0.1095  , df_denom=2314, df_num=75
#
# Granger Causality
# number of lags (no zero) 76
# ssr based F test:         F=1.1679  , p=0.1550  , df_denom=2311, df_num=76
# ssr based chi2 test:   chi2=94.6344 , p=0.0727  , df=76
# likelihood ratio test: chi2=92.8623 , p=0.0916  , df=76
# parameter F test:         F=1.1679  , p=0.1550  , df_denom=2311, df_num=76
#
# Granger Causality
# number of lags (no zero) 77
# ssr based F test:         F=1.1665  , p=0.1554  , df_denom=2308, df_num=77
# ssr based chi2 test:   chi2=95.8564 , p=0.0717  , df=77
# likelihood ratio test: chi2=94.0381 , p=0.0908  , df=77
# parameter F test:         F=1.1665  , p=0.1554  , df_denom=2308, df_num=77
#
# Granger Causality
# number of lags (no zero) 78
# ssr based F test:         F=1.1507  , p=0.1759  , df_denom=2305, df_num=78
# ssr based chi2 test:   chi2=95.8641 , p=0.0829  , df=78
# likelihood ratio test: chi2=94.0448 , p=0.1041  , df=78
# parameter F test:         F=1.1507  , p=0.1759  , df_denom=2305, df_num=78
#
# Granger Causality
# number of lags (no zero) 79
# ssr based F test:         F=1.1436  , p=0.1850  , df_denom=2302, df_num=79
# ssr based chi2 test:   chi2=96.5825 , p=0.0871  , df=79
# likelihood ratio test: chi2=94.7354 , p=0.1094  , df=79
# parameter F test:         F=1.1436  , p=0.1850  , df_denom=2302, df_num=79
#
# Granger Causality
# number of lags (no zero) 80
# ssr based F test:         F=1.1312  , p=0.2030  , df_denom=2299, df_num=80
# ssr based chi2 test:   chi2=96.8361 , p=0.0969  , df=80
# likelihood ratio test: chi2=94.9787 , p=0.1211  , df=80
# parameter F test:         F=1.1312  , p=0.2030  , df_denom=2299, df_num=80
#
# Granger Causality
# number of lags (no zero) 81
# ssr based F test:         F=1.1413  , p=0.1859  , df_denom=2296, df_num=81
# ssr based chi2 test:   chi2=99.0116 , p=0.0848  , df=81
# likelihood ratio test: chi2=97.0702 , p=0.1076  , df=81
# parameter F test:         F=1.1413  , p=0.1859  , df_denom=2296, df_num=81
#
# Granger Causality
# number of lags (no zero) 82
# ssr based F test:         F=1.1324  , p=0.1987  , df_denom=2293, df_num=82
# ssr based chi2 test:   chi2=99.5381 , p=0.0912  , df=82
# likelihood ratio test: chi2=97.5755 , p=0.1154  , df=82
# parameter F test:         F=1.1324  , p=0.1987  , df_denom=2293, df_num=82
#
# Granger Causality
# number of lags (no zero) 83
# ssr based F test:         F=1.1140  , p=0.2286  , df_denom=2290, df_num=83
# ssr based chi2 test:   chi2=99.2066 , p=0.1084  , df=83
# likelihood ratio test: chi2=97.2561 , p=0.1357  , df=83
# parameter F test:         F=1.1140  , p=0.2286  , df_denom=2290, df_num=83
#
# Granger Causality
# number of lags (no zero) 84
# ssr based F test:         F=1.2012  , p=0.1059  , df_denom=2287, df_num=84
# ssr based chi2 test:   chi2=108.3613, p=0.0380  , df=84
# likelihood ratio test: chi2=106.0388, p=0.0525  , df=84
# parameter F test:         F=1.2012  , p=0.1059  , df_denom=2287, df_num=84
#
# Granger Causality
# number of lags (no zero) 85
# ssr based F test:         F=1.2749  , p=0.0482  , df_denom=2284, df_num=85
# ssr based chi2 test:   chi2=116.4812, p=0.0133  , df=85
# likelihood ratio test: chi2=113.8023, p=0.0202  , df=85
# parameter F test:         F=1.2749  , p=0.0482  , df_denom=2284, df_num=85
#
# Granger Causality
# number of lags (no zero) 86
# ssr based F test:         F=1.3458  , p=0.0202  , df_denom=2281, df_num=86
# ssr based chi2 test:   chi2=124.5211, p=0.0042  , df=86
# likelihood ratio test: chi2=121.4648, p=0.0071  , df=86
# parameter F test:         F=1.3458  , p=0.0202  , df_denom=2281, df_num=86
#
# Granger Causality
# number of lags (no zero) 87
# ssr based F test:         F=1.3592  , p=0.0165  , df_denom=2278, df_num=87
# ssr based chi2 test:   chi2=127.3384, p=0.0032  , df=87
# likelihood ratio test: chi2=124.1433, p=0.0055  , df=87
# parameter F test:         F=1.3592  , p=0.0165  , df_denom=2278, df_num=87
#
# Granger Causality
# number of lags (no zero) 88
# ssr based F test:         F=1.3703  , p=0.0139  , df_denom=2275, df_num=88
# ssr based chi2 test:   chi2=129.9680, p=0.0024  , df=88
# likelihood ratio test: chi2=126.6406, p=0.0044  , df=88
# parameter F test:         F=1.3703  , p=0.0139  , df_denom=2275, df_num=88
#
# Granger Causality
# number of lags (no zero) 89
# ssr based F test:         F=1.3987  , p=0.0091  , df_denom=2272, df_num=89
# ssr based chi2 test:   chi2=134.2957, p=0.0014  , df=89
# likelihood ratio test: chi2=130.7456, p=0.0026  , df=89
# parameter F test:         F=1.3987  , p=0.0091  , df_denom=2272, df_num=89
#
# Granger Causality
# number of lags (no zero) 90
# ssr based F test:         F=1.3709  , p=0.0130  , df_denom=2269, df_num=90
# ssr based chi2 test:   chi2=133.2242, p=0.0021  , df=90
# likelihood ratio test: chi2=129.7282, p=0.0039  , df=90
# parameter F test:         F=1.3709  , p=0.0130  , df_denom=2269, df_num=90
#
# Granger Causality
# number of lags (no zero) 91
# ssr based F test:         F=1.4110  , p=0.0072  , df_denom=2266, df_num=91
# ssr based chi2 test:   chi2=138.7682, p=0.0009  , df=91
# likelihood ratio test: chi2=134.9791, p=0.0019  , df=91
# parameter F test:         F=1.4110  , p=0.0072  , df_denom=2266, df_num=91
#
# Granger Causality
# number of lags (no zero) 92
# ssr based F test:         F=1.4097  , p=0.0071  , df_denom=2263, df_num=92
# ssr based chi2 test:   chi2=140.2981, p=0.0009  , df=92
# likelihood ratio test: chi2=136.4250, p=0.0018  , df=92
# parameter F test:         F=1.4097  , p=0.0071  , df_denom=2263, df_num=92
#
# Granger Causality
# number of lags (no zero) 93
# ssr based F test:         F=1.3951  , p=0.0085  , df_denom=2260, df_num=93
# ssr based chi2 test:   chi2=140.4755, p=0.0011  , df=93
# likelihood ratio test: chi2=136.5913, p=0.0022  , df=93
# parameter F test:         F=1.3951  , p=0.0085  , df_denom=2260, df_num=93
#
# Granger Causality
# number of lags (no zero) 94
# ssr based F test:         F=1.3842  , p=0.0096  , df_denom=2257, df_num=94
# ssr based chi2 test:   chi2=141.0119, p=0.0012  , df=94
# likelihood ratio test: chi2=137.0970, p=0.0025  , df=94
# parameter F test:         F=1.3842  , p=0.0096  , df_denom=2257, df_num=94
#
# Granger Causality
# number of lags (no zero) 95
# ssr based F test:         F=1.3493  , p=0.0153  , df_denom=2254, df_num=95
# ssr based chi2 test:   chi2=139.0501, p=0.0022  , df=95
# likelihood ratio test: chi2=135.2399, p=0.0042  , df=95
# parameter F test:         F=1.3493  , p=0.0153  , df_denom=2254, df_num=95
#
# Granger Causality
# number of lags (no zero) 96
# ssr based F test:         F=1.3472  , p=0.0153  , df_denom=2251, df_num=96
# ssr based chi2 test:   chi2=140.4165, p=0.0021  , df=96
# likelihood ratio test: chi2=136.5310, p=0.0042  , df=96
# parameter F test:         F=1.3472  , p=0.0153  , df_denom=2251, df_num=96
#
# Granger Causality
# number of lags (no zero) 97
# ssr based F test:         F=1.3681  , p=0.0111  , df_denom=2248, df_num=97
# ssr based chi2 test:   chi2=144.2159, p=0.0013  , df=97
# likelihood ratio test: chi2=140.1197, p=0.0028  , df=97
# parameter F test:         F=1.3681  , p=0.0111  , df_denom=2248, df_num=97
#
# Granger Causality
# number of lags (no zero) 98
# ssr based F test:         F=1.3415  , p=0.0158  , df_denom=2245, df_num=98
# ssr based chi2 test:   chi2=143.0070, p=0.0021  , df=98
# likelihood ratio test: chi2=138.9763, p=0.0041  , df=98
# parameter F test:         F=1.3415  , p=0.0158  , df_denom=2245, df_num=98
#
# Granger Causality
# number of lags (no zero) 99
# ssr based F test:         F=1.3248  , p=0.0194  , df_denom=2242, df_num=99
# ssr based chi2 test:   chi2=142.8012, p=0.0026  , df=99
# likelihood ratio test: chi2=138.7803, p=0.0052  , df=99
# parameter F test:         F=1.3248  , p=0.0194  , df_denom=2242, df_num=99
#
# Granger Causality
# number of lags (no zero) 100
# ssr based F test:         F=1.3304  , p=0.0176  , df_denom=2239, df_num=100
# ssr based chi2 test:   chi2=144.9852, p=0.0022  , df=100
# likelihood ratio test: chi2=140.8410, p=0.0045  , df=100
# parameter F test:         F=1.3304  , p=0.0176  , df_denom=2239, df_num=100

# %%
def find_lags(test):
    lag_found = False
    lags = []
    
    for i in range(1, maxlag):
        p = test[i][0]['ssr_ftest'][1]
        if (p < 0.05):
            lags.append(test[i][0]['ssr_ftest'])
            lag_found = True

    if (lag_found == True):
        return lags
    else:
        print("lag not found")

# %%
lags_info = find_lags(test)

# %%
lags_info
# Out:
# [(8.089869391077013, 0.004487016466323889, 2536.0, 1),
#  (4.62873244150067, 0.009849894056606443, 2533.0, 2),
#  (3.5041455144244913, 0.014810302637529704, 2530.0, 3),
#  (2.6044894171731925, 0.03419332561287149, 2527.0, 4),
#  (2.0231268038932626, 0.048810885919218006, 2518.0, 7),
#  (2.230808938093935, 0.022739751273766883, 2515.0, 8),
#  (2.0079699233565185, 0.03480295249475197, 2512.0, 9),
#  (1.995994373672954, 0.01769205735760449, 2500.0, 13),
#  (2.0386197652611204, 0.012404250607010026, 2497.0, 14),
#  (1.7178696247183478, 0.04126780576920983, 2494.0, 15),
#  (1.7319031937425429, 0.025337112099918183, 2482.0, 19),
#  (1.654545564409579, 0.033816506561525336, 2479.0, 20),
#  (1.8078163188475744, 0.013527636342464332, 2476.0, 21),
#  (1.6264119301713198, 0.03294713653554664, 2473.0, 22),
#  (1.6071740213321737, 0.0337347638616717, 2470.0, 23),
#  (1.5550164756721798, 0.041734595446157555, 2467.0, 24),
#  (1.5311567437241378, 0.04460904962316748, 2464.0, 25),
#  (1.5624905288249362, 0.0349069550268957, 2461.0, 26),
#  (1.5695543859356382, 0.031236701846270018, 2458.0, 27),
#  (1.5667121894217606, 0.02967532501398761, 2455.0, 28),
#  (1.6326496711468494, 0.017961370458369968, 2452.0, 29),
#  (1.5673592919265746, 0.025789478910011886, 2449.0, 30),
#  (1.5164737607418641, 0.03388093928009701, 2446.0, 31),
#  (1.4921571374280451, 0.03376424750940144, 2437.0, 34),
#  (1.424864352990116, 0.04888267830887493, 2431.0, 36),
#  (1.455308060650455, 0.037721478529856446, 2428.0, 37),
#  (1.2749162768993483, 0.0482387605216175, 2284.0, 85),
#  (1.3458452718936176, 0.020190704756626078, 2281.0, 86),
#  (1.35924004275494, 0.016546264722065062, 2278.0, 87),
#  (1.370296770815266, 0.013901016001176165, 2275.0, 88),
#  (1.3987399626098116, 0.009136075503841956, 2272.0, 89),
#  (1.3709103760990742, 0.013013666379144147, 2269.0, 90),
#  (1.410975949929663, 0.007183413258156849, 2266.0, 91),
#  (1.4097335182030677, 0.007071512327282197, 2263.0, 92),
#  (1.3950574372706672, 0.008469536412047046, 2260.0, 93),
#  (1.384212994619156, 0.00960058652797534, 2257.0, 94),
#  (1.349343853548895, 0.015262603225673547, 2254.0, 95),
#  (1.3471667116858654, 0.015330873336320043, 2251.0, 96),
#  (1.3680889430948746, 0.011098630916520927, 2248.0, 97),
#  (1.341534538268838, 0.01577058581953885, 2245.0, 98),
#  (1.3248435606444955, 0.019419154087430956, 2242.0, 99)]

# %% [markdown]
# # Granger Tests - GCTAY

# %%
maxlag = 100
ticker = 'GCTAY'
series = 'compound_sentiment'

# %%
input_data = np.asarray(gctay[['closing_price', series]])
test = grangercausalitytests(input_data, maxlag, addconst = True, verbose=True);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.6362  , p=0.0177  , df_denom=2536, df_num=1
# ssr based chi2 test:   chi2=5.6428  , p=0.0175  , df=1
# likelihood ratio test: chi2=5.6366  , p=0.0176  , df=1
# parameter F test:         F=5.6362  , p=0.0177  , df_denom=2536, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2807  , p=0.0378  , df_denom=2533, df_num=2
# ssr based chi2 test:   chi2=6.5743  , p=0.0374  , df=2
# likelihood ratio test: chi2=6.5658  , p=0.0375  , df=2
# parameter F test:         F=3.2807  , p=0.0378  , df_denom=2533, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4702  , p=0.0602  , df_denom=2530, df_num=3
# ssr based chi2 test:   chi2=7.4310  , p=0.0594  , df=3
# likelihood ratio test: chi2=7.4201  , p=0.0596  , df=3
# parameter F test:         F=2.4702  , p=0.0602  , df_denom=2530, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8753  , p=0.1120  , df_denom=2527, df_num=4
# ssr based chi2 test:   chi2=7.5281  , p=0.1105  , df=4
# likelihood ratio test: chi2=7.5169  , p=0.1110  , df=4
# parameter F test:         F=1.8753  , p=0.1120  , df_denom=2527, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6991  , p=0.1314  , df_denom=2524, df_num=5
# ssr based chi2 test:   chi2=8.5323  , p=0.1292  , df=5
# likelihood ratio test: chi2=8.5180  , p=0.1299  , df=5
# parameter F test:         F=1.6991  , p=0.1314  , df_denom=2524, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6448  , p=0.1308  , df_denom=2521, df_num=6
# ssr based chi2 test:   chi2=9.9197  , p=0.1281  , df=6
# likelihood ratio test: chi2=9.9004  , p=0.1289  , df=6
# parameter F test:         F=1.6448  , p=0.1308  , df_denom=2521, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5152  , p=0.1573  , df_denom=2518, df_num=7
# ssr based chi2 test:   chi2=10.6698 , p=0.1537  , df=7
# likelihood ratio test: chi2=10.6474 , p=0.1548  , df=7
# parameter F test:         F=1.5152  , p=0.1573  , df_denom=2518, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5353  , p=0.1397  , df_denom=2515, df_num=8
# ssr based chi2 test:   chi2=12.3657 , p=0.1356  , df=8
# likelihood ratio test: chi2=12.3356 , p=0.1368  , df=8
# parameter F test:         F=1.5353  , p=0.1397  , df_denom=2515, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3811  , p=0.1908  , df_denom=2512, df_num=9
# ssr based chi2 test:   chi2=12.5243 , p=0.1853  , df=9
# likelihood ratio test: chi2=12.4934 , p=0.1869  , df=9
# parameter F test:         F=1.3811  , p=0.1908  , df_denom=2512, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2297  , p=0.2664  , df_denom=2509, df_num=10
# ssr based chi2 test:   chi2=12.3996 , p=0.2592  , df=10
# likelihood ratio test: chi2=12.3693 , p=0.2611  , df=10
# parameter F test:         F=1.2297  , p=0.2664  , df_denom=2509, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0453  , p=0.4030  , df_denom=2506, df_num=11
# ssr based chi2 test:   chi2=11.6034 , p=0.3942  , df=11
# likelihood ratio test: chi2=11.5769 , p=0.3963  , df=11
# parameter F test:         F=1.0453  , p=0.4030  , df_denom=2506, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.1574  , p=0.3086  , df_denom=2503, df_num=12
# ssr based chi2 test:   chi2=14.0274 , p=0.2990  , df=12
# likelihood ratio test: chi2=13.9886 , p=0.3014  , df=12
# parameter F test:         F=1.1574  , p=0.3086  , df_denom=2503, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.0646  , p=0.3858  , df_denom=2500, df_num=13
# ssr based chi2 test:   chi2=13.9890 , p=0.3746  , df=13
# likelihood ratio test: chi2=13.9504 , p=0.3773  , df=13
# parameter F test:         F=1.0646  , p=0.3858  , df_denom=2500, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.0755  , p=0.3749  , df_denom=2497, df_num=14
# ssr based chi2 test:   chi2=15.2323 , p=0.3625  , df=14
# likelihood ratio test: chi2=15.1865 , p=0.3655  , df=14
# parameter F test:         F=1.0755  , p=0.3749  , df_denom=2497, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.9056  , p=0.5575  , df_denom=2494, df_num=15
# ssr based chi2 test:   chi2=13.7521 , p=0.5444  , df=15
# likelihood ratio test: chi2=13.7148 , p=0.5473  , df=15
# parameter F test:         F=0.9056  , p=0.5575  , df_denom=2494, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.8254  , p=0.6574  , df_denom=2491, df_num=16
# ssr based chi2 test:   chi2=13.3816 , p=0.6447  , df=16
# likelihood ratio test: chi2=13.3462 , p=0.6473  , df=16
# parameter F test:         F=0.8254  , p=0.6574  , df_denom=2491, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.9561  , p=0.5062  , df_denom=2488, df_num=17
# ssr based chi2 test:   chi2=16.4823 , p=0.4899  , df=17
# likelihood ratio test: chi2=16.4287 , p=0.4937  , df=17
# parameter F test:         F=0.9561  , p=0.5062  , df_denom=2488, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.0588  , p=0.3890  , df_denom=2485, df_num=18
# ssr based chi2 test:   chi2=19.3414 , p=0.3711  , df=18
# likelihood ratio test: chi2=19.2676 , p=0.3755  , df=18
# parameter F test:         F=1.0588  , p=0.3890  , df_denom=2485, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.3493  , p=0.1419  , df_denom=2482, df_num=19
# ssr based chi2 test:   chi2=26.0405 , p=0.1291  , df=19
# likelihood ratio test: chi2=25.9069 , p=0.1328  , df=19
# parameter F test:         F=1.3493  , p=0.1419  , df_denom=2482, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.2737  , p=0.1852  , df_denom=2479, df_num=20
# ssr based chi2 test:   chi2=25.8960 , p=0.1693  , df=20
# likelihood ratio test: chi2=25.7638 , p=0.1738  , df=20
# parameter F test:         F=1.2737  , p=0.1852  , df_denom=2479, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.1911  , p=0.2479  , df_denom=2476, df_num=21
# ssr based chi2 test:   chi2=25.4467 , p=0.2283  , df=21
# likelihood ratio test: chi2=25.3190 , p=0.2336  , df=21
# parameter F test:         F=1.1911  , p=0.2479  , df_denom=2476, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.1255  , p=0.3098  , df_denom=2473, df_num=22
# ssr based chi2 test:   chi2=25.2108 , p=0.2871  , df=22
# likelihood ratio test: chi2=25.0854 , p=0.2930  , df=22
# parameter F test:         F=1.1255  , p=0.3098  , df_denom=2473, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.2075  , p=0.2260  , df_denom=2470, df_num=23
# ssr based chi2 test:   chi2=28.3010 , p=0.2046  , df=23
# likelihood ratio test: chi2=28.1431 , p=0.2104  , df=23
# parameter F test:         F=1.2075  , p=0.2260  , df_denom=2470, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.3351  , p=0.1275  , df_denom=2467, df_num=24
# ssr based chi2 test:   chi2=32.6800 , p=0.1110  , df=24
# likelihood ratio test: chi2=32.4696 , p=0.1158  , df=24
# parameter F test:         F=1.3351  , p=0.1275  , df_denom=2467, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.3284  , p=0.1276  , df_denom=2464, df_num=25
# ssr based chi2 test:   chi2=33.8963 , p=0.1101  , df=25
# likelihood ratio test: chi2=33.6699 , p=0.1152  , df=25
# parameter F test:         F=1.3284  , p=0.1276  , df_denom=2464, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.3651  , p=0.1030  , df_denom=2461, df_num=26
# ssr based chi2 test:   chi2=36.2580 , p=0.0870  , df=26
# likelihood ratio test: chi2=35.9990 , p=0.0917  , df=26
# parameter F test:         F=1.3651  , p=0.1030  , df_denom=2461, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.3245  , p=0.1224  , df_denom=2458, df_num=27
# ssr based chi2 test:   chi2=36.5625 , p=0.1035  , df=27
# likelihood ratio test: chi2=36.2991 , p=0.1089  , df=27
# parameter F test:         F=1.3245  , p=0.1224  , df_denom=2458, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.2926  , p=0.1396  , df_denom=2455, df_num=28
# ssr based chi2 test:   chi2=37.0332 , p=0.1181  , df=28
# likelihood ratio test: chi2=36.7628 , p=0.1242  , df=28
# parameter F test:         F=1.2926  , p=0.1396  , df_denom=2455, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.3053  , p=0.1275  , df_denom=2452, df_num=29
# ssr based chi2 test:   chi2=38.7646 , p=0.1063  , df=29
# likelihood ratio test: chi2=38.4685 , p=0.1123  , df=29
# parameter F test:         F=1.3053  , p=0.1275  , df_denom=2452, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.2892  , p=0.1351  , df_denom=2449, df_num=30
# ssr based chi2 test:   chi2=39.6383 , p=0.1121  , df=30
# likelihood ratio test: chi2=39.3286 , p=0.1185  , df=30
# parameter F test:         F=1.2892  , p=0.1351  , df_denom=2449, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.3040  , p=0.1217  , df_denom=2446, df_num=31
# ssr based chi2 test:   chi2=41.4660 , p=0.0992  , df=31
# likelihood ratio test: chi2=41.1270 , p=0.1055  , df=31
# parameter F test:         F=1.3040  , p=0.1217  , df_denom=2446, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.2694  , p=0.1432  , df_denom=2443, df_num=32
# ssr based chi2 test:   chi2=41.7017 , p=0.1171  , df=32
# likelihood ratio test: chi2=41.3588 , p=0.1243  , df=32
# parameter F test:         F=1.2694  , p=0.1432  , df_denom=2443, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.2566  , p=0.1501  , df_denom=2440, df_num=33
# ssr based chi2 test:   chi2=42.6077 , p=0.1221  , df=33
# likelihood ratio test: chi2=42.2496 , p=0.1298  , df=33
# parameter F test:         F=1.2566  , p=0.1501  , df_denom=2440, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.2281  , p=0.1716  , df_denom=2437, df_num=34
# ssr based chi2 test:   chi2=42.9361 , p=0.1400  , df=34
# likelihood ratio test: chi2=42.5725 , p=0.1486  , df=34
# parameter F test:         F=1.2281  , p=0.1716  , df_denom=2437, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.1931  , p=0.2028  , df_denom=2434, df_num=35
# ssr based chi2 test:   chi2=42.9763 , p=0.1666  , df=35
# likelihood ratio test: chi2=42.6118 , p=0.1763  , df=35
# parameter F test:         F=1.1931  , p=0.2028  , df_denom=2434, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.1650  , p=0.2311  , df_denom=2431, df_num=36
# ssr based chi2 test:   chi2=43.1976 , p=0.1908  , df=36
# likelihood ratio test: chi2=42.8292 , p=0.2015  , df=36
# parameter F test:         F=1.1650  , p=0.2311  , df_denom=2431, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.1431  , p=0.2551  , df_denom=2428, df_num=37
# ssr based chi2 test:   chi2=43.6011 , p=0.2111  , df=37
# likelihood ratio test: chi2=43.2257 , p=0.2227  , df=37
# parameter F test:         F=1.1431  , p=0.2551  , df_denom=2428, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.1721  , p=0.2181  , df_denom=2425, df_num=38
# ssr based chi2 test:   chi2=45.9556 , p=0.1759  , df=38
# likelihood ratio test: chi2=45.5387 , p=0.1871  , df=38
# parameter F test:         F=1.1721  , p=0.2181  , df_denom=2425, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.2056  , p=0.1796  , df_denom=2422, df_num=39
# ssr based chi2 test:   chi2=48.5517 , p=0.1405  , df=39
# likelihood ratio test: chi2=48.0865 , p=0.1509  , df=39
# parameter F test:         F=1.2056  , p=0.1796  , df_denom=2422, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.2016  , p=0.1811  , df_denom=2419, df_num=40
# ssr based chi2 test:   chi2=49.6746 , p=0.1405  , df=40
# likelihood ratio test: chi2=49.1875 , p=0.1513  , df=40
# parameter F test:         F=1.2016  , p=0.1811  , df_denom=2419, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.2733  , p=0.1153  , df_denom=2416, df_num=41
# ssr based chi2 test:   chi2=53.9974 , p=0.0840  , df=41
# likelihood ratio test: chi2=53.4223 , p=0.0925  , df=41
# parameter F test:         F=1.2733  , p=0.1153  , df_denom=2416, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.2441  , p=0.1361  , df_denom=2413, df_num=42
# ssr based chi2 test:   chi2=54.0935 , p=0.0999  , df=42
# likelihood ratio test: chi2=53.5162 , p=0.1096  , df=42
# parameter F test:         F=1.2441  , p=0.1361  , df_denom=2413, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.2334  , p=0.1431  , df_denom=2410, df_num=43
# ssr based chi2 test:   chi2=54.9518 , p=0.1045  , df=43
# likelihood ratio test: chi2=54.3559 , p=0.1148  , df=43
# parameter F test:         F=1.2334  , p=0.1431  , df_denom=2410, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.3027  , p=0.0883  , df_denom=2407, df_num=44
# ssr based chi2 test:   chi2=59.4401 , p=0.0600  , df=44
# likelihood ratio test: chi2=58.7434 , p=0.0677  , df=44
# parameter F test:         F=1.3027  , p=0.0883  , df_denom=2407, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.3295  , p=0.0709  , df_denom=2404, df_num=45
# ssr based chi2 test:   chi2=62.0926 , p=0.0463  , df=45
# likelihood ratio test: chi2=61.3326 , p=0.0529  , df=45
# parameter F test:         F=1.3295  , p=0.0709  , df_denom=2404, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.3085  , p=0.0807  , df_denom=2401, df_num=46
# ssr based chi2 test:   chi2=62.5245 , p=0.0527  , df=46
# likelihood ratio test: chi2=61.7536 , p=0.0602  , df=46
# parameter F test:         F=1.3085  , p=0.0807  , df_denom=2401, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.2913  , p=0.0894  , df_denom=2398, df_num=47
# ssr based chi2 test:   chi2=63.0933 , p=0.0584  , df=47
# likelihood ratio test: chi2=62.3081 , p=0.0666  , df=47
# parameter F test:         F=1.2913  , p=0.0894  , df_denom=2398, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.2562  , p=0.1126  , df_denom=2395, df_num=48
# ssr based chi2 test:   chi2=62.7405 , p=0.0750  , df=48
# likelihood ratio test: chi2=61.9637 , p=0.0849  , df=48
# parameter F test:         F=1.2562  , p=0.1126  , df_denom=2395, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.2431  , p=0.1213  , df_denom=2392, df_num=49
# ssr based chi2 test:   chi2=63.4320 , p=0.0806  , df=49
# likelihood ratio test: chi2=62.6378 , p=0.0912  , df=49
# parameter F test:         F=1.2431  , p=0.1213  , df_denom=2392, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.2595  , p=0.1059  , df_denom=2389, df_num=50
# ssr based chi2 test:   chi2=65.6364 , p=0.0681  , df=50
# likelihood ratio test: chi2=64.7862 , p=0.0779  , df=50
# parameter F test:         F=1.2595  , p=0.1059  , df_denom=2389, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=1.2726  , p=0.0942  , df_denom=2386, df_num=51
# ssr based chi2 test:   chi2=67.7060 , p=0.0587  , df=51
# likelihood ratio test: chi2=66.8015 , p=0.0679  , df=51
# parameter F test:         F=1.2726  , p=0.0942  , df_denom=2386, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=1.2557  , p=0.1050  , df_denom=2383, df_num=52
# ssr based chi2 test:   chi2=68.1741 , p=0.0655  , df=52
# likelihood ratio test: chi2=67.2568 , p=0.0757  , df=52
# parameter F test:         F=1.2557  , p=0.1050  , df_denom=2383, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=1.2067  , p=0.1474  , df_denom=2380, df_num=53
# ssr based chi2 test:   chi2=66.8299 , p=0.0959  , df=53
# likelihood ratio test: chi2=65.9477 , p=0.1091  , df=53
# parameter F test:         F=1.2067  , p=0.1474  , df_denom=2380, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=1.2414  , p=0.1129  , df_denom=2377, df_num=54
# ssr based chi2 test:   chi2=70.1079 , p=0.0693  , df=54
# likelihood ratio test: chi2=69.1375 , p=0.0805  , df=54
# parameter F test:         F=1.2414  , p=0.1129  , df_denom=2377, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=1.2449  , p=0.1081  , df_denom=2374, df_num=55
# ssr based chi2 test:   chi2=71.6704 , p=0.0649  , df=55
# likelihood ratio test: chi2=70.6563 , p=0.0759  , df=55
# parameter F test:         F=1.2449  , p=0.1081  , df_denom=2374, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=1.2495  , p=0.1026  , df_denom=2371, df_num=56
# ssr based chi2 test:   chi2=73.3077 , p=0.0601  , df=56
# likelihood ratio test: chi2=72.2468 , p=0.0709  , df=56
# parameter F test:         F=1.2495  , p=0.1026  , df_denom=2371, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=1.2214  , p=0.1254  , df_denom=2368, df_num=57
# ssr based chi2 test:   chi2=72.9996 , p=0.0751  , df=57
# likelihood ratio test: chi2=71.9471 , p=0.0878  , df=57
# parameter F test:         F=1.2214  , p=0.1254  , df_denom=2368, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=1.2620  , p=0.0895  , df_denom=2365, df_num=58
# ssr based chi2 test:   chi2=76.8198 , p=0.0497  , df=58
# likelihood ratio test: chi2=75.6550 , p=0.0596  , df=58
# parameter F test:         F=1.2620  , p=0.0895  , df_denom=2365, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=1.2435  , p=0.1023  , df_denom=2362, df_num=59
# ssr based chi2 test:   chi2=77.0641 , p=0.0573  , df=59
# likelihood ratio test: chi2=75.8914 , p=0.0685  , df=59
# parameter F test:         F=1.2435  , p=0.1023  , df_denom=2362, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=1.2289  , p=0.1132  , df_denom=2359, df_num=60
# ssr based chi2 test:   chi2=77.5168 , p=0.0636  , df=60
# likelihood ratio test: chi2=76.3300 , p=0.0759  , df=60
# parameter F test:         F=1.2289  , p=0.1132  , df_denom=2359, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=1.2102  , p=0.1294  , df_denom=2356, df_num=61
# ssr based chi2 test:   chi2=77.6744 , p=0.0736  , df=61
# likelihood ratio test: chi2=76.4823 , p=0.0873  , df=61
# parameter F test:         F=1.2102  , p=0.1294  , df_denom=2356, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=1.2446  , p=0.0965  , df_denom=2353, df_num=62
# ssr based chi2 test:   chi2=81.2613 , p=0.0509  , df=62
# likelihood ratio test: chi2=79.9573 , p=0.0621  , df=62
# parameter F test:         F=1.2446  , p=0.0965  , df_denom=2353, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=1.2571  , p=0.0853  , df_denom=2350, df_num=63
# ssr based chi2 test:   chi2=83.4790 , p=0.0431  , df=63
# likelihood ratio test: chi2=82.1032 , p=0.0534  , df=63
# parameter F test:         F=1.2571  , p=0.0853  , df_denom=2350, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=1.2854  , p=0.0650  , df_denom=2347, df_num=64
# ssr based chi2 test:   chi2=86.7888 , p=0.0306  , df=64
# likelihood ratio test: chi2=85.3024 , p=0.0388  , df=64
# parameter F test:         F=1.2854  , p=0.0650  , df_denom=2347, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=1.2590  , p=0.0809  , df_denom=2344, df_num=65
# ssr based chi2 test:   chi2=86.4118 , p=0.0391  , df=65
# likelihood ratio test: chi2=84.9375 , p=0.0491  , df=65
# parameter F test:         F=1.2590  , p=0.0809  , df_denom=2344, df_num=65
#
# Granger Causality
# number of lags (no zero) 66
# ssr based F test:         F=1.2551  , p=0.0824  , df_denom=2341, df_num=66
# ssr based chi2 test:   chi2=87.5407 , p=0.0393  , df=66
# likelihood ratio test: chi2=86.0275 , p=0.0495  , df=66
# parameter F test:         F=1.2551  , p=0.0824  , df_denom=2341, df_num=66
#
# Granger Causality
# number of lags (no zero) 67
# ssr based F test:         F=1.2308  , p=0.1005  , df_denom=2338, df_num=67
# ssr based chi2 test:   chi2=87.2234 , p=0.0491  , df=67
# likelihood ratio test: chi2=85.7204 , p=0.0613  , df=67
# parameter F test:         F=1.2308  , p=0.1005  , df_denom=2338, df_num=67
#
# Granger Causality
# number of lags (no zero) 68
# ssr based F test:         F=1.2179  , p=0.1107  , df_denom=2335, df_num=68
# ssr based chi2 test:   chi2=87.6794 , p=0.0544  , df=68
# likelihood ratio test: chi2=86.1603 , p=0.0677  , df=68
# parameter F test:         F=1.2179  , p=0.1107  , df_denom=2335, df_num=68
#
# Granger Causality
# number of lags (no zero) 69
# ssr based F test:         F=1.2277  , p=0.1003  , df_denom=2332, df_num=69
# ssr based chi2 test:   chi2=89.7602 , p=0.0473  , df=69
# likelihood ratio test: chi2=88.1683 , p=0.0598  , df=69
# parameter F test:         F=1.2277  , p=0.1003  , df_denom=2332, df_num=69
#
# Granger Causality
# number of lags (no zero) 70
# ssr based F test:         F=1.2212  , p=0.1047  , df_denom=2329, df_num=70
# ssr based chi2 test:   chi2=90.6570 , p=0.0491  , df=70
# likelihood ratio test: chi2=89.0329 , p=0.0621  , df=70
# parameter F test:         F=1.2212  , p=0.1047  , df_denom=2329, df_num=70
#
# Granger Causality
# number of lags (no zero) 71
# ssr based F test:         F=1.2028  , p=0.1213  , df_denom=2326, df_num=71
# ssr based chi2 test:   chi2=90.6479 , p=0.0580  , df=71
# likelihood ratio test: chi2=89.0235 , p=0.0728  , df=71
# parameter F test:         F=1.2028  , p=0.1213  , df_denom=2326, df_num=71
#
# Granger Causality
# number of lags (no zero) 72
# ssr based F test:         F=1.1660  , p=0.1631  , df_denom=2323, df_num=72
# ssr based chi2 test:   chi2=89.1911 , p=0.0828  , df=72
# likelihood ratio test: chi2=87.6172 , p=0.1016  , df=72
# parameter F test:         F=1.1660  , p=0.1631  , df_denom=2323, df_num=72
#
# Granger Causality
# number of lags (no zero) 73
# ssr based F test:         F=1.1527  , p=0.1798  , df_denom=2320, df_num=73
# ssr based chi2 test:   chi2=89.4763 , p=0.0923  , df=73
# likelihood ratio test: chi2=87.8919 , p=0.1128  , df=73
# parameter F test:         F=1.1527  , p=0.1798  , df_denom=2320, df_num=73
#
# Granger Causality
# number of lags (no zero) 74
# ssr based F test:         F=1.1582  , p=0.1707  , df_denom=2317, df_num=74
# ssr based chi2 test:   chi2=91.2179 , p=0.0850  , df=74
# likelihood ratio test: chi2=89.5713 , p=0.1050  , df=74
# parameter F test:         F=1.1582  , p=0.1707  , df_denom=2317, df_num=74
#
# Granger Causality
# number of lags (no zero) 75
# ssr based F test:         F=1.1383  , p=0.1983  , df_denom=2314, df_num=75
# ssr based chi2 test:   chi2=90.9402 , p=0.1015  , df=75
# likelihood ratio test: chi2=89.3029 , p=0.1241  , df=75
# parameter F test:         F=1.1383  , p=0.1983  , df_denom=2314, df_num=75
#
# Granger Causality
# number of lags (no zero) 76
# ssr based F test:         F=1.1321  , p=0.2066  , df_denom=2311, df_num=76
# ssr based chi2 test:   chi2=91.7368 , p=0.1055  , df=76
# likelihood ratio test: chi2=90.0703 , p=0.1291  , df=76
# parameter F test:         F=1.1321  , p=0.2066  , df_denom=2311, df_num=76
#
# Granger Causality
# number of lags (no zero) 77
# ssr based F test:         F=1.1238  , p=0.2188  , df_denom=2308, df_num=77
# ssr based chi2 test:   chi2=92.3452 , p=0.1120  , df=77
# likelihood ratio test: chi2=90.6561 , p=0.1369  , df=77
# parameter F test:         F=1.1238  , p=0.2188  , df_denom=2308, df_num=77
#
# Granger Causality
# number of lags (no zero) 78
# ssr based F test:         F=1.1588  , p=0.1645  , df_denom=2305, df_num=78
# ssr based chi2 test:   chi2=96.5388 , p=0.0759  , df=78
# likelihood ratio test: chi2=94.6942 , p=0.0961  , df=78
# parameter F test:         F=1.1588  , p=0.1645  , df_denom=2305, df_num=78
#
# Granger Causality
# number of lags (no zero) 79
# ssr based F test:         F=1.1724  , p=0.1452  , df_denom=2302, df_num=79
# ssr based chi2 test:   chi2=99.0162 , p=0.0634  , df=79
# likelihood ratio test: chi2=97.0762 , p=0.0818  , df=79
# parameter F test:         F=1.1724  , p=0.1452  , df_denom=2302, df_num=79
#
# Granger Causality
# number of lags (no zero) 80
# ssr based F test:         F=1.1574  , p=0.1637  , df_denom=2299, df_num=80
# ssr based chi2 test:   chi2=99.0765 , p=0.0729  , df=80
# likelihood ratio test: chi2=97.1333 , p=0.0934  , df=80
# parameter F test:         F=1.1574  , p=0.1637  , df_denom=2299, df_num=80
#
# Granger Causality
# number of lags (no zero) 81
# ssr based F test:         F=1.1524  , p=0.1695  , df_denom=2296, df_num=81
# ssr based chi2 test:   chi2=99.9708 , p=0.0750  , df=81
# likelihood ratio test: chi2=97.9921 , p=0.0963  , df=81
# parameter F test:         F=1.1524  , p=0.1695  , df_denom=2296, df_num=81
#
# Granger Causality
# number of lags (no zero) 82
# ssr based F test:         F=1.1392  , p=0.1879  , df_denom=2293, df_num=82
# ssr based chi2 test:   chi2=100.1377, p=0.0846  , df=82
# likelihood ratio test: chi2=98.1517 , p=0.1078  , df=82
# parameter F test:         F=1.1392  , p=0.1879  , df_denom=2293, df_num=82
#
# Granger Causality
# number of lags (no zero) 83
# ssr based F test:         F=1.1320  , p=0.1981  , df_denom=2290, df_num=83
# ssr based chi2 test:   chi2=100.8102, p=0.0893  , df=83
# likelihood ratio test: chi2=98.7970 , p=0.1137  , df=83
# parameter F test:         F=1.1320  , p=0.1981  , df_denom=2290, df_num=83
#
# Granger Causality
# number of lags (no zero) 84
# ssr based F test:         F=1.1676  , p=0.1450  , df_denom=2287, df_num=84
# ssr based chi2 test:   chi2=105.3266, p=0.0577  , df=84
# likelihood ratio test: chi2=103.1306, p=0.0767  , df=84
# parameter F test:         F=1.1676  , p=0.1450  , df_denom=2287, df_num=84
#
# Granger Causality
# number of lags (no zero) 85
# ssr based F test:         F=1.2063  , p=0.0996  , df_denom=2284, df_num=85
# ssr based chi2 test:   chi2=110.2115, p=0.0344  , df=85
# likelihood ratio test: chi2=107.8093, p=0.0481  , df=85
# parameter F test:         F=1.2063  , p=0.0996  , df_denom=2284, df_num=85
#
# Granger Causality
# number of lags (no zero) 86
# ssr based F test:         F=1.1843  , p=0.1220  , df_denom=2281, df_num=86
# ssr based chi2 test:   chi2=109.5748, p=0.0441  , df=86
# likelihood ratio test: chi2=107.1989, p=0.0606  , df=86
# parameter F test:         F=1.1843  , p=0.1220  , df_denom=2281, df_num=86
#
# Granger Causality
# number of lags (no zero) 87
# ssr based F test:         F=1.1824  , p=0.1230  , df_denom=2278, df_num=87
# ssr based chi2 test:   chi2=110.7746, p=0.0437  , df=87
# likelihood ratio test: chi2=108.3463, p=0.0604  , df=87
# parameter F test:         F=1.1824  , p=0.1230  , df_denom=2278, df_num=87
#
# Granger Causality
# number of lags (no zero) 88
# ssr based F test:         F=1.1705  , p=0.1363  , df_denom=2275, df_num=88
# ssr based chi2 test:   chi2=111.0219, p=0.0492  , df=88
# likelihood ratio test: chi2=108.5819, p=0.0676  , df=88
# parameter F test:         F=1.1705  , p=0.1363  , df_denom=2275, df_num=88
#
# Granger Causality
# number of lags (no zero) 89
# ssr based F test:         F=1.1557  , p=0.1551  , df_denom=2272, df_num=89
# ssr based chi2 test:   chi2=110.9634, p=0.0575  , df=89
# likelihood ratio test: chi2=108.5249, p=0.0782  , df=89
# parameter F test:         F=1.1557  , p=0.1551  , df_denom=2272, df_num=89
#
# Granger Causality
# number of lags (no zero) 90
# ssr based F test:         F=1.1223  , p=0.2063  , df_denom=2269, df_num=90
# ssr based chi2 test:   chi2=109.0680, p=0.0837  , df=90
# likelihood ratio test: chi2=106.7100, p=0.1103  , df=90
# parameter F test:         F=1.1223  , p=0.2063  , df_denom=2269, df_num=90
#
# Granger Causality
# number of lags (no zero) 91
# ssr based F test:         F=1.1378  , p=0.1797  , df_denom=2266, df_num=91
# ssr based chi2 test:   chi2=111.8970, p=0.0678  , df=91
# likelihood ratio test: chi2=109.4159, p=0.0916  , df=91
# parameter F test:         F=1.1378  , p=0.1797  , df_denom=2266, df_num=91
#
# Granger Causality
# number of lags (no zero) 92
# ssr based F test:         F=1.1207  , p=0.2070  , df_denom=2263, df_num=92
# ssr based chi2 test:   chi2=111.5378, p=0.0811  , df=92
# likelihood ratio test: chi2=109.0715, p=0.1081  , df=92
# parameter F test:         F=1.1207  , p=0.2070  , df_denom=2263, df_num=92
#
# Granger Causality
# number of lags (no zero) 93
# ssr based F test:         F=1.1221  , p=0.2035  , df_denom=2260, df_num=93
# ssr based chi2 test:   chi2=112.9931, p=0.0777  , df=93
# likelihood ratio test: chi2=110.4619, p=0.1045  , df=93
# parameter F test:         F=1.1221  , p=0.2035  , df_denom=2260, df_num=93
#
# Granger Causality
# number of lags (no zero) 94
# ssr based F test:         F=1.1121  , p=0.2205  , df_denom=2257, df_num=94
# ssr based chi2 test:   chi2=113.2874, p=0.0856  , df=94
# likelihood ratio test: chi2=110.7422, p=0.1144  , df=94
# parameter F test:         F=1.1121  , p=0.2205  , df_denom=2257, df_num=94
#
# Granger Causality
# number of lags (no zero) 95
# ssr based F test:         F=1.1013  , p=0.2400  , df_denom=2254, df_num=95
# ssr based chi2 test:   chi2=113.4936, p=0.0949  , df=95
# likelihood ratio test: chi2=110.9382, p=0.1261  , df=95
# parameter F test:         F=1.1013  , p=0.2400  , df_denom=2254, df_num=95
#
# Granger Causality
# number of lags (no zero) 96
# ssr based F test:         F=1.0928  , p=0.2561  , df_denom=2251, df_num=96
# ssr based chi2 test:   chi2=113.9072, p=0.1025  , df=96
# likelihood ratio test: chi2=111.3325, p=0.1356  , df=96
# parameter F test:         F=1.0928  , p=0.2561  , df_denom=2251, df_num=96
#
# Granger Causality
# number of lags (no zero) 97
# ssr based F test:         F=1.0888  , p=0.2637  , df_denom=2248, df_num=97
# ssr based chi2 test:   chi2=114.7708, p=0.1052  , df=97
# likelihood ratio test: chi2=112.1565, p=0.1393  , df=97
# parameter F test:         F=1.0888  , p=0.2637  , df_denom=2248, df_num=97
#
# Granger Causality
# number of lags (no zero) 98
# ssr based F test:         F=1.0676  , p=0.3097  , df_denom=2245, df_num=98
# ssr based chi2 test:   chi2=113.8006, p=0.1313  , df=98
# likelihood ratio test: chi2=111.2286, p=0.1704  , df=98
# parameter F test:         F=1.0676  , p=0.3097  , df_denom=2245, df_num=98
#
# Granger Causality
# number of lags (no zero) 99
# ssr based F test:         F=1.0521  , p=0.3459  , df_denom=2242, df_num=99
# ssr based chi2 test:   chi2=113.4007, p=0.1528  , df=99
# likelihood ratio test: chi2=110.8454, p=0.1956  , df=99
# parameter F test:         F=1.0521  , p=0.3459  , df_denom=2242, df_num=99
#
# Granger Causality
# number of lags (no zero) 100
# ssr based F test:         F=1.0545  , p=0.3394  , df_denom=2239, df_num=100
# ssr based chi2 test:   chi2=114.9190, p=0.1461  , df=100
# likelihood ratio test: chi2=112.2949, p=0.1887  , df=100
# parameter F test:         F=1.0545  , p=0.3394  , df_denom=2239, df_num=100

# %%
def find_lags(test):
    lag_found = False
    lags = []
    
    for i in range(1, maxlag):
        p = test[i][0]['ssr_ftest'][1]
        if (p < 0.05):
            lags.append(test[i][0]['ssr_ftest'])
            lag_found = True

    if (lag_found == True):
        return lags
    else:
        print("lag not found")

# %%
lags_info = find_lags(test)

# %%
lags_info
# Out:
# [(8.089869391077013, 0.004487016466323889, 2536.0, 1),
#  (4.62873244150067, 0.009849894056606443, 2533.0, 2),
#  (3.5041455144244913, 0.014810302637529704, 2530.0, 3),
#  (2.6044894171731925, 0.03419332561287149, 2527.0, 4),
#  (2.0231268038932626, 0.048810885919218006, 2518.0, 7),
#  (2.230808938093935, 0.022739751273766883, 2515.0, 8),
#  (2.0079699233565185, 0.03480295249475197, 2512.0, 9),
#  (1.995994373672954, 0.01769205735760449, 2500.0, 13),
#  (2.0386197652611204, 0.012404250607010026, 2497.0, 14),
#  (1.7178696247183478, 0.04126780576920983, 2494.0, 15),
#  (1.7319031937425429, 0.025337112099918183, 2482.0, 19),
#  (1.654545564409579, 0.033816506561525336, 2479.0, 20),
#  (1.8078163188475744, 0.013527636342464332, 2476.0, 21),
#  (1.6264119301713198, 0.03294713653554664, 2473.0, 22),
#  (1.6071740213321737, 0.0337347638616717, 2470.0, 23),
#  (1.5550164756721798, 0.041734595446157555, 2467.0, 24),
#  (1.5311567437241378, 0.04460904962316748, 2464.0, 25),
#  (1.5624905288249362, 0.0349069550268957, 2461.0, 26),
#  (1.5695543859356382, 0.031236701846270018, 2458.0, 27),
#  (1.5667121894217606, 0.02967532501398761, 2455.0, 28),
#  (1.6326496711468494, 0.017961370458369968, 2452.0, 29),
#  (1.5673592919265746, 0.025789478910011886, 2449.0, 30),
#  (1.5164737607418641, 0.03388093928009701, 2446.0, 31),
#  (1.4921571374280451, 0.03376424750940144, 2437.0, 34),
#  (1.424864352990116, 0.04888267830887493, 2431.0, 36),
#  (1.455308060650455, 0.037721478529856446, 2428.0, 37),
#  (1.2749162768993483, 0.0482387605216175, 2284.0, 85),
#  (1.3458452718936176, 0.020190704756626078, 2281.0, 86),
#  (1.35924004275494, 0.016546264722065062, 2278.0, 87),
#  (1.370296770815266, 0.013901016001176165, 2275.0, 88),
#  (1.3987399626098116, 0.009136075503841956, 2272.0, 89),
#  (1.3709103760990742, 0.013013666379144147, 2269.0, 90),
#  (1.410975949929663, 0.007183413258156849, 2266.0, 91),
#  (1.4097335182030677, 0.007071512327282197, 2263.0, 92),
#  (1.3950574372706672, 0.008469536412047046, 2260.0, 93),
#  (1.384212994619156, 0.00960058652797534, 2257.0, 94),
#  (1.349343853548895, 0.015262603225673547, 2254.0, 95),
#  (1.3471667116858654, 0.015330873336320043, 2251.0, 96),
#  (1.3680889430948746, 0.011098630916520927, 2248.0, 97),
#  (1.341534538268838, 0.01577058581953885, 2245.0, 98),
#  (1.3248435606444955, 0.019419154087430956, 2242.0, 99)]

# %% [markdown]
# # Granger Tests - RUN

# %% [markdown]
# # Granger Tests - PLUG

# %% [markdown]
# #  Granger Tests - SPWR
