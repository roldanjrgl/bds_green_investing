# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk 
import string
import re
import dateutil.parser
# %matplotlib inline
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ## Load data

# %%
# Load dataset
twitter_data_all = pd.read_csv('../../data/data_collected_ref_cleaned/2_first_solar_tweets_cleaned_v2.csv')

# %%
# twitter_data_all.head()

# %%
# twitter_data_all.info()

# %%
# datetime = pd.to_datetime(twitter_data['CreatedAt'])

# %% [markdown]
# ## Delete header rows

# %%
index_names = twitter_data_all[ twitter_data_all['CreatedAt'] == 'CreatedAt' ].index
index_names
# Out:
# Int64Index([   492,    989,   1208,   1704,   2196,   2665,   3163,   3664,
#               4163,   4540,
#             ...
#             152624, 153118, 153617, 154117, 154615, 155113, 155609, 156105,
#             156600, 157096],
#            dtype='int64', length=352)

# %%
twitter_data_all.drop(index_names, inplace = True)

# %%
twitter_data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156812 entries, 0 to 157163
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CreatedAt         156812 non-null  object
#  1   TweetId           156812 non-null  object
#  2   AuthorId          156812 non-null  object
#  3   TweetText         156812 non-null  object
#  4   Tweet_punct       156812 non-null  object
#  5   Tweet_tokenized   156812 non-null  object
#  6   Tweet_nonstop     156812 non-null  object
#  7   Tweet_stemmed     156812 non-null  object
#  8   Tweet_lemmatized  156812 non-null  object
# dtypes: object(9)
# memory usage: 12.0+ MB

# %% [markdown]
# ## Select Columns

# %%
columns = ['CreatedAt',  'TweetId', 'AuthorId', 'TweetText', 'Tweet_stemmed']
twitter_data = twitter_data_all[columns]
twitter_data.head()
# Out:
#                   CreatedAt              TweetId             AuthorId  \
# 0  2021-04-01T00:50:05.000Z  1377422984751775755  1134049078424162304
# 1  2021-03-31T23:54:00.000Z  1377408871212351489            586116334
# 2  2021-03-31T23:47:40.000Z  1377407278056230912  1313171678625701889
# 3  2021-03-31T23:31:00.000Z  1377403081005150211   831801503694336000
# 4  2021-03-31T23:29:07.000Z  1377402607010902019  1355194932445786112
#
#                                                                                              TweetText  \
# 0  First Solar Completes Sale of North American O&amp;M Business to NovaSource $FSLR https://t.co/j...
# 1  $ALYI To Reveal New Significant Investment In Company From Leading Texas Based Private Equity Fu...
# 2  @SolarPowerEU @renewableH2EU @EU_Commission @Akuo_Energy @enelgreenpower @EdpRenewables @Enapter...
# 3                                                  $FSLR sector move confirmed https://t.co/h08Dwn5CIF
# 4  $FSLR NovaSource Power Services is World's Largest Solar O&amp;M Provider with Acquisition of Fi...
#
#                                                                                          Tweet_stemmed
# 0  ['first', 'solar', 'complet', 'sale', 'north', 'american', 'oampm', 'busi', 'novasourc', 'fslr',...
# 1  ['alyi', 'reveal', 'new', 'signific', 'invest', 'compani', 'lead', 'texa', 'base', 'privat', 'eq...
# 2  ['solarpowereu', 'renewableheu', 'eucommiss', 'akuoenergi', 'enelgreenpow', 'edprenew', 'enapt',...
# 3                                             ['fslr', 'sector', 'move', 'confirm', 'httpstcohdwncif']
# 4  ['fslr', 'novasourc', 'power', 'servic', 'world', 'largest', 'solar', 'oampm', 'provid', 'acquis...

# %%
print(dateutil.parser.isoparse('2008-09-03T20:56:35.450686Z'))
# Out:
# 2008-09-03 20:56:35.450686+00:00

# %%
# twitter_data.head()
def change_time_type(createdAtAtribute):
    changed_time = dateutil.parser.isoparse(createdAtAtribute)
    return changed_time

# %%
# twitter_data['datetest'] = dateutil.parser.isoparse((twitter_data['CreatedAt']))
# twitter_data_date_test = twitter_data['CreatedAt'][0]
# twitter_data_date_test
# print(dateutil.parser.isoparse(twitter_data_date_test))
# # testing = change_time_type(twitter_data['CreatedAt'][0])
# print(twitter_data['CreatedAt'])
# print(change_time_type(twitter_data['CreatedAt'][0]))

# %%
twitter_data['created_datetime'] = twitter_data['CreatedAt'].apply(lambda x: change_time_type(x))
# print(type(twitter_data['CreatedAt'][0]))
# Out:
# <ipython-input-13-02a89fb700ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitter_data['created_datetime'] = twitter_data['CreatedAt'].apply(lambda x: change_time_type(x))

# %%
twitter_data.head()
# Out:
#                   CreatedAt              TweetId             AuthorId  \
# 0  2021-04-01T00:50:05.000Z  1377422984751775755  1134049078424162304
# 1  2021-03-31T23:54:00.000Z  1377408871212351489            586116334
# 2  2021-03-31T23:47:40.000Z  1377407278056230912  1313171678625701889
# 3  2021-03-31T23:31:00.000Z  1377403081005150211   831801503694336000
# 4  2021-03-31T23:29:07.000Z  1377402607010902019  1355194932445786112
#
#                                                                                              TweetText  \
# 0  First Solar Completes Sale of North American O&amp;M Business to NovaSource $FSLR https://t.co/j...
# 1  $ALYI To Reveal New Significant Investment In Company From Leading Texas Based Private Equity Fu...
# 2  @SolarPowerEU @renewableH2EU @EU_Commission @Akuo_Energy @enelgreenpower @EdpRenewables @Enapter...
# 3                                                  $FSLR sector move confirmed https://t.co/h08Dwn5CIF
# 4  $FSLR NovaSource Power Services is World's Largest Solar O&amp;M Provider with Acquisition of Fi...
#
#                                                                                          Tweet_stemmed  \
# 0  ['first', 'solar', 'complet', 'sale', 'north', 'american', 'oampm', 'busi', 'novasourc', 'fslr',...
# 1  ['alyi', 'reveal', 'new', 'signific', 'invest', 'compani', 'lead', 'texa', 'base', 'privat', 'eq...
# 2  ['solarpowereu', 'renewableheu', 'eucommiss', 'akuoenergi', 'enelgreenpow', 'edprenew', 'enapt',...
# 3                                             ['fslr', 'sector', 'move', 'confirm', 'httpstcohdwncif']
# 4  ['fslr', 'novasourc', 'power', 'servic', 'world', 'largest', 'solar', 'oampm', 'provid', 'acquis...
#
#            created_datetime
# 0 2021-04-01 00:50:05+00:00
# 1 2021-03-31 23:54:00+00:00
# 2 2021-03-31 23:47:40+00:00
# 3 2021-03-31 23:31:00+00:00
# 4 2021-03-31 23:29:07+00:00

# %%
twitter_data['day'] = twitter_data['created_datetime'].apply(lambda x: "%d/%d/%d" % (x.month, x.day , x.year))
# Out:
# <ipython-input-15-cac6ce402a0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitter_data['day'] = twitter_data['created_datetime'].apply(lambda x: "%d/%d/%d" % (x.month, x.day , x.year))

# %%
twitter_data.head()
# Out:
#                   CreatedAt              TweetId             AuthorId  \
# 0  2021-04-01T00:50:05.000Z  1377422984751775755  1134049078424162304
# 1  2021-03-31T23:54:00.000Z  1377408871212351489            586116334
# 2  2021-03-31T23:47:40.000Z  1377407278056230912  1313171678625701889
# 3  2021-03-31T23:31:00.000Z  1377403081005150211   831801503694336000
# 4  2021-03-31T23:29:07.000Z  1377402607010902019  1355194932445786112
#
#                                                                                              TweetText  \
# 0  First Solar Completes Sale of North American O&amp;M Business to NovaSource $FSLR https://t.co/j...
# 1  $ALYI To Reveal New Significant Investment In Company From Leading Texas Based Private Equity Fu...
# 2  @SolarPowerEU @renewableH2EU @EU_Commission @Akuo_Energy @enelgreenpower @EdpRenewables @Enapter...
# 3                                                  $FSLR sector move confirmed https://t.co/h08Dwn5CIF
# 4  $FSLR NovaSource Power Services is World's Largest Solar O&amp;M Provider with Acquisition of Fi...
#
#                                                                                          Tweet_stemmed  \
# 0  ['first', 'solar', 'complet', 'sale', 'north', 'american', 'oampm', 'busi', 'novasourc', 'fslr',...
# 1  ['alyi', 'reveal', 'new', 'signific', 'invest', 'compani', 'lead', 'texa', 'base', 'privat', 'eq...
# 2  ['solarpowereu', 'renewableheu', 'eucommiss', 'akuoenergi', 'enelgreenpow', 'edprenew', 'enapt',...
# 3                                             ['fslr', 'sector', 'move', 'confirm', 'httpstcohdwncif']
# 4  ['fslr', 'novasourc', 'power', 'servic', 'world', 'largest', 'solar', 'oampm', 'provid', 'acquis...
#
#            created_datetime        day
# 0 2021-04-01 00:50:05+00:00   4/1/2021
# 1 2021-03-31 23:54:00+00:00  3/31/2021
# 2 2021-03-31 23:47:40+00:00  3/31/2021
# 3 2021-03-31 23:31:00+00:00  3/31/2021
# 4 2021-03-31 23:29:07+00:00  3/31/2021

# %% [markdown]
# # Group By Week

# %%
twitter_data.columns
# Out:
# Index(['CreatedAt', 'TweetId', 'AuthorId', 'TweetText', 'Tweet_stemmed',
#        'created_datetime', 'day'],
#       dtype='object')

# %%
twitter_data.index = pd.to_datetime(twitter_data['CreatedAt'])

# %%
df_1 = twitter_data.resample('W').count()

# %%
df_1
# Out:
#                            CreatedAt  TweetId  AuthorId  TweetText  \
# CreatedAt
# 2011-01-02 00:00:00+00:00          5        5         5          5
# 2011-01-09 00:00:00+00:00         80       80        80         80
# 2011-01-16 00:00:00+00:00         75       75        75         75
# 2011-01-23 00:00:00+00:00         93       93        93         93
# 2011-01-30 00:00:00+00:00        142      142       142        142
# ...                              ...      ...       ...        ...
# 2021-03-07 00:00:00+00:00        232      232       232        232
# 2021-03-14 00:00:00+00:00        375      375       375        375
# 2021-03-21 00:00:00+00:00        169      169       169        169
# 2021-03-28 00:00:00+00:00        250      250       250        250
# 2021-04-04 00:00:00+00:00        181      181       181        181
#
#                            Tweet_stemmed  created_datetime  day
# CreatedAt
# 2011-01-02 00:00:00+00:00              5                 5    5
# 2011-01-09 00:00:00+00:00             80                80   80
# 2011-01-16 00:00:00+00:00             75                75   75
# 2011-01-23 00:00:00+00:00             93                93   93
# 2011-01-30 00:00:00+00:00            142               142  142
# ...                                  ...               ...  ...
# 2021-03-07 00:00:00+00:00            232               232  232
# 2021-03-14 00:00:00+00:00            375               375  375
# 2021-03-21 00:00:00+00:00            169               169  169
# 2021-03-28 00:00:00+00:00            250               250  250
# 2021-04-04 00:00:00+00:00            181               181  181
#
# [536 rows x 7 columns]

# %%
weekly_pop = df_1['day']

# %%
weekly_pop_df = pd.DataFrame(weekly_pop)

# %%
# plt.figure(figsize=(15,6))
# df1 = twitter_data_by_week_df.set_index('w') # setting "Years" as index
# fig,ax = plt.subplots(figsize=(15,6))
# df1.plot(kind='line',ax=ax)
# plt.title("First Solar Tweet Time Series")
# plt.show()

# %%
weekly_pop_df.rename(columns = {"day":"count"})
weekly_pop_df.rename(columns = {"CreatedAt":"week"})
# df.rename(columns={"A": "a", "B": "c"})
# Out:
#                            day
# CreatedAt
# 2011-01-02 00:00:00+00:00    5
# 2011-01-09 00:00:00+00:00   80
# 2011-01-16 00:00:00+00:00   75
# 2011-01-23 00:00:00+00:00   93
# 2011-01-30 00:00:00+00:00  142
# ...                        ...
# 2021-03-07 00:00:00+00:00  232
# 2021-03-14 00:00:00+00:00  375
# 2021-03-21 00:00:00+00:00  169
# 2021-03-28 00:00:00+00:00  250
# 2021-04-04 00:00:00+00:00  181
#
# [536 rows x 1 columns]

# %%
weekly_pop_df.reset_index
# Out:
# <bound method DataFrame.reset_index of                            day
# CreatedAt
# 2011-01-02 00:00:00+00:00    5
# 2011-01-09 00:00:00+00:00   80
# 2011-01-16 00:00:00+00:00   75
# 2011-01-23 00:00:00+00:00   93
# 2011-01-30 00:00:00+00:00  142
# ...                        ...
# 2021-03-07 00:00:00+00:00  232
# 2021-03-14 00:00:00+00:00  375
# 2021-03-21 00:00:00+00:00  169
# 2021-03-28 00:00:00+00:00  250
# 2021-04-04 00:00:00+00:00  181
#
# [536 rows x 1 columns]>

# %%
weekly_pop_df.reset_index(inplace=True)

# %%
plt.figure(figsize=(15,6))
df1 = weekly_pop_df.set_index('CreatedAt') # setting "Years" as index
fig,ax = plt.subplots(figsize=(15,6))
df1.plot(kind='line',ax=ax)
plt.title("First Solar Tweet Time Series")
plt.show()

# %% [markdown]
# # Group By Week

# %%
twitter_data
# Out:
#                                           CreatedAt              TweetId  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  2021-04-01T00:50:05.000Z  1377422984751775755
# 2021-03-31 23:54:00+00:00  2021-03-31T23:54:00.000Z  1377408871212351489
# 2021-03-31 23:47:40+00:00  2021-03-31T23:47:40.000Z  1377407278056230912
# 2021-03-31 23:31:00+00:00  2021-03-31T23:31:00.000Z  1377403081005150211
# 2021-03-31 23:29:07+00:00  2021-03-31T23:29:07.000Z  1377402607010902019
# ...                                             ...                  ...
# 2011-01-02 23:43:44+00:00  2011-01-02T23:43:44.000Z    21713283799056384
# 2011-01-02 16:06:34+00:00  2011-01-02T16:06:34.000Z    21598232073216001
# 2011-01-02 06:33:22+00:00  2011-01-02T06:33:22.000Z    21453981167394816
# 2011-01-02 00:16:28+00:00  2011-01-02T00:16:28.000Z    21359133609431040
# 2011-01-01 05:30:11+00:00  2011-01-01T05:30:11.000Z    21075692561113088
#
#                                       AuthorId  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  1134049078424162304
# 2021-03-31 23:54:00+00:00            586116334
# 2021-03-31 23:47:40+00:00  1313171678625701889
# 2021-03-31 23:31:00+00:00   831801503694336000
# 2021-03-31 23:29:07+00:00  1355194932445786112
# ...                                        ...
# 2011-01-02 23:43:44+00:00             53215424
# 2011-01-02 16:06:34+00:00            100592354
# 2011-01-02 06:33:22+00:00            100592354
# 2011-01-02 00:16:28+00:00            162521687
# 2011-01-01 05:30:11+00:00            220900876
#
#                                                                                                                      TweetText  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  First Solar Completes Sale of North American O&amp;M Business to NovaSource $FSLR https://t.co/j...
# 2021-03-31 23:54:00+00:00  $ALYI To Reveal New Significant Investment In Company From Leading Texas Based Private Equity Fu...
# 2021-03-31 23:47:40+00:00  @SolarPowerEU @renewableH2EU @EU_Commission @Akuo_Energy @enelgreenpower @EdpRenewables @Enapter...
# 2021-03-31 23:31:00+00:00                                                  $FSLR sector move confirmed https://t.co/h08Dwn5CIF
# 2021-03-31 23:29:07+00:00  $FSLR NovaSource Power Services is World's Largest Solar O&amp;M Provider with Acquisition of Fi...
# ...                                                                                                                        ...
# 2011-01-02 23:43:44+00:00  @womarmd - Just watching right now... as I am not convinced yet on solar...  $FSLR needs to hold...
# 2011-01-02 16:06:34+00:00  SHORT BUSt - Scope L: entries on high SS interest names $ADS  $BBBB  $CIEN  $CTCT  $FSLR  $PWER ...
# 2011-01-02 06:33:22+00:00  SOLARS - Auriga USA research on sector is very good. Top FA names $SOLR  $TSL may not be top ST ...
# 2011-01-02 00:16:28+00:00  Stochastic Crossover: this stock may rally - $FSLR - http://www.dojispace.com/stock-picks/first-...
# 2011-01-01 05:30:11+00:00      Someone just got a simple quote on $FSLR @simplestockqtes http://www.simplestockquotes.com/FSLR
#
#                                                                                                                  Tweet_stemmed  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  ['first', 'solar', 'complet', 'sale', 'north', 'american', 'oampm', 'busi', 'novasourc', 'fslr',...
# 2021-03-31 23:54:00+00:00  ['alyi', 'reveal', 'new', 'signific', 'invest', 'compani', 'lead', 'texa', 'base', 'privat', 'eq...
# 2021-03-31 23:47:40+00:00  ['solarpowereu', 'renewableheu', 'eucommiss', 'akuoenergi', 'enelgreenpow', 'edprenew', 'enapt',...
# 2021-03-31 23:31:00+00:00                                             ['fslr', 'sector', 'move', 'confirm', 'httpstcohdwncif']
# 2021-03-31 23:29:07+00:00  ['fslr', 'novasourc', 'power', 'servic', 'world', 'largest', 'solar', 'oampm', 'provid', 'acquis...
# ...                                                                                                                        ...
# 2011-01-02 23:43:44+00:00  ['womarmd', 'watch', 'right', 'convinc', 'yet', 'solar', 'fslr', 'need', 'hold', 'jaso', 'break'...
# 2011-01-02 16:06:34+00:00  ['short', 'bust', 'scope', 'l', 'entri', 'high', 'ss', 'interest', 'name', 'ad', 'bbbb', 'cien',...
# 2011-01-02 06:33:22+00:00  ['solar', 'auriga', 'usa', 'research', 'sector', 'good', 'top', 'fa', 'name', 'solr', 'tsl', 'ma...
# 2011-01-02 00:16:28+00:00  ['stochast', 'crossov', 'stock', 'may', 'ralli', 'fslr', 'httpwwwdojispacecomstockpicksfirstsola...
# 2011-01-01 05:30:11+00:00       ['someon', 'got', 'simpl', 'quot', 'fslr', 'simplestockqt', 'httpwwwsimplestockquotescomfslr']
#
#                                    created_datetime        day
# CreatedAt
# 2021-04-01 00:50:05+00:00 2021-04-01 00:50:05+00:00   4/1/2021
# 2021-03-31 23:54:00+00:00 2021-03-31 23:54:00+00:00  3/31/2021
# 2021-03-31 23:47:40+00:00 2021-03-31 23:47:40+00:00  3/31/2021
# 2021-03-31 23:31:00+00:00 2021-03-31 23:31:00+00:00  3/31/2021
# 2021-03-31 23:29:07+00:00 2021-03-31 23:29:07+00:00  3/31/2021
# ...                                             ...        ...
# 2011-01-02 23:43:44+00:00 2011-01-02 23:43:44+00:00   1/2/2011
# 2011-01-02 16:06:34+00:00 2011-01-02 16:06:34+00:00   1/2/2011
# 2011-01-02 06:33:22+00:00 2011-01-02 06:33:22+00:00   1/2/2011
# 2011-01-02 00:16:28+00:00 2011-01-02 00:16:28+00:00   1/2/2011
# 2011-01-01 05:30:11+00:00 2011-01-01 05:30:11+00:00   1/1/2011
#
# [156812 rows x 7 columns]

# %%
popularity_first_solar =  pd.DataFrame(twitter_data)

# %%
popularity_first_solar['Company'] = "First Solar"

# %%
popularity_first_solar['Week Number'] = popularity_first_solar['created_datetime'].dt.week
# Out:
# <ipython-input-80-2967631eb506>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   popularity_first_solar['Week Number'] = popularity_first_solar['created_datetime'].dt.week

# %%
popularity_first_solar
# Out:
#                                           CreatedAt              TweetId  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  2021-04-01T00:50:05.000Z  1377422984751775755
# 2021-03-31 23:54:00+00:00  2021-03-31T23:54:00.000Z  1377408871212351489
# 2021-03-31 23:47:40+00:00  2021-03-31T23:47:40.000Z  1377407278056230912
# 2021-03-31 23:31:00+00:00  2021-03-31T23:31:00.000Z  1377403081005150211
# 2021-03-31 23:29:07+00:00  2021-03-31T23:29:07.000Z  1377402607010902019
# ...                                             ...                  ...
# 2011-01-02 23:43:44+00:00  2011-01-02T23:43:44.000Z    21713283799056384
# 2011-01-02 16:06:34+00:00  2011-01-02T16:06:34.000Z    21598232073216001
# 2011-01-02 06:33:22+00:00  2011-01-02T06:33:22.000Z    21453981167394816
# 2011-01-02 00:16:28+00:00  2011-01-02T00:16:28.000Z    21359133609431040
# 2011-01-01 05:30:11+00:00  2011-01-01T05:30:11.000Z    21075692561113088
#
#                                       AuthorId  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  1134049078424162304
# 2021-03-31 23:54:00+00:00            586116334
# 2021-03-31 23:47:40+00:00  1313171678625701889
# 2021-03-31 23:31:00+00:00   831801503694336000
# 2021-03-31 23:29:07+00:00  1355194932445786112
# ...                                        ...
# 2011-01-02 23:43:44+00:00             53215424
# 2011-01-02 16:06:34+00:00            100592354
# 2011-01-02 06:33:22+00:00            100592354
# 2011-01-02 00:16:28+00:00            162521687
# 2011-01-01 05:30:11+00:00            220900876
#
#                                                                                                                      TweetText  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  First Solar Completes Sale of North American O&amp;M Business to NovaSource $FSLR https://t.co/j...
# 2021-03-31 23:54:00+00:00  $ALYI To Reveal New Significant Investment In Company From Leading Texas Based Private Equity Fu...
# 2021-03-31 23:47:40+00:00  @SolarPowerEU @renewableH2EU @EU_Commission @Akuo_Energy @enelgreenpower @EdpRenewables @Enapter...
# 2021-03-31 23:31:00+00:00                                                  $FSLR sector move confirmed https://t.co/h08Dwn5CIF
# 2021-03-31 23:29:07+00:00  $FSLR NovaSource Power Services is World's Largest Solar O&amp;M Provider with Acquisition of Fi...
# ...                                                                                                                        ...
# 2011-01-02 23:43:44+00:00  @womarmd - Just watching right now... as I am not convinced yet on solar...  $FSLR needs to hold...
# 2011-01-02 16:06:34+00:00  SHORT BUSt - Scope L: entries on high SS interest names $ADS  $BBBB  $CIEN  $CTCT  $FSLR  $PWER ...
# 2011-01-02 06:33:22+00:00  SOLARS - Auriga USA research on sector is very good. Top FA names $SOLR  $TSL may not be top ST ...
# 2011-01-02 00:16:28+00:00  Stochastic Crossover: this stock may rally - $FSLR - http://www.dojispace.com/stock-picks/first-...
# 2011-01-01 05:30:11+00:00      Someone just got a simple quote on $FSLR @simplestockqtes http://www.simplestockquotes.com/FSLR
#
#                                                                                                                  Tweet_stemmed  \
# CreatedAt
# 2021-04-01 00:50:05+00:00  ['first', 'solar', 'complet', 'sale', 'north', 'american', 'oampm', 'busi', 'novasourc', 'fslr',...
# 2021-03-31 23:54:00+00:00  ['alyi', 'reveal', 'new', 'signific', 'invest', 'compani', 'lead', 'texa', 'base', 'privat', 'eq...
# 2021-03-31 23:47:40+00:00  ['solarpowereu', 'renewableheu', 'eucommiss', 'akuoenergi', 'enelgreenpow', 'edprenew', 'enapt',...
# 2021-03-31 23:31:00+00:00                                             ['fslr', 'sector', 'move', 'confirm', 'httpstcohdwncif']
# 2021-03-31 23:29:07+00:00  ['fslr', 'novasourc', 'power', 'servic', 'world', 'largest', 'solar', 'oampm', 'provid', 'acquis...
# ...                                                                                                                        ...
# 2011-01-02 23:43:44+00:00  ['womarmd', 'watch', 'right', 'convinc', 'yet', 'solar', 'fslr', 'need', 'hold', 'jaso', 'break'...
# 2011-01-02 16:06:34+00:00  ['short', 'bust', 'scope', 'l', 'entri', 'high', 'ss', 'interest', 'name', 'ad', 'bbbb', 'cien',...
# 2011-01-02 06:33:22+00:00  ['solar', 'auriga', 'usa', 'research', 'sector', 'good', 'top', 'fa', 'name', 'solr', 'tsl', 'ma...
# 2011-01-02 00:16:28+00:00  ['stochast', 'crossov', 'stock', 'may', 'ralli', 'fslr', 'httpwwwdojispacecomstockpicksfirstsola...
# 2011-01-01 05:30:11+00:00       ['someon', 'got', 'simpl', 'quot', 'fslr', 'simplestockqt', 'httpwwwsimplestockquotescomfslr']
#
#                                    created_datetime        day      Company  \
# CreatedAt
# 2021-04-01 00:50:05+00:00 2021-04-01 00:50:05+00:00   4/1/2021  First Solar
# 2021-03-31 23:54:00+00:00 2021-03-31 23:54:00+00:00  3/31/2021  First Solar
# 2021-03-31 23:47:40+00:00 2021-03-31 23:47:40+00:00  3/31/2021  First Solar
# 2021-03-31 23:31:00+00:00 2021-03-31 23:31:00+00:00  3/31/2021  First Solar
# 2021-03-31 23:29:07+00:00 2021-03-31 23:29:07+00:00  3/31/2021  First Solar
# ...                                             ...        ...          ...
# 2011-01-02 23:43:44+00:00 2011-01-02 23:43:44+00:00   1/2/2011  First Solar
# 2011-01-02 16:06:34+00:00 2011-01-02 16:06:34+00:00   1/2/2011  First Solar
# 2011-01-02 06:33:22+00:00 2011-01-02 06:33:22+00:00   1/2/2011  First Solar
# 2011-01-02 00:16:28+00:00 2011-01-02 00:16:28+00:00   1/2/2011  First Solar
# 2011-01-01 05:30:11+00:00 2011-01-01 05:30:11+00:00   1/1/2011  First Solar
#
#                            Week Number
# CreatedAt
# 2021-04-01 00:50:05+00:00           13
# 2021-03-31 23:54:00+00:00           13
# 2021-03-31 23:47:40+00:00           13
# 2021-03-31 23:31:00+00:00           13
# 2021-03-31 23:29:07+00:00           13
# ...                                ...
# 2011-01-02 23:43:44+00:00           52
# 2011-01-02 16:06:34+00:00           52
# 2011-01-02 06:33:22+00:00           52
# 2011-01-02 00:16:28+00:00           52
# 2011-01-01 05:30:11+00:00           52
#
# [156812 rows x 9 columns]

# %%
popularity_first_solar['week-year'] = twitter_data['created_datetime'].apply(lambda x: "%d - %d" % (x.week, x.year))
